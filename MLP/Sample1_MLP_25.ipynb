# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.io as sio
from scipy import io as spio
from tqdm import tqdm
import cv2
from sklearn import metrics


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Split Data

# %%
def tic():
    #Homemade version of matlab tic and toc functions
    import time
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    import time
    if 'startTime_for_tictoc' in globals():
        print ('\nElapsed time is ')
        print (str(time.time() - startTime_for_tictoc))
        print('seconds.\n')
    else:
        print ('\nToc: start time not set\n')

# %%
data1= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_1/RDM_Sample_1.mat')
angles1= data1['RDM']['angles'][0][0]
Enn1= data1['RDM']['Strains'][0][0][0][0][5]
Etn1= data1['RDM']['Strains'][0][0][0][0][4]
Ett1= data1['RDM']['Strains'][0][0][0][0][3]
CM1= data1['RDM']['CM'][0][0]

data2= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles2= data2['RDM']['angles'][0][0]
Enn2= data2['RDM']['Strains'][0][0][0][0][5]
Etn2= data2['RDM']['Strains'][0][0][0][0][4]
Ett2= data2['RDM']['Strains'][0][0][0][0][3]
CM2= data2['RDM']['CM'][0][0]

data3= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles3= data3['RDM']['angles'][0][0]
Enn3= data3['RDM']['Strains'][0][0][0][0][5]
Etn3= data3['RDM']['Strains'][0][0][0][0][4]
Ett3= data3['RDM']['Strains'][0][0][0][0][3]
CM3= data3['RDM']['CM'][0][0]

# %%
print(angles1.shape)
print(angles2.shape)
# Out:
# (199, 210)
# (405, 419)

# %%
data= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_1/RDM_Sample_1.mat')
angles= data['RDM']['angles'][0][0]
Enn= data['RDM']['Strains'][0][0][0][0][5]
Etn= data['RDM']['Strains'][0][0][0][0][4]
Ett= data['RDM']['Strains'][0][0][0][0][3]
CM= data['RDM']['CM'][0][0]

indPred= CM==1
wndSize= 25
n,m = angles.shape

print('n=', n , 'm=', m )

stride= int((wndSize-1)/2)
ncases= sum(sum(CM[stride:n-stride,stride:m-stride]==1))

Y= np.zeros((ncases,5))
X0= np.zeros((ncases, wndSize**2))
X1= np.zeros((ncases,1))

cnt=0
for i in range(0+stride,n-stride):
  for j in range(0+stride,m-stride):
    if CM[i,j] == 1:
      indX= range(i-stride,i+stride+1)
      indY= range(j-stride,j+stride+1)
      Maux = angles[indX, :][:, indY]
      row= [Enn[i,j], Etn[i,j], Ett[i,j],i,j]
      Y[cnt,:]= row
      X0[cnt,:]= Maux.flatten()
      X1[cnt,:]= angles[i,j]
      cnt= cnt+1
      prog=cnt/ncases*100
# Out:
# n= 199 m= 210

# %%
Y1=Y[:,1]

df = pd.DataFrame({'Angles': X1.flatten()}) 
df['Enn'] = Y[:,0].flatten()
df['Etn'] = Y[:,1].flatten()
df['Ett'] = Y[:,2].flatten()
df['i'] = Y[:,3].flatten()
df['j'] = Y[:,4].flatten()

# %%
df
# Out:
#          Angles       Enn       Etn       Ett      i      j
# 0      1.265090 -0.019728 -0.006153  0.047145   12.0   35.0
# 1      1.265090 -0.021315 -0.008860  0.044652   12.0   36.0
# 2      1.265090 -0.023895 -0.011431  0.041400   12.0   37.0
# 3      1.268809 -0.026060 -0.013764  0.039412   12.0   38.0
# 4      1.286458 -0.027144 -0.014716  0.038354   12.0   39.0
# ...         ...       ...       ...       ...    ...    ...
# 10660 -0.899112  0.005716  0.009976  0.001424  186.0  162.0
# 10661 -0.899112  0.005706  0.012690  0.002096  186.0  163.0
# 10662 -0.927225  0.004249  0.014915  0.003026  186.0  164.0
# 10663 -0.960139  0.001893  0.016678  0.004734  186.0  165.0
# 10664 -0.960139  0.000269  0.017708  0.005981  186.0  166.0
#
# [10665 rows x 6 columns]

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ## Added noise

# %%
import numpy as np

def augment_data(angles_arr, enn_arr, etn_arr, ett_arr, noise_stddev, noise_prob):
    angle_aug = []
    enn_aug = []
    etn_aug = []
    ett_aug = []
    for angle, enn, etn, ett in zip(angles_arr, enn_arr, etn_arr, ett_arr):
        noise = np.random.normal(0, noise_stddev)
        augmented_angle_ = angle + noise
        augmented_enn_ = enn + noise
        augmented_etn_ = etn + noise
        augmented_ett_ = ett + noise
        
        angle_aug.append(angle)
        enn_aug.append(enn)
        etn_aug.append(etn)
        ett_aug.append(ett)
        
        if np.random.rand() < noise_prob:
            angle_aug.append(augmented_angle_)
            enn_aug.append(augmented_enn_)
            etn_aug.append(augmented_etn_)
            ett_aug.append(augmented_ett_)

    return np.array(angle_aug), np.array(enn_aug), np.array(etn_aug), np.array(ett_aug)

X = X0
y = df.iloc[:,1:4]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Load your input and target data
angle_data = X_train
enn_data = y_train['Enn']
etn_data = y_train['Etn']
ett_data = y_train['Ett']

# Generate augmented input and target data
augmented_angle_data, augmented_enn_data, augmented_etn_data, augmented_ett_data = augment_data(angle_data, enn_data, etn_data, ett_data, 0.2, 0.3)

X_train_aug = augmented_angle_data
y_train_aug = pd.DataFrame(list(zip(augmented_enn_data,augmented_etn_data,augmented_ett_data)),columns=['Enn','Etn','Ett'])

print(X_train.shape, X_train_aug.shape)
print(y_train.shape, y_train_aug.shape)
# Out:
# (7465, 625) (9753, 625)
# (7465, 3) (9753, 3)

# %% [markdown]
# # Model

# %%
# Scaling not augmented data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
print(X_train.shape)

X_test = scaler.transform(X_test)
print(X_test.shape)

# Scaling augmented data
scaler_aug = StandardScaler()
X_train_aug = scaler_aug.fit_transform(X_train_aug)
print(X_train_aug.shape)

X_test_aug = scaler_aug.transform(X_train_aug)
# Out:
# (7465, 625)
# (3200, 625)
# (9753, 625)

# %%
# Import necessary libraries
from sklearn.pipeline import Pipeline
from tensorflow import keras
import numpy as np


model = keras.Sequential([
    keras.layers.Flatten(input_shape=(625,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(158, activation='relu'), 
    keras.layers.Dense(3)
])

model_aug = keras.Sequential([
    keras.layers.Flatten(input_shape=(625,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(158, activation='relu'), 
    keras.layers.Dense(3)  
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
model_aug.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
batch_ = 64
epochs_ = 200
history = model.fit(X_train, y_train, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 2023-09-13 18:07:20.672071: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 94/94 - 1s - loss: 0.0470 - val_loss: 0.0042 - 1s/epoch - 16ms/step
# Epoch 2/200
# 94/94 - 1s - loss: 0.0025 - val_loss: 0.0024 - 527ms/epoch - 6ms/step
# Epoch 3/200
# 94/94 - 0s - loss: 0.0012 - val_loss: 0.0019 - 485ms/epoch - 5ms/step
# Epoch 4/200
# 94/94 - 0s - loss: 7.2473e-04 - val_loss: 0.0017 - 498ms/epoch - 5ms/step
# Epoch 5/200
# 94/94 - 1s - loss: 4.9074e-04 - val_loss: 0.0015 - 618ms/epoch - 7ms/step
# Epoch 6/200
# 94/94 - 1s - loss: 3.5292e-04 - val_loss: 0.0014 - 619ms/epoch - 7ms/step
# Epoch 7/200
# 94/94 - 1s - loss: 2.6727e-04 - val_loss: 0.0014 - 567ms/epoch - 6ms/step
# Epoch 8/200
# 94/94 - 1s - loss: 2.1055e-04 - val_loss: 0.0013 - 581ms/epoch - 6ms/step
# Epoch 9/200
# 94/94 - 1s - loss: 1.6870e-04 - val_loss: 0.0013 - 623ms/epoch - 7ms/step
# Epoch 10/200
# 94/94 - 1s - loss: 1.4062e-04 - val_loss: 0.0012 - 539ms/epoch - 6ms/step
# Epoch 11/200
# 94/94 - 0s - loss: 1.1777e-04 - val_loss: 0.0012 - 415ms/epoch - 4ms/step
# Epoch 12/200
# 94/94 - 0s - loss: 1.0228e-04 - val_loss: 0.0012 - 446ms/epoch - 5ms/step
# Epoch 13/200
# 94/94 - 0s - loss: 9.0308e-05 - val_loss: 0.0012 - 475ms/epoch - 5ms/step
# Epoch 14/200
# 94/94 - 1s - loss: 8.3611e-05 - val_loss: 0.0011 - 501ms/epoch - 5ms/step
# Epoch 15/200
# 94/94 - 0s - loss: 8.1564e-05 - val_loss: 0.0011 - 469ms/epoch - 5ms/step
# Epoch 16/200
# 94/94 - 1s - loss: 8.3577e-05 - val_loss: 0.0011 - 705ms/epoch - 8ms/step
# Epoch 17/200
# 94/94 - 1s - loss: 8.7310e-05 - val_loss: 0.0011 - 543ms/epoch - 6ms/step
# Epoch 18/200
# 94/94 - 0s - loss: 1.0045e-04 - val_loss: 0.0010 - 494ms/epoch - 5ms/step
# Epoch 19/200
# 94/94 - 1s - loss: 1.1449e-04 - val_loss: 0.0010 - 602ms/epoch - 6ms/step
# Epoch 20/200
# 94/94 - 1s - loss: 1.2190e-04 - val_loss: 9.9914e-04 - 535ms/epoch - 6ms/step
# Epoch 21/200
# 94/94 - 0s - loss: 1.4404e-04 - val_loss: 9.4791e-04 - 446ms/epoch - 5ms/step
# Epoch 22/200
# 94/94 - 0s - loss: 1.5104e-04 - val_loss: 8.7705e-04 - 444ms/epoch - 5ms/step
# Epoch 23/200
# 94/94 - 0s - loss: 1.4799e-04 - val_loss: 8.4717e-04 - 426ms/epoch - 5ms/step
# Epoch 24/200
# 94/94 - 0s - loss: 1.4695e-04 - val_loss: 7.9345e-04 - 447ms/epoch - 5ms/step
# Epoch 25/200
# 94/94 - 0s - loss: 1.3279e-04 - val_loss: 7.3384e-04 - 422ms/epoch - 4ms/step
# Epoch 26/200
# 94/94 - 0s - loss: 1.2326e-04 - val_loss: 7.1559e-04 - 461ms/epoch - 5ms/step
# Epoch 27/200
# 94/94 - 0s - loss: 1.0645e-04 - val_loss: 6.7131e-04 - 451ms/epoch - 5ms/step
# Epoch 28/200
# 94/94 - 1s - loss: 9.7480e-05 - val_loss: 6.5715e-04 - 638ms/epoch - 7ms/step
# Epoch 29/200
# 94/94 - 0s - loss: 9.3453e-05 - val_loss: 6.3417e-04 - 472ms/epoch - 5ms/step
# Epoch 30/200
# 94/94 - 1s - loss: 8.8516e-05 - val_loss: 6.1253e-04 - 595ms/epoch - 6ms/step
# Epoch 31/200
# 94/94 - 0s - loss: 8.6572e-05 - val_loss: 5.8161e-04 - 479ms/epoch - 5ms/step
# Epoch 32/200
# 94/94 - 1s - loss: 8.2154e-05 - val_loss: 5.6926e-04 - 685ms/epoch - 7ms/step
# Epoch 33/200
# 94/94 - 0s - loss: 7.7436e-05 - val_loss: 5.4579e-04 - 423ms/epoch - 5ms/step
# Epoch 34/200
# 94/94 - 0s - loss: 7.7375e-05 - val_loss: 5.2184e-04 - 432ms/epoch - 5ms/step
# Epoch 35/200
# 94/94 - 0s - loss: 8.0047e-05 - val_loss: 4.9445e-04 - 407ms/epoch - 4ms/step
# Epoch 36/200
# 94/94 - 0s - loss: 7.5575e-05 - val_loss: 4.7795e-04 - 467ms/epoch - 5ms/step
# Epoch 37/200
# 94/94 - 1s - loss: 7.6333e-05 - val_loss: 4.6040e-04 - 657ms/epoch - 7ms/step
# Epoch 38/200
# 94/94 - 1s - loss: 7.9542e-05 - val_loss: 4.3664e-04 - 564ms/epoch - 6ms/step
# Epoch 39/200
# 94/94 - 1s - loss: 7.4682e-05 - val_loss: 4.1212e-04 - 525ms/epoch - 6ms/step
# Epoch 40/200
# 94/94 - 1s - loss: 7.0387e-05 - val_loss: 4.0228e-04 - 563ms/epoch - 6ms/step
# Epoch 41/200
# 94/94 - 0s - loss: 6.5290e-05 - val_loss: 3.7733e-04 - 422ms/epoch - 4ms/step
# Epoch 42/200
# 94/94 - 0s - loss: 6.2384e-05 - val_loss: 3.6367e-04 - 425ms/epoch - 5ms/step
# Epoch 43/200
# 94/94 - 0s - loss: 5.8409e-05 - val_loss: 3.5610e-04 - 412ms/epoch - 4ms/step
# Epoch 44/200
# 94/94 - 1s - loss: 5.3117e-05 - val_loss: 3.3548e-04 - 593ms/epoch - 6ms/step
# Epoch 45/200
# 94/94 - 0s - loss: 5.4608e-05 - val_loss: 3.2607e-04 - 412ms/epoch - 4ms/step
# Epoch 46/200
# 94/94 - 0s - loss: 4.9193e-05 - val_loss: 3.0237e-04 - 435ms/epoch - 5ms/step
# Epoch 47/200
# 94/94 - 0s - loss: 4.3870e-05 - val_loss: 3.0269e-04 - 417ms/epoch - 4ms/step
# Epoch 48/200
# 94/94 - 1s - loss: 4.0494e-05 - val_loss: 2.8650e-04 - 582ms/epoch - 6ms/step
# Epoch 49/200
# 94/94 - 1s - loss: 4.2168e-05 - val_loss: 2.8676e-04 - 586ms/epoch - 6ms/step
# Epoch 50/200
# 94/94 - 1s - loss: 4.1792e-05 - val_loss: 2.7947e-04 - 546ms/epoch - 6ms/step
# Epoch 51/200
# 94/94 - 1s - loss: 3.9315e-05 - val_loss: 2.7143e-04 - 542ms/epoch - 6ms/step
# Epoch 52/200
# 94/94 - 1s - loss: 3.6773e-05 - val_loss: 2.6517e-04 - 594ms/epoch - 6ms/step
# Epoch 53/200
# 94/94 - 0s - loss: 4.0317e-05 - val_loss: 2.5970e-04 - 496ms/epoch - 5ms/step
# Epoch 54/200
# 94/94 - 0s - loss: 4.1141e-05 - val_loss: 2.3844e-04 - 458ms/epoch - 5ms/step
# Epoch 55/200
# 94/94 - 1s - loss: 3.8738e-05 - val_loss: 2.3378e-04 - 572ms/epoch - 6ms/step
# Epoch 56/200
# 94/94 - 0s - loss: 3.6516e-05 - val_loss: 2.2565e-04 - 409ms/epoch - 4ms/step
# Epoch 57/200
# 94/94 - 0s - loss: 3.5977e-05 - val_loss: 2.2130e-04 - 422ms/epoch - 4ms/step
# Epoch 58/200
# 94/94 - 0s - loss: 3.6996e-05 - val_loss: 2.1764e-04 - 456ms/epoch - 5ms/step
# Epoch 59/200
# 94/94 - 1s - loss: 3.3686e-05 - val_loss: 2.0688e-04 - 674ms/epoch - 7ms/step
# Epoch 60/200
# 94/94 - 1s - loss: 3.6488e-05 - val_loss: 1.9170e-04 - 537ms/epoch - 6ms/step
# Epoch 61/200
# 94/94 - 1s - loss: 3.3926e-05 - val_loss: 1.8630e-04 - 530ms/epoch - 6ms/step
# Epoch 62/200
# 94/94 - 1s - loss: 3.3992e-05 - val_loss: 1.8102e-04 - 512ms/epoch - 5ms/step
# Epoch 63/200
# 94/94 - 0s - loss: 3.1905e-05 - val_loss: 1.7389e-04 - 462ms/epoch - 5ms/step
# Epoch 64/200
# 94/94 - 0s - loss: 2.9294e-05 - val_loss: 1.7119e-04 - 497ms/epoch - 5ms/step
# Epoch 65/200
# 94/94 - 1s - loss: 2.8829e-05 - val_loss: 1.6230e-04 - 616ms/epoch - 7ms/step
# Epoch 66/200
# 94/94 - 1s - loss: 2.7462e-05 - val_loss: 1.6080e-04 - 606ms/epoch - 6ms/step
# Epoch 67/200
# 94/94 - 1s - loss: 2.5647e-05 - val_loss: 1.5879e-04 - 521ms/epoch - 6ms/step
# Epoch 68/200
# 94/94 - 0s - loss: 2.6058e-05 - val_loss: 1.5491e-04 - 493ms/epoch - 5ms/step
# Epoch 69/200
# 94/94 - 0s - loss: 2.6602e-05 - val_loss: 1.4735e-04 - 441ms/epoch - 5ms/step
# Epoch 70/200
# 94/94 - 0s - loss: 2.8232e-05 - val_loss: 1.4960e-04 - 473ms/epoch - 5ms/step
# Epoch 71/200
# 94/94 - 1s - loss: 2.8166e-05 - val_loss: 1.4725e-04 - 515ms/epoch - 5ms/step
# Epoch 72/200
# 94/94 - 0s - loss: 2.6607e-05 - val_loss: 1.3514e-04 - 426ms/epoch - 5ms/step
# Epoch 73/200
# 94/94 - 0s - loss: 2.8139e-05 - val_loss: 1.2727e-04 - 475ms/epoch - 5ms/step
# Epoch 74/200
# 94/94 - 0s - loss: 2.6075e-05 - val_loss: 1.2425e-04 - 471ms/epoch - 5ms/step
# Epoch 75/200
# 94/94 - 0s - loss: 2.4930e-05 - val_loss: 1.2120e-04 - 468ms/epoch - 5ms/step
# Epoch 76/200
# 94/94 - 1s - loss: 2.5091e-05 - val_loss: 1.2137e-04 - 508ms/epoch - 5ms/step
# Epoch 77/200
# 94/94 - 1s - loss: 2.7643e-05 - val_loss: 1.1444e-04 - 564ms/epoch - 6ms/step
# Epoch 78/200
# 94/94 - 0s - loss: 2.3896e-05 - val_loss: 1.1407e-04 - 442ms/epoch - 5ms/step
# Epoch 79/200
# 94/94 - 0s - loss: 2.3848e-05 - val_loss: 1.0748e-04 - 433ms/epoch - 5ms/step
# Epoch 80/200
# 94/94 - 0s - loss: 2.0795e-05 - val_loss: 1.0346e-04 - 461ms/epoch - 5ms/step
# Epoch 81/200
# 94/94 - 0s - loss: 1.9530e-05 - val_loss: 1.0254e-04 - 457ms/epoch - 5ms/step
# Epoch 82/200
# 94/94 - 0s - loss: 1.9409e-05 - val_loss: 1.0150e-04 - 492ms/epoch - 5ms/step
# Epoch 83/200
# 94/94 - 0s - loss: 1.8194e-05 - val_loss: 1.0085e-04 - 448ms/epoch - 5ms/step
# Epoch 84/200
# 94/94 - 0s - loss: 1.8537e-05 - val_loss: 9.9585e-05 - 492ms/epoch - 5ms/step
# Epoch 85/200
# 94/94 - 1s - loss: 1.9152e-05 - val_loss: 9.9013e-05 - 503ms/epoch - 5ms/step
# Epoch 86/200
# 94/94 - 0s - loss: 1.8784e-05 - val_loss: 9.5857e-05 - 447ms/epoch - 5ms/step
# Epoch 87/200
# 94/94 - 1s - loss: 1.7402e-05 - val_loss: 9.3337e-05 - 503ms/epoch - 5ms/step
# Epoch 88/200
# 94/94 - 0s - loss: 1.6395e-05 - val_loss: 9.0515e-05 - 499ms/epoch - 5ms/step
# Epoch 89/200
# 94/94 - 0s - loss: 1.6525e-05 - val_loss: 8.8207e-05 - 458ms/epoch - 5ms/step
# Epoch 90/200
# 94/94 - 0s - loss: 2.2732e-05 - val_loss: 9.9475e-05 - 423ms/epoch - 5ms/step
# Epoch 91/200
# 94/94 - 0s - loss: 2.9413e-05 - val_loss: 8.3205e-05 - 435ms/epoch - 5ms/step
# Epoch 92/200
# 94/94 - 0s - loss: 2.3729e-05 - val_loss: 7.8553e-05 - 456ms/epoch - 5ms/step
# Epoch 93/200
# 94/94 - 0s - loss: 2.1280e-05 - val_loss: 7.6807e-05 - 497ms/epoch - 5ms/step
# Epoch 94/200
# 94/94 - 1s - loss: 2.0558e-05 - val_loss: 7.7318e-05 - 715ms/epoch - 8ms/step
# Epoch 95/200
# 94/94 - 1s - loss: 1.6633e-05 - val_loss: 7.3380e-05 - 576ms/epoch - 6ms/step
# Epoch 96/200
# 94/94 - 0s - loss: 1.4786e-05 - val_loss: 7.4083e-05 - 476ms/epoch - 5ms/step
# Epoch 97/200
# 94/94 - 0s - loss: 1.4396e-05 - val_loss: 7.2310e-05 - 497ms/epoch - 5ms/step
# Epoch 98/200
# 94/94 - 0s - loss: 1.2403e-05 - val_loss: 7.1684e-05 - 432ms/epoch - 5ms/step
# Epoch 99/200
# 94/94 - 0s - loss: 1.1288e-05 - val_loss: 7.2609e-05 - 475ms/epoch - 5ms/step
# Epoch 100/200
# 94/94 - 0s - loss: 1.3316e-05 - val_loss: 7.3056e-05 - 453ms/epoch - 5ms/step
# Epoch 101/200
# 94/94 - 0s - loss: 1.2591e-05 - val_loss: 6.8437e-05 - 459ms/epoch - 5ms/step
# Epoch 102/200
# 94/94 - 0s - loss: 1.3392e-05 - val_loss: 6.9689e-05 - 446ms/epoch - 5ms/step
# Epoch 103/200
# 94/94 - 1s - loss: 1.3185e-05 - val_loss: 6.6783e-05 - 553ms/epoch - 6ms/step
# Epoch 104/200
# 94/94 - 0s - loss: 1.5370e-05 - val_loss: 6.7122e-05 - 486ms/epoch - 5ms/step
# Epoch 105/200
# 94/94 - 1s - loss: 1.5157e-05 - val_loss: 6.5299e-05 - 507ms/epoch - 5ms/step
# Epoch 106/200
# 94/94 - 1s - loss: 1.7444e-05 - val_loss: 7.1641e-05 - 547ms/epoch - 6ms/step
# Epoch 107/200
# 94/94 - 1s - loss: 1.5513e-05 - val_loss: 6.3313e-05 - 551ms/epoch - 6ms/step
# Epoch 108/200
# 94/94 - 1s - loss: 1.3229e-05 - val_loss: 6.3452e-05 - 521ms/epoch - 6ms/step
# Epoch 109/200
# 94/94 - 0s - loss: 1.2007e-05 - val_loss: 6.1614e-05 - 473ms/epoch - 5ms/step
# Epoch 110/200
# 94/94 - 0s - loss: 1.2577e-05 - val_loss: 6.4146e-05 - 469ms/epoch - 5ms/step
# Epoch 111/200
# 94/94 - 0s - loss: 1.2878e-05 - val_loss: 6.0945e-05 - 448ms/epoch - 5ms/step
# Epoch 112/200
# 94/94 - 0s - loss: 1.2518e-05 - val_loss: 5.9151e-05 - 449ms/epoch - 5ms/step
# Epoch 113/200
# 94/94 - 0s - loss: 1.2780e-05 - val_loss: 5.8781e-05 - 453ms/epoch - 5ms/step
# Epoch 114/200
# 94/94 - 0s - loss: 1.2014e-05 - val_loss: 5.7440e-05 - 440ms/epoch - 5ms/step
# Epoch 115/200
# 94/94 - 0s - loss: 1.2166e-05 - val_loss: 5.9344e-05 - 468ms/epoch - 5ms/step
# Epoch 116/200
# 94/94 - 0s - loss: 1.6372e-05 - val_loss: 6.1853e-05 - 447ms/epoch - 5ms/step
# Epoch 117/200
# 94/94 - 0s - loss: 1.7981e-05 - val_loss: 6.1269e-05 - 440ms/epoch - 5ms/step
# Epoch 118/200
# 94/94 - 1s - loss: 1.8068e-05 - val_loss: 6.1565e-05 - 595ms/epoch - 6ms/step
# Epoch 119/200
# 94/94 - 0s - loss: 1.9236e-05 - val_loss: 5.6855e-05 - 437ms/epoch - 5ms/step
# Epoch 120/200
# 94/94 - 1s - loss: 1.5217e-05 - val_loss: 5.5488e-05 - 501ms/epoch - 5ms/step
# Epoch 121/200
# 94/94 - 0s - loss: 1.3338e-05 - val_loss: 5.3050e-05 - 465ms/epoch - 5ms/step
# Epoch 122/200
# 94/94 - 0s - loss: 1.1733e-05 - val_loss: 5.5388e-05 - 469ms/epoch - 5ms/step
# Epoch 123/200
# 94/94 - 0s - loss: 1.1849e-05 - val_loss: 5.3202e-05 - 456ms/epoch - 5ms/step
# Epoch 124/200
# 94/94 - 1s - loss: 1.0328e-05 - val_loss: 5.2961e-05 - 516ms/epoch - 5ms/step
# Epoch 125/200
# 94/94 - 1s - loss: 8.9786e-06 - val_loss: 5.4645e-05 - 582ms/epoch - 6ms/step
# Epoch 126/200
# 94/94 - 1s - loss: 1.0681e-05 - val_loss: 5.1058e-05 - 742ms/epoch - 8ms/step
# Epoch 127/200
# 94/94 - 0s - loss: 1.1350e-05 - val_loss: 5.4721e-05 - 425ms/epoch - 5ms/step
# Epoch 128/200
# 94/94 - 0s - loss: 1.0923e-05 - val_loss: 5.1727e-05 - 464ms/epoch - 5ms/step
# Epoch 129/200
# 94/94 - 0s - loss: 1.1122e-05 - val_loss: 5.4615e-05 - 428ms/epoch - 5ms/step
# Epoch 130/200
# 94/94 - 0s - loss: 1.2619e-05 - val_loss: 5.1481e-05 - 322ms/epoch - 3ms/step
# Epoch 131/200
# 94/94 - 0s - loss: 1.0596e-05 - val_loss: 4.9833e-05 - 348ms/epoch - 4ms/step
# Epoch 132/200
# 94/94 - 0s - loss: 1.0368e-05 - val_loss: 5.0984e-05 - 368ms/epoch - 4ms/step
# Epoch 133/200
# 94/94 - 0s - loss: 9.3802e-06 - val_loss: 5.0126e-05 - 336ms/epoch - 4ms/step
# Epoch 134/200
# 94/94 - 0s - loss: 8.8101e-06 - val_loss: 4.9651e-05 - 323ms/epoch - 3ms/step
# Epoch 135/200
# 94/94 - 0s - loss: 9.2155e-06 - val_loss: 4.7965e-05 - 330ms/epoch - 4ms/step
# Epoch 136/200
# 94/94 - 0s - loss: 8.9894e-06 - val_loss: 4.8708e-05 - 332ms/epoch - 4ms/step
# Epoch 137/200
# 94/94 - 0s - loss: 9.6349e-06 - val_loss: 4.8451e-05 - 331ms/epoch - 4ms/step
# Epoch 138/200
# 94/94 - 0s - loss: 9.3160e-06 - val_loss: 4.9363e-05 - 329ms/epoch - 4ms/step
# Epoch 139/200
# 94/94 - 0s - loss: 8.6474e-06 - val_loss: 4.9694e-05 - 332ms/epoch - 4ms/step
# Epoch 140/200
# 94/94 - 0s - loss: 8.3926e-06 - val_loss: 4.6068e-05 - 331ms/epoch - 4ms/step
# Epoch 141/200
# 94/94 - 0s - loss: 7.4657e-06 - val_loss: 4.7402e-05 - 339ms/epoch - 4ms/step
# Epoch 142/200
# 94/94 - 0s - loss: 8.7574e-06 - val_loss: 4.7627e-05 - 333ms/epoch - 4ms/step
# Epoch 143/200
# 94/94 - 0s - loss: 1.1468e-05 - val_loss: 5.1015e-05 - 332ms/epoch - 4ms/step
# Epoch 144/200
# 94/94 - 0s - loss: 1.3491e-05 - val_loss: 5.7988e-05 - 327ms/epoch - 3ms/step
# Epoch 145/200
# 94/94 - 0s - loss: 1.5691e-05 - val_loss: 4.6971e-05 - 327ms/epoch - 3ms/step
# Epoch 146/200
# 94/94 - 0s - loss: 1.1378e-05 - val_loss: 4.5712e-05 - 355ms/epoch - 4ms/step
# Epoch 147/200
# 94/94 - 0s - loss: 1.1222e-05 - val_loss: 4.5753e-05 - 383ms/epoch - 4ms/step
# Epoch 148/200
# 94/94 - 0s - loss: 9.9027e-06 - val_loss: 4.7490e-05 - 335ms/epoch - 4ms/step
# Epoch 149/200
# 94/94 - 0s - loss: 1.0045e-05 - val_loss: 4.4327e-05 - 332ms/epoch - 4ms/step
# Epoch 150/200
# 94/94 - 0s - loss: 8.9853e-06 - val_loss: 4.4299e-05 - 338ms/epoch - 4ms/step
# Epoch 151/200
# 94/94 - 0s - loss: 1.3003e-05 - val_loss: 4.7506e-05 - 353ms/epoch - 4ms/step
# Epoch 152/200
# 94/94 - 0s - loss: 1.1192e-05 - val_loss: 4.5111e-05 - 344ms/epoch - 4ms/step
# Epoch 153/200
# 94/94 - 0s - loss: 9.5767e-06 - val_loss: 4.3106e-05 - 353ms/epoch - 4ms/step
# Epoch 154/200
# 94/94 - 0s - loss: 7.2944e-06 - val_loss: 4.0995e-05 - 344ms/epoch - 4ms/step
# Epoch 155/200
# 94/94 - 0s - loss: 5.5004e-06 - val_loss: 4.1042e-05 - 338ms/epoch - 4ms/step
# Epoch 156/200
# 94/94 - 0s - loss: 4.8801e-06 - val_loss: 4.0954e-05 - 323ms/epoch - 3ms/step
# Epoch 157/200
# 94/94 - 0s - loss: 5.1861e-06 - val_loss: 4.3261e-05 - 380ms/epoch - 4ms/step
# Epoch 158/200
# 94/94 - 0s - loss: 9.4813e-06 - val_loss: 4.3329e-05 - 333ms/epoch - 4ms/step
# Epoch 159/200
# 94/94 - 0s - loss: 7.9370e-06 - val_loss: 4.2514e-05 - 321ms/epoch - 3ms/step
# Epoch 160/200
# 94/94 - 0s - loss: 6.8926e-06 - val_loss: 4.3246e-05 - 325ms/epoch - 3ms/step
# Epoch 161/200
# 94/94 - 0s - loss: 8.2644e-06 - val_loss: 5.1395e-05 - 327ms/epoch - 3ms/step
# Epoch 162/200
# 94/94 - 0s - loss: 1.6981e-05 - val_loss: 4.7174e-05 - 325ms/epoch - 3ms/step
# Epoch 163/200
# 94/94 - 0s - loss: 1.3441e-05 - val_loss: 4.3449e-05 - 330ms/epoch - 4ms/step
# Epoch 164/200
# 94/94 - 0s - loss: 1.0017e-05 - val_loss: 4.0682e-05 - 325ms/epoch - 3ms/step
# Epoch 165/200
# 94/94 - 0s - loss: 7.2084e-06 - val_loss: 4.0257e-05 - 329ms/epoch - 4ms/step
# Epoch 166/200
# 94/94 - 0s - loss: 6.1103e-06 - val_loss: 4.0201e-05 - 334ms/epoch - 4ms/step
# Epoch 167/200
# 94/94 - 0s - loss: 6.3408e-06 - val_loss: 3.9306e-05 - 325ms/epoch - 3ms/step
# Epoch 168/200
# 94/94 - 0s - loss: 5.4258e-06 - val_loss: 3.9330e-05 - 325ms/epoch - 3ms/step
# Epoch 169/200
# 94/94 - 0s - loss: 4.5308e-06 - val_loss: 3.9569e-05 - 328ms/epoch - 3ms/step
# Epoch 170/200
# 94/94 - 0s - loss: 3.8137e-06 - val_loss: 3.9906e-05 - 330ms/epoch - 4ms/step
# Epoch 171/200
# 94/94 - 0s - loss: 3.4242e-06 - val_loss: 3.8296e-05 - 326ms/epoch - 3ms/step
# Epoch 172/200
# 94/94 - 0s - loss: 3.0764e-06 - val_loss: 3.8640e-05 - 332ms/epoch - 4ms/step
# Epoch 173/200
# 94/94 - 0s - loss: 3.1517e-06 - val_loss: 3.9056e-05 - 328ms/epoch - 3ms/step
# Epoch 174/200
# 94/94 - 0s - loss: 2.7421e-06 - val_loss: 3.8544e-05 - 323ms/epoch - 3ms/step
# Epoch 175/200
# 94/94 - 0s - loss: 5.1086e-06 - val_loss: 4.0020e-05 - 329ms/epoch - 3ms/step
# Epoch 176/200
# 94/94 - 0s - loss: 4.5683e-06 - val_loss: 3.7940e-05 - 329ms/epoch - 3ms/step
# Epoch 177/200
# 94/94 - 0s - loss: 4.0532e-06 - val_loss: 4.2011e-05 - 331ms/epoch - 4ms/step
# Epoch 178/200
# 94/94 - 0s - loss: 4.2331e-06 - val_loss: 3.8932e-05 - 326ms/epoch - 3ms/step
# Epoch 179/200
# 94/94 - 0s - loss: 4.4737e-06 - val_loss: 3.8940e-05 - 328ms/epoch - 3ms/step
# Epoch 180/200
# 94/94 - 0s - loss: 4.4329e-06 - val_loss: 4.0386e-05 - 326ms/epoch - 3ms/step
# Epoch 181/200
# 94/94 - 0s - loss: 4.6071e-06 - val_loss: 3.9103e-05 - 328ms/epoch - 3ms/step
# Epoch 182/200
# 94/94 - 0s - loss: 4.6002e-06 - val_loss: 3.9533e-05 - 335ms/epoch - 4ms/step
# Epoch 183/200
# 94/94 - 0s - loss: 4.5402e-06 - val_loss: 4.0393e-05 - 332ms/epoch - 4ms/step
# Epoch 184/200
# 94/94 - 0s - loss: 6.4125e-06 - val_loss: 4.0684e-05 - 332ms/epoch - 4ms/step
# Epoch 185/200
# 94/94 - 0s - loss: 7.2151e-06 - val_loss: 4.0096e-05 - 441ms/epoch - 5ms/step
# Epoch 186/200
# 94/94 - 0s - loss: 6.2730e-06 - val_loss: 3.9880e-05 - 340ms/epoch - 4ms/step
# Epoch 187/200
# 94/94 - 0s - loss: 5.8454e-06 - val_loss: 3.9960e-05 - 314ms/epoch - 3ms/step
# Epoch 188/200
# 94/94 - 0s - loss: 5.0913e-06 - val_loss: 3.8667e-05 - 326ms/epoch - 3ms/step
# Epoch 189/200
# 94/94 - 0s - loss: 4.3092e-06 - val_loss: 3.7731e-05 - 336ms/epoch - 4ms/step
# Epoch 190/200
# 94/94 - 0s - loss: 7.7319e-06 - val_loss: 4.1388e-05 - 339ms/epoch - 4ms/step
# Epoch 191/200
# 94/94 - 0s - loss: 3.5325e-05 - val_loss: 5.6840e-05 - 329ms/epoch - 3ms/step
# Epoch 192/200
# 94/94 - 0s - loss: 2.5724e-05 - val_loss: 4.6601e-05 - 322ms/epoch - 3ms/step
# Epoch 193/200
# 94/94 - 0s - loss: 1.5649e-05 - val_loss: 3.8677e-05 - 322ms/epoch - 3ms/step
# Epoch 194/200
# 94/94 - 0s - loss: 1.0656e-05 - val_loss: 3.8054e-05 - 336ms/epoch - 4ms/step
# Epoch 195/200
# 94/94 - 0s - loss: 7.0704e-06 - val_loss: 3.7026e-05 - 337ms/epoch - 4ms/step
# Epoch 196/200
# 94/94 - 0s - loss: 6.7619e-06 - val_loss: 3.7177e-05 - 328ms/epoch - 3ms/step
# Epoch 197/200
# 94/94 - 0s - loss: 5.3222e-06 - val_loss: 3.5611e-05 - 318ms/epoch - 3ms/step
# Epoch 198/200
# 94/94 - 0s - loss: 4.3628e-06 - val_loss: 3.4919e-05 - 321ms/epoch - 3ms/step
# Epoch 199/200
# 94/94 - 0s - loss: 3.6911e-06 - val_loss: 3.4735e-05 - 323ms/epoch - 3ms/step
# Epoch 200/200
# 94/94 - 0s - loss: 2.9313e-06 - val_loss: 3.4850e-05 - 328ms/epoch - 3ms/step

# %%
history_aug = model_aug.fit(X_train_aug, y_train_aug, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 122/122 - 1s - loss: 0.0381 - val_loss: 0.0096 - 748ms/epoch - 6ms/step
# Epoch 2/200
# 122/122 - 0s - loss: 0.0071 - val_loss: 0.0071 - 411ms/epoch - 3ms/step
# Epoch 3/200
# 122/122 - 0s - loss: 0.0046 - val_loss: 0.0062 - 456ms/epoch - 4ms/step
# Epoch 4/200
# 122/122 - 0s - loss: 0.0033 - val_loss: 0.0054 - 458ms/epoch - 4ms/step
# Epoch 5/200
# 122/122 - 0s - loss: 0.0027 - val_loss: 0.0054 - 443ms/epoch - 4ms/step
# Epoch 6/200
# 122/122 - 0s - loss: 0.0024 - val_loss: 0.0049 - 446ms/epoch - 4ms/step
# Epoch 7/200
# 122/122 - 0s - loss: 0.0020 - val_loss: 0.0043 - 454ms/epoch - 4ms/step
# Epoch 8/200
# 122/122 - 0s - loss: 0.0017 - val_loss: 0.0041 - 439ms/epoch - 4ms/step
# Epoch 9/200
# 122/122 - 0s - loss: 0.0016 - val_loss: 0.0039 - 449ms/epoch - 4ms/step
# Epoch 10/200
# 122/122 - 0s - loss: 0.0014 - val_loss: 0.0038 - 440ms/epoch - 4ms/step
# Epoch 11/200
# 122/122 - 0s - loss: 0.0014 - val_loss: 0.0037 - 444ms/epoch - 4ms/step
# Epoch 12/200
# 122/122 - 0s - loss: 0.0014 - val_loss: 0.0038 - 447ms/epoch - 4ms/step
# Epoch 13/200
# 122/122 - 0s - loss: 0.0013 - val_loss: 0.0038 - 440ms/epoch - 4ms/step
# Epoch 14/200
# 122/122 - 0s - loss: 0.0012 - val_loss: 0.0032 - 441ms/epoch - 4ms/step
# Epoch 15/200
# 122/122 - 0s - loss: 0.0011 - val_loss: 0.0031 - 450ms/epoch - 4ms/step
# Epoch 16/200
# 122/122 - 0s - loss: 0.0011 - val_loss: 0.0033 - 444ms/epoch - 4ms/step
# Epoch 17/200
# 122/122 - 0s - loss: 0.0011 - val_loss: 0.0031 - 454ms/epoch - 4ms/step
# Epoch 18/200
# 122/122 - 0s - loss: 0.0011 - val_loss: 0.0032 - 443ms/epoch - 4ms/step
# Epoch 19/200
# 122/122 - 0s - loss: 0.0013 - val_loss: 0.0028 - 450ms/epoch - 4ms/step
# Epoch 20/200
# 122/122 - 0s - loss: 0.0011 - val_loss: 0.0029 - 439ms/epoch - 4ms/step
# Epoch 21/200
# 122/122 - 0s - loss: 9.7598e-04 - val_loss: 0.0029 - 452ms/epoch - 4ms/step
# Epoch 22/200
# 122/122 - 0s - loss: 0.0011 - val_loss: 0.0027 - 447ms/epoch - 4ms/step
# Epoch 23/200
# 122/122 - 0s - loss: 9.1411e-04 - val_loss: 0.0028 - 433ms/epoch - 4ms/step
# Epoch 24/200
# 122/122 - 0s - loss: 9.1652e-04 - val_loss: 0.0026 - 446ms/epoch - 4ms/step
# Epoch 25/200
# 122/122 - 0s - loss: 8.6399e-04 - val_loss: 0.0026 - 464ms/epoch - 4ms/step
# Epoch 26/200
# 122/122 - 1s - loss: 9.8123e-04 - val_loss: 0.0026 - 540ms/epoch - 4ms/step
# Epoch 27/200
# 122/122 - 0s - loss: 9.5981e-04 - val_loss: 0.0025 - 423ms/epoch - 3ms/step
# Epoch 28/200
# 122/122 - 0s - loss: 9.7115e-04 - val_loss: 0.0026 - 427ms/epoch - 4ms/step
# Epoch 29/200
# 122/122 - 0s - loss: 9.4601e-04 - val_loss: 0.0023 - 454ms/epoch - 4ms/step
# Epoch 30/200
# 122/122 - 0s - loss: 8.9079e-04 - val_loss: 0.0023 - 438ms/epoch - 4ms/step
# Epoch 31/200
# 122/122 - 0s - loss: 9.2234e-04 - val_loss: 0.0024 - 444ms/epoch - 4ms/step
# Epoch 32/200
# 122/122 - 0s - loss: 8.5659e-04 - val_loss: 0.0025 - 437ms/epoch - 4ms/step
# Epoch 33/200
# 122/122 - 0s - loss: 9.3575e-04 - val_loss: 0.0022 - 437ms/epoch - 4ms/step
# Epoch 34/200
# 122/122 - 0s - loss: 7.9890e-04 - val_loss: 0.0022 - 439ms/epoch - 4ms/step
# Epoch 35/200
# 122/122 - 0s - loss: 7.8213e-04 - val_loss: 0.0023 - 433ms/epoch - 4ms/step
# Epoch 36/200
# 122/122 - 0s - loss: 8.3944e-04 - val_loss: 0.0022 - 444ms/epoch - 4ms/step
# Epoch 37/200
# 122/122 - 0s - loss: 7.3027e-04 - val_loss: 0.0022 - 444ms/epoch - 4ms/step
# Epoch 38/200
# 122/122 - 0s - loss: 7.0903e-04 - val_loss: 0.0021 - 452ms/epoch - 4ms/step
# Epoch 39/200
# 122/122 - 0s - loss: 7.9269e-04 - val_loss: 0.0020 - 457ms/epoch - 4ms/step
# Epoch 40/200
# 122/122 - 0s - loss: 6.8746e-04 - val_loss: 0.0020 - 440ms/epoch - 4ms/step
# Epoch 41/200
# 122/122 - 0s - loss: 7.6821e-04 - val_loss: 0.0020 - 444ms/epoch - 4ms/step
# Epoch 42/200
# 122/122 - 0s - loss: 6.9271e-04 - val_loss: 0.0019 - 440ms/epoch - 4ms/step
# Epoch 43/200
# 122/122 - 0s - loss: 6.3101e-04 - val_loss: 0.0019 - 435ms/epoch - 4ms/step
# Epoch 44/200
# 122/122 - 0s - loss: 6.9557e-04 - val_loss: 0.0021 - 442ms/epoch - 4ms/step
# Epoch 45/200
# 122/122 - 0s - loss: 7.8562e-04 - val_loss: 0.0022 - 446ms/epoch - 4ms/step
# Epoch 46/200
# 122/122 - 0s - loss: 7.3981e-04 - val_loss: 0.0021 - 439ms/epoch - 4ms/step
# Epoch 47/200
# 122/122 - 0s - loss: 7.3132e-04 - val_loss: 0.0021 - 435ms/epoch - 4ms/step
# Epoch 48/200
# 122/122 - 0s - loss: 6.7181e-04 - val_loss: 0.0018 - 433ms/epoch - 4ms/step
# Epoch 49/200
# 122/122 - 0s - loss: 7.8145e-04 - val_loss: 0.0020 - 444ms/epoch - 4ms/step
# Epoch 50/200
# 122/122 - 0s - loss: 7.6688e-04 - val_loss: 0.0019 - 437ms/epoch - 4ms/step
# Epoch 51/200
# 122/122 - 0s - loss: 8.1950e-04 - val_loss: 0.0021 - 438ms/epoch - 4ms/step
# Epoch 52/200
# 122/122 - 0s - loss: 7.0007e-04 - val_loss: 0.0019 - 439ms/epoch - 4ms/step
# Epoch 53/200
# 122/122 - 0s - loss: 6.4904e-04 - val_loss: 0.0017 - 460ms/epoch - 4ms/step
# Epoch 54/200
# 122/122 - 0s - loss: 6.1255e-04 - val_loss: 0.0017 - 439ms/epoch - 4ms/step
# Epoch 55/200
# 122/122 - 0s - loss: 5.1684e-04 - val_loss: 0.0016 - 429ms/epoch - 4ms/step
# Epoch 56/200
# 122/122 - 0s - loss: 4.9006e-04 - val_loss: 0.0018 - 458ms/epoch - 4ms/step
# Epoch 57/200
# 122/122 - 0s - loss: 4.8547e-04 - val_loss: 0.0018 - 466ms/epoch - 4ms/step
# Epoch 58/200
# 122/122 - 0s - loss: 5.3104e-04 - val_loss: 0.0017 - 456ms/epoch - 4ms/step
# Epoch 59/200
# 122/122 - 0s - loss: 5.7928e-04 - val_loss: 0.0016 - 451ms/epoch - 4ms/step
# Epoch 60/200
# 122/122 - 0s - loss: 5.8282e-04 - val_loss: 0.0020 - 434ms/epoch - 4ms/step
# Epoch 61/200
# 122/122 - 0s - loss: 5.8185e-04 - val_loss: 0.0017 - 437ms/epoch - 4ms/step
# Epoch 62/200
# 122/122 - 0s - loss: 5.0607e-04 - val_loss: 0.0017 - 446ms/epoch - 4ms/step
# Epoch 63/200
# 122/122 - 0s - loss: 6.1880e-04 - val_loss: 0.0018 - 436ms/epoch - 4ms/step
# Epoch 64/200
# 122/122 - 0s - loss: 5.4666e-04 - val_loss: 0.0016 - 434ms/epoch - 4ms/step
# Epoch 65/200
# 122/122 - 0s - loss: 5.4964e-04 - val_loss: 0.0018 - 448ms/epoch - 4ms/step
# Epoch 66/200
# 122/122 - 0s - loss: 4.9191e-04 - val_loss: 0.0017 - 440ms/epoch - 4ms/step
# Epoch 67/200
# 122/122 - 0s - loss: 5.8178e-04 - val_loss: 0.0016 - 464ms/epoch - 4ms/step
# Epoch 68/200
# 122/122 - 0s - loss: 5.5128e-04 - val_loss: 0.0016 - 437ms/epoch - 4ms/step
# Epoch 69/200
# 122/122 - 0s - loss: 5.9604e-04 - val_loss: 0.0018 - 440ms/epoch - 4ms/step
# Epoch 70/200
# 122/122 - 0s - loss: 5.1325e-04 - val_loss: 0.0016 - 441ms/epoch - 4ms/step
# Epoch 71/200
# 122/122 - 0s - loss: 4.7529e-04 - val_loss: 0.0016 - 438ms/epoch - 4ms/step
# Epoch 72/200
# 122/122 - 0s - loss: 4.9073e-04 - val_loss: 0.0016 - 449ms/epoch - 4ms/step
# Epoch 73/200
# 122/122 - 0s - loss: 4.4931e-04 - val_loss: 0.0015 - 440ms/epoch - 4ms/step
# Epoch 74/200
# 122/122 - 0s - loss: 3.8001e-04 - val_loss: 0.0015 - 441ms/epoch - 4ms/step
# Epoch 75/200
# 122/122 - 0s - loss: 3.5910e-04 - val_loss: 0.0014 - 444ms/epoch - 4ms/step
# Epoch 76/200
# 122/122 - 0s - loss: 4.4148e-04 - val_loss: 0.0017 - 439ms/epoch - 4ms/step
# Epoch 77/200
# 122/122 - 0s - loss: 4.8172e-04 - val_loss: 0.0015 - 448ms/epoch - 4ms/step
# Epoch 78/200
# 122/122 - 0s - loss: 4.3425e-04 - val_loss: 0.0016 - 434ms/epoch - 4ms/step
# Epoch 79/200
# 122/122 - 0s - loss: 4.5091e-04 - val_loss: 0.0017 - 442ms/epoch - 4ms/step
# Epoch 80/200
# 122/122 - 0s - loss: 5.1499e-04 - val_loss: 0.0017 - 436ms/epoch - 4ms/step
# Epoch 81/200
# 122/122 - 0s - loss: 5.2065e-04 - val_loss: 0.0016 - 462ms/epoch - 4ms/step
# Epoch 82/200
# 122/122 - 0s - loss: 4.0313e-04 - val_loss: 0.0016 - 432ms/epoch - 4ms/step
# Epoch 83/200
# 122/122 - 0s - loss: 4.2577e-04 - val_loss: 0.0016 - 440ms/epoch - 4ms/step
# Epoch 84/200
# 122/122 - 0s - loss: 4.3220e-04 - val_loss: 0.0017 - 444ms/epoch - 4ms/step
# Epoch 85/200
# 122/122 - 1s - loss: 3.6312e-04 - val_loss: 0.0014 - 524ms/epoch - 4ms/step
# Epoch 86/200
# 122/122 - 0s - loss: 3.4777e-04 - val_loss: 0.0015 - 499ms/epoch - 4ms/step
# Epoch 87/200
# 122/122 - 0s - loss: 3.4649e-04 - val_loss: 0.0014 - 431ms/epoch - 4ms/step
# Epoch 88/200
# 122/122 - 1s - loss: 3.7299e-04 - val_loss: 0.0015 - 549ms/epoch - 4ms/step
# Epoch 89/200
# 122/122 - 0s - loss: 3.8125e-04 - val_loss: 0.0017 - 431ms/epoch - 4ms/step
# Epoch 90/200
# 122/122 - 0s - loss: 3.4995e-04 - val_loss: 0.0014 - 432ms/epoch - 4ms/step
# Epoch 91/200
# 122/122 - 0s - loss: 3.1362e-04 - val_loss: 0.0015 - 435ms/epoch - 4ms/step
# Epoch 92/200
# 122/122 - 0s - loss: 3.1433e-04 - val_loss: 0.0014 - 444ms/epoch - 4ms/step
# Epoch 93/200
# 122/122 - 0s - loss: 3.6337e-04 - val_loss: 0.0015 - 445ms/epoch - 4ms/step
# Epoch 94/200
# 122/122 - 0s - loss: 3.4173e-04 - val_loss: 0.0015 - 434ms/epoch - 4ms/step
# Epoch 95/200
# 122/122 - 0s - loss: 3.2091e-04 - val_loss: 0.0016 - 459ms/epoch - 4ms/step
# Epoch 96/200
# 122/122 - 0s - loss: 3.0336e-04 - val_loss: 0.0014 - 431ms/epoch - 4ms/step
# Epoch 97/200
# 122/122 - 0s - loss: 3.2443e-04 - val_loss: 0.0015 - 430ms/epoch - 4ms/step
# Epoch 98/200
# 122/122 - 0s - loss: 3.9301e-04 - val_loss: 0.0015 - 450ms/epoch - 4ms/step
# Epoch 99/200
# 122/122 - 0s - loss: 3.3380e-04 - val_loss: 0.0014 - 431ms/epoch - 4ms/step
# Epoch 100/200
# 122/122 - 0s - loss: 3.1241e-04 - val_loss: 0.0014 - 439ms/epoch - 4ms/step
# Epoch 101/200
# 122/122 - 0s - loss: 3.0907e-04 - val_loss: 0.0014 - 449ms/epoch - 4ms/step
# Epoch 102/200
# 122/122 - 0s - loss: 2.9907e-04 - val_loss: 0.0014 - 437ms/epoch - 4ms/step
# Epoch 103/200
# 122/122 - 0s - loss: 2.6714e-04 - val_loss: 0.0014 - 438ms/epoch - 4ms/step
# Epoch 104/200
# 122/122 - 0s - loss: 3.1465e-04 - val_loss: 0.0015 - 435ms/epoch - 4ms/step
# Epoch 105/200
# 122/122 - 0s - loss: 2.8968e-04 - val_loss: 0.0014 - 493ms/epoch - 4ms/step
# Epoch 106/200
# 122/122 - 0s - loss: 2.2805e-04 - val_loss: 0.0014 - 473ms/epoch - 4ms/step
# Epoch 107/200
# 122/122 - 1s - loss: 2.8601e-04 - val_loss: 0.0014 - 603ms/epoch - 5ms/step
# Epoch 108/200
# 122/122 - 0s - loss: 2.6745e-04 - val_loss: 0.0014 - 434ms/epoch - 4ms/step
# Epoch 109/200
# 122/122 - 0s - loss: 2.8603e-04 - val_loss: 0.0014 - 453ms/epoch - 4ms/step
# Epoch 110/200
# 122/122 - 0s - loss: 2.6868e-04 - val_loss: 0.0015 - 442ms/epoch - 4ms/step
# Epoch 111/200
# 122/122 - 0s - loss: 2.6761e-04 - val_loss: 0.0015 - 433ms/epoch - 4ms/step
# Epoch 112/200
# 122/122 - 0s - loss: 2.5170e-04 - val_loss: 0.0014 - 440ms/epoch - 4ms/step
# Epoch 113/200
# 122/122 - 0s - loss: 2.8046e-04 - val_loss: 0.0015 - 435ms/epoch - 4ms/step
# Epoch 114/200
# 122/122 - 0s - loss: 2.8740e-04 - val_loss: 0.0016 - 436ms/epoch - 4ms/step
# Epoch 115/200
# 122/122 - 0s - loss: 3.0042e-04 - val_loss: 0.0017 - 440ms/epoch - 4ms/step
# Epoch 116/200
# 122/122 - 0s - loss: 3.0382e-04 - val_loss: 0.0014 - 437ms/epoch - 4ms/step
# Epoch 117/200
# 122/122 - 0s - loss: 2.5390e-04 - val_loss: 0.0014 - 434ms/epoch - 4ms/step
# Epoch 118/200
# 122/122 - 0s - loss: 2.4019e-04 - val_loss: 0.0015 - 438ms/epoch - 4ms/step
# Epoch 119/200
# 122/122 - 0s - loss: 2.1648e-04 - val_loss: 0.0014 - 438ms/epoch - 4ms/step
# Epoch 120/200
# 122/122 - 0s - loss: 2.0205e-04 - val_loss: 0.0013 - 429ms/epoch - 4ms/step
# Epoch 121/200
# 122/122 - 0s - loss: 2.2870e-04 - val_loss: 0.0013 - 441ms/epoch - 4ms/step
# Epoch 122/200
# 122/122 - 0s - loss: 2.0594e-04 - val_loss: 0.0014 - 431ms/epoch - 4ms/step
# Epoch 123/200
# 122/122 - 0s - loss: 2.0712e-04 - val_loss: 0.0013 - 456ms/epoch - 4ms/step
# Epoch 124/200
# 122/122 - 0s - loss: 2.3760e-04 - val_loss: 0.0014 - 436ms/epoch - 4ms/step
# Epoch 125/200
# 122/122 - 0s - loss: 2.5335e-04 - val_loss: 0.0014 - 437ms/epoch - 4ms/step
# Epoch 126/200
# 122/122 - 0s - loss: 2.4015e-04 - val_loss: 0.0014 - 437ms/epoch - 4ms/step
# Epoch 127/200
# 122/122 - 0s - loss: 1.9484e-04 - val_loss: 0.0014 - 434ms/epoch - 4ms/step
# Epoch 128/200
# 122/122 - 0s - loss: 2.0936e-04 - val_loss: 0.0015 - 438ms/epoch - 4ms/step
# Epoch 129/200
# 122/122 - 0s - loss: 1.9979e-04 - val_loss: 0.0013 - 446ms/epoch - 4ms/step
# Epoch 130/200
# 122/122 - 0s - loss: 2.0042e-04 - val_loss: 0.0013 - 456ms/epoch - 4ms/step
# Epoch 131/200
# 122/122 - 0s - loss: 2.1604e-04 - val_loss: 0.0013 - 438ms/epoch - 4ms/step
# Epoch 132/200
# 122/122 - 0s - loss: 1.8806e-04 - val_loss: 0.0015 - 436ms/epoch - 4ms/step
# Epoch 133/200
# 122/122 - 0s - loss: 2.0797e-04 - val_loss: 0.0013 - 450ms/epoch - 4ms/step
# Epoch 134/200
# 122/122 - 0s - loss: 1.8668e-04 - val_loss: 0.0013 - 433ms/epoch - 4ms/step
# Epoch 135/200
# 122/122 - 0s - loss: 2.4000e-04 - val_loss: 0.0014 - 431ms/epoch - 4ms/step
# Epoch 136/200
# 122/122 - 0s - loss: 2.1085e-04 - val_loss: 0.0014 - 445ms/epoch - 4ms/step
# Epoch 137/200
# 122/122 - 0s - loss: 1.9302e-04 - val_loss: 0.0014 - 435ms/epoch - 4ms/step
# Epoch 138/200
# 122/122 - 0s - loss: 1.7280e-04 - val_loss: 0.0013 - 431ms/epoch - 4ms/step
# Epoch 139/200
# 122/122 - 0s - loss: 2.1541e-04 - val_loss: 0.0014 - 461ms/epoch - 4ms/step
# Epoch 140/200
# 122/122 - 0s - loss: 2.0472e-04 - val_loss: 0.0015 - 437ms/epoch - 4ms/step
# Epoch 141/200
# 122/122 - 0s - loss: 1.9178e-04 - val_loss: 0.0014 - 439ms/epoch - 4ms/step
# Epoch 142/200
# 122/122 - 0s - loss: 1.7400e-04 - val_loss: 0.0012 - 433ms/epoch - 4ms/step
# Epoch 143/200
# 122/122 - 0s - loss: 2.0099e-04 - val_loss: 0.0014 - 437ms/epoch - 4ms/step
# Epoch 144/200
# 122/122 - 0s - loss: 2.3327e-04 - val_loss: 0.0015 - 490ms/epoch - 4ms/step
# Epoch 145/200
# 122/122 - 0s - loss: 2.1530e-04 - val_loss: 0.0014 - 496ms/epoch - 4ms/step
# Epoch 146/200
# 122/122 - 0s - loss: 1.9896e-04 - val_loss: 0.0014 - 430ms/epoch - 4ms/step
# Epoch 147/200
# 122/122 - 0s - loss: 1.8295e-04 - val_loss: 0.0013 - 427ms/epoch - 3ms/step
# Epoch 148/200
# 122/122 - 0s - loss: 1.6025e-04 - val_loss: 0.0014 - 445ms/epoch - 4ms/step
# Epoch 149/200
# 122/122 - 0s - loss: 1.5507e-04 - val_loss: 0.0013 - 440ms/epoch - 4ms/step
# Epoch 150/200
# 122/122 - 0s - loss: 1.4457e-04 - val_loss: 0.0013 - 439ms/epoch - 4ms/step
# Epoch 151/200
# 122/122 - 0s - loss: 1.3699e-04 - val_loss: 0.0014 - 433ms/epoch - 4ms/step
# Epoch 152/200
# 122/122 - 0s - loss: 1.7592e-04 - val_loss: 0.0016 - 445ms/epoch - 4ms/step
# Epoch 153/200
# 122/122 - 0s - loss: 2.0545e-04 - val_loss: 0.0014 - 455ms/epoch - 4ms/step
# Epoch 154/200
# 122/122 - 0s - loss: 2.1448e-04 - val_loss: 0.0013 - 434ms/epoch - 4ms/step
# Epoch 155/200
# 122/122 - 0s - loss: 1.9920e-04 - val_loss: 0.0015 - 441ms/epoch - 4ms/step
# Epoch 156/200
# 122/122 - 0s - loss: 1.9050e-04 - val_loss: 0.0013 - 441ms/epoch - 4ms/step
# Epoch 157/200
# 122/122 - 0s - loss: 1.8143e-04 - val_loss: 0.0014 - 435ms/epoch - 4ms/step
# Epoch 158/200
# 122/122 - 0s - loss: 1.9525e-04 - val_loss: 0.0013 - 443ms/epoch - 4ms/step
# Epoch 159/200
# 122/122 - 0s - loss: 1.6091e-04 - val_loss: 0.0013 - 437ms/epoch - 4ms/step
# Epoch 160/200
# 122/122 - 0s - loss: 1.5531e-04 - val_loss: 0.0015 - 449ms/epoch - 4ms/step
# Epoch 161/200
# 122/122 - 0s - loss: 1.7045e-04 - val_loss: 0.0013 - 434ms/epoch - 4ms/step
# Epoch 162/200
# 122/122 - 0s - loss: 1.6975e-04 - val_loss: 0.0014 - 440ms/epoch - 4ms/step
# Epoch 163/200
# 122/122 - 0s - loss: 1.5873e-04 - val_loss: 0.0014 - 432ms/epoch - 4ms/step
# Epoch 164/200
# 122/122 - 0s - loss: 1.9536e-04 - val_loss: 0.0014 - 438ms/epoch - 4ms/step
# Epoch 165/200
# 122/122 - 0s - loss: 1.9868e-04 - val_loss: 0.0013 - 440ms/epoch - 4ms/step
# Epoch 166/200
# 122/122 - 0s - loss: 1.9259e-04 - val_loss: 0.0013 - 431ms/epoch - 4ms/step
# Epoch 167/200
# 122/122 - 0s - loss: 1.6241e-04 - val_loss: 0.0013 - 455ms/epoch - 4ms/step
# Epoch 168/200
# 122/122 - 0s - loss: 1.6524e-04 - val_loss: 0.0013 - 430ms/epoch - 4ms/step
# Epoch 169/200
# 122/122 - 0s - loss: 1.6314e-04 - val_loss: 0.0012 - 485ms/epoch - 4ms/step
# Epoch 170/200
# 122/122 - 1s - loss: 1.5546e-04 - val_loss: 0.0012 - 601ms/epoch - 5ms/step
# Epoch 171/200
# 122/122 - 0s - loss: 1.3558e-04 - val_loss: 0.0013 - 490ms/epoch - 4ms/step
# Epoch 172/200
# 122/122 - 0s - loss: 1.7030e-04 - val_loss: 0.0013 - 430ms/epoch - 4ms/step
# Epoch 173/200
# 122/122 - 0s - loss: 1.6072e-04 - val_loss: 0.0014 - 452ms/epoch - 4ms/step
# Epoch 174/200
# 122/122 - 0s - loss: 1.5265e-04 - val_loss: 0.0013 - 442ms/epoch - 4ms/step
# Epoch 175/200
# 122/122 - 0s - loss: 1.1502e-04 - val_loss: 0.0013 - 435ms/epoch - 4ms/step
# Epoch 176/200
# 122/122 - 0s - loss: 1.2459e-04 - val_loss: 0.0013 - 443ms/epoch - 4ms/step
# Epoch 177/200
# 122/122 - 1s - loss: 1.1807e-04 - val_loss: 0.0013 - 597ms/epoch - 5ms/step
# Epoch 178/200
# 122/122 - 0s - loss: 1.6194e-04 - val_loss: 0.0013 - 428ms/epoch - 4ms/step
# Epoch 179/200
# 122/122 - 0s - loss: 2.7824e-04 - val_loss: 0.0016 - 471ms/epoch - 4ms/step
# Epoch 180/200
# 122/122 - 1s - loss: 2.5773e-04 - val_loss: 0.0013 - 533ms/epoch - 4ms/step
# Epoch 181/200
# 122/122 - 0s - loss: 2.2666e-04 - val_loss: 0.0013 - 492ms/epoch - 4ms/step
# Epoch 182/200
# 122/122 - 0s - loss: 1.9600e-04 - val_loss: 0.0013 - 484ms/epoch - 4ms/step
# Epoch 183/200
# 122/122 - 0s - loss: 1.5941e-04 - val_loss: 0.0013 - 476ms/epoch - 4ms/step
# Epoch 184/200
# 122/122 - 0s - loss: 1.2842e-04 - val_loss: 0.0013 - 475ms/epoch - 4ms/step
# Epoch 185/200
# 122/122 - 0s - loss: 1.2445e-04 - val_loss: 0.0013 - 488ms/epoch - 4ms/step
# Epoch 186/200
# 122/122 - 1s - loss: 1.1236e-04 - val_loss: 0.0012 - 539ms/epoch - 4ms/step
# Epoch 187/200
# 122/122 - 0s - loss: 1.2143e-04 - val_loss: 0.0013 - 491ms/epoch - 4ms/step
# Epoch 188/200
# 122/122 - 0s - loss: 1.2911e-04 - val_loss: 0.0014 - 482ms/epoch - 4ms/step
# Epoch 189/200
# 122/122 - 0s - loss: 1.3751e-04 - val_loss: 0.0013 - 481ms/epoch - 4ms/step
# Epoch 190/200
# 122/122 - 0s - loss: 1.4469e-04 - val_loss: 0.0013 - 482ms/epoch - 4ms/step
# Epoch 191/200
# 122/122 - 1s - loss: 1.4425e-04 - val_loss: 0.0013 - 788ms/epoch - 6ms/step
# Epoch 192/200
# 122/122 - 1s - loss: 1.3276e-04 - val_loss: 0.0013 - 574ms/epoch - 5ms/step
# Epoch 193/200
# 122/122 - 0s - loss: 1.5758e-04 - val_loss: 0.0013 - 484ms/epoch - 4ms/step
# Epoch 194/200
# 122/122 - 1s - loss: 1.3890e-04 - val_loss: 0.0014 - 507ms/epoch - 4ms/step
# Epoch 195/200
# 122/122 - 1s - loss: 1.9849e-04 - val_loss: 0.0014 - 506ms/epoch - 4ms/step
# Epoch 196/200
# 122/122 - 1s - loss: 1.9213e-04 - val_loss: 0.0013 - 507ms/epoch - 4ms/step
# Epoch 197/200
# 122/122 - 1s - loss: 2.1460e-04 - val_loss: 0.0013 - 723ms/epoch - 6ms/step
# Epoch 198/200
# 122/122 - 1s - loss: 1.4474e-04 - val_loss: 0.0013 - 643ms/epoch - 5ms/step
# Epoch 199/200
# 122/122 - 1s - loss: 1.1870e-04 - val_loss: 0.0014 - 631ms/epoch - 5ms/step
# Epoch 200/200
# 122/122 - 1s - loss: 1.1732e-04 - val_loss: 0.0013 - 673ms/epoch - 6ms/step

# %%
# Extraia os valores de loss do histórico
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Non Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Extraia os valores de loss do histórico
train_loss = history_aug.history['loss']
val_loss = history_aug.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_hat = model.predict(X_test)
print(y_hat.shape)

y_hat_aug = model_aug.predict(X_test)
print(y_hat_aug.shape)
# Out:
# 100/100 [==============================] - 0s 996us/step
# (3200, 3)
# 100/100 [==============================] - 0s 895us/step
# (3200, 3)

# %%
PredDF = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat,columns=['yh1','yh2','yh3'])],axis=1)

PredDF_aug = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat_aug,columns=['yh1','yh2','yh3'])],axis=1)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Correlation

# %%
PredDF.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.896082 -0.054003 -0.570576
# y2 -0.080624  0.907174  0.139730
# y3 -0.544688  0.073895  0.932412

# %%
PredDF_aug.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.583444 -0.052070 -0.350453
# y2 -0.116618  0.532846  0.061933
# y3 -0.403443  0.041997  0.588180

# %% [markdown]
# ## R2

# %%
print('Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF['y1'], PredDF['yh1']))
print('')
print('')
# plt.scatter(PredDF['y1'], PredDF['yh1'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF['y2'], PredDF['yh2']))
print('')
print('')
# plt.scatter(PredDF['y2'], PredDF['yh2'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF['y3'], PredDF['yh3']))
print('')
print('')
# plt.scatter(PredDF['y3'], PredDF['yh3'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()


print('PredDF_aug: Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF_aug['y1'], PredDF_aug['yh1']))
print('')
print('')
# plt.scatter(PredDF_aug['y1'], PredDF_aug['yh1'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF_aug['y2'], PredDF_aug['yh2']))
print('')
print('')
# plt.scatter(PredDF_aug['y2'], PredDF_aug['yh2'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF_aug['y3'], PredDF_aug['yh3']))
# print('')
# print('')
# plt.scatter(PredDF_aug['y3'], PredDF_aug['yh3'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()
# Out:
# Resultados Holdout Enn
#
# 0.8017287230583297
#
#
# Resultados Holdout Etn
#
# 0.8212689482755444
#
#
# Resultados Holdout Ett
#
# 0.8597969811078832
#
#
# PredDF_aug: Resultados Holdout Enn
#
# -0.23891047077325256
#
#
# PredDF_aug: Resultados Holdout Etn
#
# -0.3080884621454125
#
#
# PredDF_aug: Resultados Holdout Ett
#
# -0.20747505975003278

# %%
ind_tr1= y_test.Enn
ind_tr2= y_test.Etn
ind_tr3= y_test.Ett
y_test.loc[ind_tr1.index,'Enn'] = y_hat[:,0]
y_test.loc[ind_tr2.index,'Etn'] = y_hat[:,1]
y_test.loc[ind_tr3.index,'Ett'] = y_hat[:,2]

ind_tr1_aug= y_test.Enn
ind_tr2_aug= y_test.Etn
ind_tr3_aug= y_test.Ett
y_test.loc[ind_tr1_aug.index,'Enn'] = y_hat_aug[:,0]
y_test.loc[ind_tr2_aug.index,'Etn'] = y_hat_aug[:,1]
y_test.loc[ind_tr3_aug.index,'Ett'] = y_hat_aug[:,2]

# %%
ind_tes1= y_test.Enn
ind_tes2= y_test.Etn
ind_tes3= y_test.Ett
df.loc[ind_tes1.index,'Enn'] = y_test.Enn
df.loc[ind_tes2.index,'Etn'] = y_test.Etn
df.loc[ind_tes3.index,'Ett'] = y_test.Ett

df_aug = df
ind_tes1_aug= y_test.Enn
ind_tes2_aug= y_test.Etn
ind_tes3_aug= y_test.Ett
df_aug.loc[ind_tes1_aug.index,'Enn'] = y_test.Enn
df_aug.loc[ind_tes2_aug.index,'Etn'] = y_test.Etn
df_aug.loc[ind_tes3_aug.index,'Ett'] = y_test.Ett

# %%
display(df[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
display(df_aug[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df.iloc[a,4]
    j=df.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df.iloc[a,1]
    df2.iloc[ind,2]=df.iloc[a,2]
    df2.iloc[ind,3]=df.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100

Enn_MLP_35=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35.mat', {'Enn_MLP_35': Enn_MLP_35}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35.mat', {'Etn_MLP_35': Etn_MLP_35})
spio.savemat('Ett_MLP_35.mat', {'Ett_MLP_35': Ett_MLP_35})
# Out:
# n1= 199 m1= 210
# ncases= 41790

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df_aug.iloc[a,4]
    j=df_aug.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df_aug.iloc[a,1]
    df2.iloc[ind,2]=df_aug.iloc[a,2]
    df2.iloc[ind,3]=df_aug.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100
    
Enn_MLP_35_aug=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35_aug=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35_aug=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35_aug.mat', {'Enn_MLP_35_aug': Enn_MLP_35_aug}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35_aug.mat', {'Etn_MLP_35_aug': Etn_MLP_35_aug})
spio.savemat('Ett_MLP_35_aug.mat', {'Ett_MLP_35_aug': Ett_MLP_35_aug})
# Out:
# n1= 199 m1= 210
# ncases= 41790
