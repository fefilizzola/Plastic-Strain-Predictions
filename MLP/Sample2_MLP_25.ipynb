# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.io as sio
from scipy import io as spio
from tqdm import tqdm
import cv2
from sklearn import metrics


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Split Data

# %%
def tic():
    #Homemade version of matlab tic and toc functions
    import time
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    import time
    if 'startTime_for_tictoc' in globals():
        print ('\nElapsed time is ')
        print (str(time.time() - startTime_for_tictoc))
        print('seconds.\n')
    else:
        print ('\nToc: start time not set\n')

# %%
data1= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_1/RDM_Sample_1.mat')
angles1= data1['RDM']['angles'][0][0]
Enn1= data1['RDM']['Strains'][0][0][0][0][5]
Etn1= data1['RDM']['Strains'][0][0][0][0][4]
Ett1= data1['RDM']['Strains'][0][0][0][0][3]
CM1= data1['RDM']['CM'][0][0]

data2= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles2= data2['RDM']['angles'][0][0]
Enn2= data2['RDM']['Strains'][0][0][0][0][5]
Etn2= data2['RDM']['Strains'][0][0][0][0][4]
Ett2= data2['RDM']['Strains'][0][0][0][0][3]
CM2= data2['RDM']['CM'][0][0]

data3= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles3= data3['RDM']['angles'][0][0]
Enn3= data3['RDM']['Strains'][0][0][0][0][5]
Etn3= data3['RDM']['Strains'][0][0][0][0][4]
Ett3= data3['RDM']['Strains'][0][0][0][0][3]
CM3= data3['RDM']['CM'][0][0]

# %%
print(angles1.shape)
print(angles2.shape)
# Out:
# (199, 210)
# (405, 419)

# %%
data= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles= data['RDM']['angles'][0][0]
Enn= data['RDM']['Strains'][0][0][0][0][5]
Etn= data['RDM']['Strains'][0][0][0][0][4]
Ett= data['RDM']['Strains'][0][0][0][0][3]
CM= data['RDM']['CM'][0][0]

indPred= CM==1
wndSize= 25
n,m = angles.shape

print('n=', n , 'm=', m )

stride= int((wndSize-1)/2)
ncases= sum(sum(CM[stride:n-stride,stride:m-stride]==1))

Y= np.zeros((ncases,5))
X0= np.zeros((ncases, wndSize**2))
X1= np.zeros((ncases,1))

cnt=0
for i in range(0+stride,n-stride):
  for j in range(0+stride,m-stride):
    if CM[i,j] == 1:
      indX= range(i-stride,i+stride+1)
      indY= range(j-stride,j+stride+1)
      Maux = angles[indX, :][:, indY]
      row= [Enn[i,j], Etn[i,j], Ett[i,j],i,j]
      Y[cnt,:]= row
      X0[cnt,:]= Maux.flatten()
      X1[cnt,:]= angles[i,j]
      cnt= cnt+1
      prog=cnt/ncases*100
# Out:
# n= 405 m= 419

# %%
Y1=Y[:,1]

df = pd.DataFrame({'Angles': X1.flatten()}) 
df['Enn'] = Y[:,0].flatten()
df['Etn'] = Y[:,1].flatten()
df['Ett'] = Y[:,2].flatten()
df['i'] = Y[:,3].flatten()
df['j'] = Y[:,4].flatten()

# %%
df
# Out:
#          Angles       Enn       Etn       Ett      i      j
# 0     -1.372718  0.000651  0.006652  0.003654   12.0   48.0
# 1     -1.372718  0.000262  0.007367  0.004803   12.0   49.0
# 2     -1.372718  0.000156  0.006271  0.006054   12.0   50.0
# 3     -1.372718  0.002638  0.004774  0.005317   12.0   51.0
# 4     -1.372718  0.005725  0.005411  0.003470   12.0   52.0
# ...         ...       ...       ...       ...    ...    ...
# 18700 -1.296966 -0.011336  0.008438  0.004791  392.0  402.0
# 18701 -1.297122 -0.009491  0.005365  0.007930  392.0  403.0
# 18702  1.851445 -0.004617  0.004245  0.010863  392.0  404.0
# 18703  1.854917 -0.000852  0.006637  0.011325  392.0  405.0
# 18704  1.854917  0.000988  0.008350  0.010173  392.0  406.0
#
# [18705 rows x 6 columns]

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ## Added noise

# %%
import numpy as np

def augment_data(angles_arr, enn_arr, etn_arr, ett_arr, noise_stddev, noise_prob):
    angle_aug = []
    enn_aug = []
    etn_aug = []
    ett_aug = []
    for angle, enn, etn, ett in zip(angles_arr, enn_arr, etn_arr, ett_arr):
        noise = np.random.normal(0, noise_stddev)
        augmented_angle_ = angle + noise
        augmented_enn_ = enn + noise
        augmented_etn_ = etn + noise
        augmented_ett_ = ett + noise
        
        angle_aug.append(angle)
        enn_aug.append(enn)
        etn_aug.append(etn)
        ett_aug.append(ett)
        
        if np.random.rand() < noise_prob:
            angle_aug.append(augmented_angle_)
            enn_aug.append(augmented_enn_)
            etn_aug.append(augmented_etn_)
            ett_aug.append(augmented_ett_)

    return np.array(angle_aug), np.array(enn_aug), np.array(etn_aug), np.array(ett_aug)

X = X0
y = df.iloc[:,1:4]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Load your input and target data
angle_data = X_train
enn_data = y_train['Enn']
etn_data = y_train['Etn']
ett_data = y_train['Ett']

# Generate augmented input and target data
augmented_angle_data, augmented_enn_data, augmented_etn_data, augmented_ett_data = augment_data(angle_data, enn_data, etn_data, ett_data, 0.2, 0.3)

X_train_aug = augmented_angle_data
y_train_aug = pd.DataFrame(list(zip(augmented_enn_data,augmented_etn_data,augmented_ett_data)),columns=['Enn','Etn','Ett'])

print(X_train.shape, X_train_aug.shape)
print(y_train.shape, y_train_aug.shape)
# Out:
# (13093, 625) (17037, 625)
# (13093, 3) (17037, 3)

# %% [markdown]
# # Model

# %%
# Scaling not augmented data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
print(X_train.shape)

X_test = scaler.transform(X_test)
print(X_test.shape)

# Scaling augmented data
scaler_aug = StandardScaler()
X_train_aug = scaler_aug.fit_transform(X_train_aug)
print(X_train_aug.shape)

X_test_aug = scaler_aug.transform(X_train_aug)
# Out:
# (13093, 625)
# (5612, 625)
# (17037, 625)

# %%
# Import necessary libraries
from sklearn.pipeline import Pipeline
from tensorflow import keras
import numpy as np


model = keras.Sequential([
    keras.layers.Flatten(input_shape=(625,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3)
])

model_aug = keras.Sequential([
    keras.layers.Flatten(input_shape=(625,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3)  
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
model_aug.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
batch_ = 64
epochs_ = 200
history = model.fit(X_train, y_train, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 2023-09-13 18:12:03.565635: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 164/164 - 1s - loss: 0.0228 - val_loss: 0.0017 - 1s/epoch - 6ms/step
# Epoch 2/200
# 164/164 - 1s - loss: 9.6895e-04 - val_loss: 7.9085e-04 - 686ms/epoch - 4ms/step
# Epoch 3/200
# 164/164 - 1s - loss: 4.9155e-04 - val_loss: 5.5381e-04 - 649ms/epoch - 4ms/step
# Epoch 4/200
# 164/164 - 1s - loss: 3.2177e-04 - val_loss: 4.3976e-04 - 761ms/epoch - 5ms/step
# Epoch 5/200
# 164/164 - 1s - loss: 2.4181e-04 - val_loss: 3.7316e-04 - 621ms/epoch - 4ms/step
# Epoch 6/200
# 164/164 - 1s - loss: 1.9364e-04 - val_loss: 3.3550e-04 - 798ms/epoch - 5ms/step
# Epoch 7/200
# 164/164 - 1s - loss: 1.6379e-04 - val_loss: 3.0691e-04 - 686ms/epoch - 4ms/step
# Epoch 8/200
# 164/164 - 1s - loss: 1.4271e-04 - val_loss: 2.8228e-04 - 645ms/epoch - 4ms/step
# Epoch 9/200
# 164/164 - 1s - loss: 1.2629e-04 - val_loss: 2.6346e-04 - 712ms/epoch - 4ms/step
# Epoch 10/200
# 164/164 - 1s - loss: 1.1605e-04 - val_loss: 2.4378e-04 - 637ms/epoch - 4ms/step
# Epoch 11/200
# 164/164 - 1s - loss: 1.0640e-04 - val_loss: 2.3738e-04 - 622ms/epoch - 4ms/step
# Epoch 12/200
# 164/164 - 1s - loss: 9.7947e-05 - val_loss: 2.2978e-04 - 710ms/epoch - 4ms/step
# Epoch 13/200
# 164/164 - 1s - loss: 9.2507e-05 - val_loss: 2.2407e-04 - 646ms/epoch - 4ms/step
# Epoch 14/200
# 164/164 - 1s - loss: 8.7344e-05 - val_loss: 2.1004e-04 - 694ms/epoch - 4ms/step
# Epoch 15/200
# 164/164 - 1s - loss: 8.2389e-05 - val_loss: 2.0749e-04 - 778ms/epoch - 5ms/step
# Epoch 16/200
# 164/164 - 1s - loss: 8.2551e-05 - val_loss: 2.2543e-04 - 629ms/epoch - 4ms/step
# Epoch 17/200
# 164/164 - 1s - loss: 7.6311e-05 - val_loss: 2.0100e-04 - 737ms/epoch - 4ms/step
# Epoch 18/200
# 164/164 - 1s - loss: 7.5848e-05 - val_loss: 1.8591e-04 - 777ms/epoch - 5ms/step
# Epoch 19/200
# 164/164 - 1s - loss: 7.1561e-05 - val_loss: 1.8477e-04 - 709ms/epoch - 4ms/step
# Epoch 20/200
# 164/164 - 1s - loss: 6.9902e-05 - val_loss: 1.8131e-04 - 756ms/epoch - 5ms/step
# Epoch 21/200
# 164/164 - 1s - loss: 6.7183e-05 - val_loss: 1.7033e-04 - 822ms/epoch - 5ms/step
# Epoch 22/200
# 164/164 - 1s - loss: 6.6441e-05 - val_loss: 1.6315e-04 - 714ms/epoch - 4ms/step
# Epoch 23/200
# 164/164 - 1s - loss: 6.4452e-05 - val_loss: 1.6377e-04 - 938ms/epoch - 6ms/step
# Epoch 24/200
# 164/164 - 1s - loss: 6.1289e-05 - val_loss: 1.6451e-04 - 691ms/epoch - 4ms/step
# Epoch 25/200
# 164/164 - 1s - loss: 5.8945e-05 - val_loss: 1.5428e-04 - 644ms/epoch - 4ms/step
# Epoch 26/200
# 164/164 - 1s - loss: 6.1788e-05 - val_loss: 1.5027e-04 - 612ms/epoch - 4ms/step
# Epoch 27/200
# 164/164 - 1s - loss: 5.7403e-05 - val_loss: 1.8291e-04 - 900ms/epoch - 5ms/step
# Epoch 28/200
# 164/164 - 1s - loss: 5.7803e-05 - val_loss: 1.4706e-04 - 631ms/epoch - 4ms/step
# Epoch 29/200
# 164/164 - 1s - loss: 5.7985e-05 - val_loss: 1.3372e-04 - 635ms/epoch - 4ms/step
# Epoch 30/200
# 164/164 - 1s - loss: 5.3991e-05 - val_loss: 1.3603e-04 - 643ms/epoch - 4ms/step
# Epoch 31/200
# 164/164 - 1s - loss: 5.2789e-05 - val_loss: 1.3422e-04 - 609ms/epoch - 4ms/step
# Epoch 32/200
# 164/164 - 1s - loss: 5.2373e-05 - val_loss: 1.2448e-04 - 733ms/epoch - 4ms/step
# Epoch 33/200
# 164/164 - 1s - loss: 5.1617e-05 - val_loss: 1.2248e-04 - 619ms/epoch - 4ms/step
# Epoch 34/200
# 164/164 - 1s - loss: 5.2536e-05 - val_loss: 1.2542e-04 - 639ms/epoch - 4ms/step
# Epoch 35/200
# 164/164 - 1s - loss: 4.7362e-05 - val_loss: 1.1823e-04 - 598ms/epoch - 4ms/step
# Epoch 36/200
# 164/164 - 1s - loss: 4.6451e-05 - val_loss: 1.1879e-04 - 606ms/epoch - 4ms/step
# Epoch 37/200
# 164/164 - 1s - loss: 4.6616e-05 - val_loss: 1.0980e-04 - 607ms/epoch - 4ms/step
# Epoch 38/200
# 164/164 - 1s - loss: 4.3839e-05 - val_loss: 1.0953e-04 - 719ms/epoch - 4ms/step
# Epoch 39/200
# 164/164 - 1s - loss: 3.9911e-05 - val_loss: 1.1254e-04 - 670ms/epoch - 4ms/step
# Epoch 40/200
# 164/164 - 1s - loss: 3.8412e-05 - val_loss: 1.1063e-04 - 646ms/epoch - 4ms/step
# Epoch 41/200
# 164/164 - 1s - loss: 3.9196e-05 - val_loss: 1.0444e-04 - 752ms/epoch - 5ms/step
# Epoch 42/200
# 164/164 - 1s - loss: 3.6642e-05 - val_loss: 1.0805e-04 - 624ms/epoch - 4ms/step
# Epoch 43/200
# 164/164 - 1s - loss: 3.6405e-05 - val_loss: 9.8193e-05 - 639ms/epoch - 4ms/step
# Epoch 44/200
# 164/164 - 1s - loss: 3.6550e-05 - val_loss: 9.7551e-05 - 650ms/epoch - 4ms/step
# Epoch 45/200
# 164/164 - 1s - loss: 3.4852e-05 - val_loss: 9.7509e-05 - 600ms/epoch - 4ms/step
# Epoch 46/200
# 164/164 - 1s - loss: 3.2739e-05 - val_loss: 1.0163e-04 - 584ms/epoch - 4ms/step
# Epoch 47/200
# 164/164 - 1s - loss: 3.2971e-05 - val_loss: 9.6350e-05 - 671ms/epoch - 4ms/step
# Epoch 48/200
# 164/164 - 1s - loss: 3.4698e-05 - val_loss: 1.0149e-04 - 616ms/epoch - 4ms/step
# Epoch 49/200
# 164/164 - 1s - loss: 3.7871e-05 - val_loss: 9.1748e-05 - 604ms/epoch - 4ms/step
# Epoch 50/200
# 164/164 - 1s - loss: 3.3824e-05 - val_loss: 9.4524e-05 - 642ms/epoch - 4ms/step
# Epoch 51/200
# 164/164 - 1s - loss: 3.3479e-05 - val_loss: 9.2395e-05 - 617ms/epoch - 4ms/step
# Epoch 52/200
# 164/164 - 1s - loss: 3.4727e-05 - val_loss: 8.4733e-05 - 660ms/epoch - 4ms/step
# Epoch 53/200
# 164/164 - 1s - loss: 3.2898e-05 - val_loss: 8.8101e-05 - 607ms/epoch - 4ms/step
# Epoch 54/200
# 164/164 - 1s - loss: 3.0422e-05 - val_loss: 9.6010e-05 - 677ms/epoch - 4ms/step
# Epoch 55/200
# 164/164 - 1s - loss: 2.9801e-05 - val_loss: 8.8112e-05 - 637ms/epoch - 4ms/step
# Epoch 56/200
# 164/164 - 1s - loss: 2.9446e-05 - val_loss: 9.5243e-05 - 621ms/epoch - 4ms/step
# Epoch 57/200
# 164/164 - 1s - loss: 3.0384e-05 - val_loss: 8.6068e-05 - 688ms/epoch - 4ms/step
# Epoch 58/200
# 164/164 - 1s - loss: 3.0673e-05 - val_loss: 9.0234e-05 - 664ms/epoch - 4ms/step
# Epoch 59/200
# 164/164 - 1s - loss: 3.5045e-05 - val_loss: 8.2388e-05 - 655ms/epoch - 4ms/step
# Epoch 60/200
# 164/164 - 1s - loss: 3.4430e-05 - val_loss: 8.7862e-05 - 644ms/epoch - 4ms/step
# Epoch 61/200
# 164/164 - 1s - loss: 3.8733e-05 - val_loss: 8.0631e-05 - 697ms/epoch - 4ms/step
# Epoch 62/200
# 164/164 - 1s - loss: 3.3607e-05 - val_loss: 7.9271e-05 - 673ms/epoch - 4ms/step
# Epoch 63/200
# 164/164 - 1s - loss: 3.0877e-05 - val_loss: 7.5816e-05 - 902ms/epoch - 6ms/step
# Epoch 64/200
# 164/164 - 1s - loss: 2.9333e-05 - val_loss: 7.7977e-05 - 611ms/epoch - 4ms/step
# Epoch 65/200
# 164/164 - 1s - loss: 2.7322e-05 - val_loss: 7.2947e-05 - 720ms/epoch - 4ms/step
# Epoch 66/200
# 164/164 - 1s - loss: 2.5515e-05 - val_loss: 7.8841e-05 - 719ms/epoch - 4ms/step
# Epoch 67/200
# 164/164 - 1s - loss: 2.9329e-05 - val_loss: 7.6092e-05 - 646ms/epoch - 4ms/step
# Epoch 68/200
# 164/164 - 1s - loss: 2.8968e-05 - val_loss: 7.4390e-05 - 621ms/epoch - 4ms/step
# Epoch 69/200
# 164/164 - 1s - loss: 2.9087e-05 - val_loss: 8.0361e-05 - 591ms/epoch - 4ms/step
# Epoch 70/200
# 164/164 - 1s - loss: 2.8521e-05 - val_loss: 7.7075e-05 - 616ms/epoch - 4ms/step
# Epoch 71/200
# 164/164 - 1s - loss: 2.8221e-05 - val_loss: 7.2566e-05 - 579ms/epoch - 4ms/step
# Epoch 72/200
# 164/164 - 1s - loss: 2.8726e-05 - val_loss: 7.6169e-05 - 647ms/epoch - 4ms/step
# Epoch 73/200
# 164/164 - 1s - loss: 5.8108e-05 - val_loss: 9.5073e-05 - 582ms/epoch - 4ms/step
# Epoch 74/200
# 164/164 - 1s - loss: 6.3032e-05 - val_loss: 7.8961e-05 - 589ms/epoch - 4ms/step
# Epoch 75/200
# 164/164 - 1s - loss: 4.3531e-05 - val_loss: 7.7763e-05 - 591ms/epoch - 4ms/step
# Epoch 76/200
# 164/164 - 1s - loss: 3.5536e-05 - val_loss: 7.1626e-05 - 586ms/epoch - 4ms/step
# Epoch 77/200
# 164/164 - 1s - loss: 3.3936e-05 - val_loss: 6.8624e-05 - 616ms/epoch - 4ms/step
# Epoch 78/200
# 164/164 - 1s - loss: 2.8486e-05 - val_loss: 6.7394e-05 - 578ms/epoch - 4ms/step
# Epoch 79/200
# 164/164 - 1s - loss: 3.2043e-05 - val_loss: 7.7014e-05 - 598ms/epoch - 4ms/step
# Epoch 80/200
# 164/164 - 1s - loss: 2.6237e-05 - val_loss: 7.4169e-05 - 580ms/epoch - 4ms/step
# Epoch 81/200
# 164/164 - 1s - loss: 2.5699e-05 - val_loss: 6.7034e-05 - 598ms/epoch - 4ms/step
# Epoch 82/200
# 164/164 - 1s - loss: 2.5353e-05 - val_loss: 6.5294e-05 - 589ms/epoch - 4ms/step
# Epoch 83/200
# 164/164 - 1s - loss: 2.1026e-05 - val_loss: 6.2928e-05 - 592ms/epoch - 4ms/step
# Epoch 84/200
# 164/164 - 1s - loss: 2.0191e-05 - val_loss: 6.6214e-05 - 687ms/epoch - 4ms/step
# Epoch 85/200
# 164/164 - 1s - loss: 2.2621e-05 - val_loss: 6.6159e-05 - 774ms/epoch - 5ms/step
# Epoch 86/200
# 164/164 - 1s - loss: 3.8990e-05 - val_loss: 7.4200e-05 - 647ms/epoch - 4ms/step
# Epoch 87/200
# 164/164 - 1s - loss: 3.1405e-05 - val_loss: 6.2805e-05 - 602ms/epoch - 4ms/step
# Epoch 88/200
# 164/164 - 1s - loss: 2.2609e-05 - val_loss: 5.9357e-05 - 685ms/epoch - 4ms/step
# Epoch 89/200
# 164/164 - 1s - loss: 2.3781e-05 - val_loss: 6.4709e-05 - 586ms/epoch - 4ms/step
# Epoch 90/200
# 164/164 - 1s - loss: 2.0589e-05 - val_loss: 6.2627e-05 - 576ms/epoch - 4ms/step
# Epoch 91/200
# 164/164 - 1s - loss: 1.8584e-05 - val_loss: 6.2018e-05 - 595ms/epoch - 4ms/step
# Epoch 92/200
# 164/164 - 1s - loss: 1.6479e-05 - val_loss: 6.4091e-05 - 588ms/epoch - 4ms/step
# Epoch 93/200
# 164/164 - 1s - loss: 1.8021e-05 - val_loss: 6.5923e-05 - 600ms/epoch - 4ms/step
# Epoch 94/200
# 164/164 - 1s - loss: 1.6750e-05 - val_loss: 6.2669e-05 - 589ms/epoch - 4ms/step
# Epoch 95/200
# 164/164 - 1s - loss: 1.4908e-05 - val_loss: 5.9950e-05 - 582ms/epoch - 4ms/step
# Epoch 96/200
# 164/164 - 1s - loss: 1.4363e-05 - val_loss: 5.8846e-05 - 594ms/epoch - 4ms/step
# Epoch 97/200
# 164/164 - 1s - loss: 1.5147e-05 - val_loss: 5.9164e-05 - 574ms/epoch - 3ms/step
# Epoch 98/200
# 164/164 - 1s - loss: 2.0419e-05 - val_loss: 6.0128e-05 - 589ms/epoch - 4ms/step
# Epoch 99/200
# 164/164 - 1s - loss: 1.6706e-05 - val_loss: 5.8572e-05 - 661ms/epoch - 4ms/step
# Epoch 100/200
# 164/164 - 1s - loss: 2.4024e-05 - val_loss: 6.7907e-05 - 681ms/epoch - 4ms/step
# Epoch 101/200
# 164/164 - 1s - loss: 2.2034e-05 - val_loss: 6.3074e-05 - 632ms/epoch - 4ms/step
# Epoch 102/200
# 164/164 - 1s - loss: 1.5789e-05 - val_loss: 5.8344e-05 - 661ms/epoch - 4ms/step
# Epoch 103/200
# 164/164 - 1s - loss: 1.4353e-05 - val_loss: 5.7099e-05 - 637ms/epoch - 4ms/step
# Epoch 104/200
# 164/164 - 1s - loss: 1.2586e-05 - val_loss: 5.6996e-05 - 613ms/epoch - 4ms/step
# Epoch 105/200
# 164/164 - 1s - loss: 1.1868e-05 - val_loss: 5.5102e-05 - 602ms/epoch - 4ms/step
# Epoch 106/200
# 164/164 - 1s - loss: 1.1064e-05 - val_loss: 5.6423e-05 - 584ms/epoch - 4ms/step
# Epoch 107/200
# 164/164 - 1s - loss: 1.0122e-05 - val_loss: 5.3934e-05 - 600ms/epoch - 4ms/step
# Epoch 108/200
# 164/164 - 1s - loss: 9.4506e-06 - val_loss: 5.6450e-05 - 589ms/epoch - 4ms/step
# Epoch 109/200
# 164/164 - 1s - loss: 1.0793e-05 - val_loss: 5.4294e-05 - 608ms/epoch - 4ms/step
# Epoch 110/200
# 164/164 - 1s - loss: 1.0609e-05 - val_loss: 5.5866e-05 - 601ms/epoch - 4ms/step
# Epoch 111/200
# 164/164 - 1s - loss: 1.1051e-05 - val_loss: 5.7004e-05 - 635ms/epoch - 4ms/step
# Epoch 112/200
# 164/164 - 1s - loss: 1.4070e-05 - val_loss: 5.7664e-05 - 603ms/epoch - 4ms/step
# Epoch 113/200
# 164/164 - 1s - loss: 1.2990e-05 - val_loss: 5.5295e-05 - 764ms/epoch - 5ms/step
# Epoch 114/200
# 164/164 - 1s - loss: 3.0970e-05 - val_loss: 6.7416e-05 - 567ms/epoch - 3ms/step
# Epoch 115/200
# 164/164 - 1s - loss: 2.2646e-05 - val_loss: 5.8873e-05 - 624ms/epoch - 4ms/step
# Epoch 116/200
# 164/164 - 1s - loss: 1.4525e-05 - val_loss: 5.6633e-05 - 641ms/epoch - 4ms/step
# Epoch 117/200
# 164/164 - 1s - loss: 1.0618e-05 - val_loss: 5.2896e-05 - 726ms/epoch - 4ms/step
# Epoch 118/200
# 164/164 - 1s - loss: 9.1794e-06 - val_loss: 5.4231e-05 - 643ms/epoch - 4ms/step
# Epoch 119/200
# 164/164 - 1s - loss: 7.9359e-06 - val_loss: 5.2295e-05 - 633ms/epoch - 4ms/step
# Epoch 120/200
# 164/164 - 1s - loss: 7.3046e-06 - val_loss: 5.3321e-05 - 624ms/epoch - 4ms/step
# Epoch 121/200
# 164/164 - 1s - loss: 7.6669e-06 - val_loss: 5.1989e-05 - 598ms/epoch - 4ms/step
# Epoch 122/200
# 164/164 - 1s - loss: 6.6630e-06 - val_loss: 5.0877e-05 - 599ms/epoch - 4ms/step
# Epoch 123/200
# 164/164 - 1s - loss: 6.5006e-06 - val_loss: 5.2046e-05 - 599ms/epoch - 4ms/step
# Epoch 124/200
# 164/164 - 1s - loss: 5.9026e-05 - val_loss: 7.2191e-05 - 603ms/epoch - 4ms/step
# Epoch 125/200
# 164/164 - 1s - loss: 3.9884e-05 - val_loss: 6.4936e-05 - 640ms/epoch - 4ms/step
# Epoch 126/200
# 164/164 - 1s - loss: 2.7921e-05 - val_loss: 6.2415e-05 - 620ms/epoch - 4ms/step
# Epoch 127/200
# 164/164 - 1s - loss: 2.1832e-05 - val_loss: 5.3981e-05 - 668ms/epoch - 4ms/step
# Epoch 128/200
# 164/164 - 1s - loss: 1.5276e-05 - val_loss: 5.5362e-05 - 610ms/epoch - 4ms/step
# Epoch 129/200
# 164/164 - 1s - loss: 1.2178e-05 - val_loss: 5.5526e-05 - 592ms/epoch - 4ms/step
# Epoch 130/200
# 164/164 - 1s - loss: 1.0545e-05 - val_loss: 5.4115e-05 - 612ms/epoch - 4ms/step
# Epoch 131/200
# 164/164 - 1s - loss: 9.1303e-06 - val_loss: 5.1589e-05 - 605ms/epoch - 4ms/step
# Epoch 132/200
# 164/164 - 1s - loss: 8.4597e-06 - val_loss: 5.2009e-05 - 608ms/epoch - 4ms/step
# Epoch 133/200
# 164/164 - 1s - loss: 8.0677e-06 - val_loss: 5.0932e-05 - 599ms/epoch - 4ms/step
# Epoch 134/200
# 164/164 - 1s - loss: 7.4371e-06 - val_loss: 5.1093e-05 - 613ms/epoch - 4ms/step
# Epoch 135/200
# 164/164 - 1s - loss: 7.2212e-06 - val_loss: 5.1023e-05 - 593ms/epoch - 4ms/step
# Epoch 136/200
# 164/164 - 1s - loss: 6.9184e-06 - val_loss: 5.3067e-05 - 609ms/epoch - 4ms/step
# Epoch 137/200
# 164/164 - 1s - loss: 1.3702e-05 - val_loss: 6.6053e-05 - 609ms/epoch - 4ms/step
# Epoch 138/200
# 164/164 - 1s - loss: 2.1223e-05 - val_loss: 5.6271e-05 - 639ms/epoch - 4ms/step
# Epoch 139/200
# 164/164 - 1s - loss: 1.2395e-05 - val_loss: 5.4068e-05 - 602ms/epoch - 4ms/step
# Epoch 140/200
# 164/164 - 1s - loss: 9.7925e-06 - val_loss: 5.2383e-05 - 598ms/epoch - 4ms/step
# Epoch 141/200
# 164/164 - 1s - loss: 7.8771e-06 - val_loss: 5.2112e-05 - 619ms/epoch - 4ms/step
# Epoch 142/200
# 164/164 - 1s - loss: 7.1892e-06 - val_loss: 5.2077e-05 - 603ms/epoch - 4ms/step
# Epoch 143/200
# 164/164 - 1s - loss: 6.4229e-06 - val_loss: 5.0686e-05 - 605ms/epoch - 4ms/step
# Epoch 144/200
# 164/164 - 1s - loss: 6.4474e-06 - val_loss: 5.2464e-05 - 623ms/epoch - 4ms/step
# Epoch 145/200
# 164/164 - 1s - loss: 6.2760e-06 - val_loss: 5.1533e-05 - 608ms/epoch - 4ms/step
# Epoch 146/200
# 164/164 - 1s - loss: 5.9831e-06 - val_loss: 5.0939e-05 - 627ms/epoch - 4ms/step
# Epoch 147/200
# 164/164 - 1s - loss: 9.2149e-06 - val_loss: 5.7991e-05 - 802ms/epoch - 5ms/step
# Epoch 148/200
# 164/164 - 1s - loss: 1.0499e-05 - val_loss: 5.2521e-05 - 678ms/epoch - 4ms/step
# Epoch 149/200
# 164/164 - 1s - loss: 8.5263e-06 - val_loss: 5.4111e-05 - 835ms/epoch - 5ms/step
# Epoch 150/200
# 164/164 - 1s - loss: 8.3092e-06 - val_loss: 5.3835e-05 - 657ms/epoch - 4ms/step
# Epoch 151/200
# 164/164 - 1s - loss: 6.0948e-06 - val_loss: 5.0029e-05 - 851ms/epoch - 5ms/step
# Epoch 152/200
# 164/164 - 1s - loss: 4.6809e-06 - val_loss: 5.0205e-05 - 744ms/epoch - 5ms/step
# Epoch 153/200
# 164/164 - 1s - loss: 4.4187e-06 - val_loss: 4.9863e-05 - 664ms/epoch - 4ms/step
# Epoch 154/200
# 164/164 - 1s - loss: 7.1017e-06 - val_loss: 5.2100e-05 - 626ms/epoch - 4ms/step
# Epoch 155/200
# 164/164 - 1s - loss: 7.1083e-06 - val_loss: 4.8818e-05 - 634ms/epoch - 4ms/step
# Epoch 156/200
# 164/164 - 1s - loss: 5.1848e-06 - val_loss: 5.1476e-05 - 633ms/epoch - 4ms/step
# Epoch 157/200
# 164/164 - 1s - loss: 5.3060e-06 - val_loss: 5.0748e-05 - 632ms/epoch - 4ms/step
# Epoch 158/200
# 164/164 - 1s - loss: 5.4366e-06 - val_loss: 4.8977e-05 - 631ms/epoch - 4ms/step
# Epoch 159/200
# 164/164 - 1s - loss: 6.9457e-06 - val_loss: 5.4822e-05 - 634ms/epoch - 4ms/step
# Epoch 160/200
# 164/164 - 1s - loss: 8.9223e-06 - val_loss: 5.1570e-05 - 639ms/epoch - 4ms/step
# Epoch 161/200
# 164/164 - 1s - loss: 6.5623e-06 - val_loss: 5.1233e-05 - 637ms/epoch - 4ms/step
# Epoch 162/200
# 164/164 - 1s - loss: 5.7602e-06 - val_loss: 4.8636e-05 - 649ms/epoch - 4ms/step
# Epoch 163/200
# 164/164 - 1s - loss: 4.7638e-06 - val_loss: 4.9494e-05 - 628ms/epoch - 4ms/step
# Epoch 164/200
# 164/164 - 1s - loss: 4.1971e-06 - val_loss: 4.9509e-05 - 628ms/epoch - 4ms/step
# Epoch 165/200
# 164/164 - 1s - loss: 4.0938e-06 - val_loss: 4.9431e-05 - 635ms/epoch - 4ms/step
# Epoch 166/200
# 164/164 - 1s - loss: 3.7580e-06 - val_loss: 4.9480e-05 - 654ms/epoch - 4ms/step
# Epoch 167/200
# 164/164 - 1s - loss: 3.9387e-06 - val_loss: 5.0019e-05 - 612ms/epoch - 4ms/step
# Epoch 168/200
# 164/164 - 1s - loss: 4.2620e-06 - val_loss: 5.0080e-05 - 624ms/epoch - 4ms/step
# Epoch 169/200
# 164/164 - 1s - loss: 4.5295e-06 - val_loss: 5.2515e-05 - 604ms/epoch - 4ms/step
# Epoch 170/200
# 164/164 - 1s - loss: 4.2941e-06 - val_loss: 4.9615e-05 - 618ms/epoch - 4ms/step
# Epoch 171/200
# 164/164 - 1s - loss: 4.2920e-06 - val_loss: 4.9632e-05 - 725ms/epoch - 4ms/step
# Epoch 172/200
# 164/164 - 1s - loss: 3.9906e-06 - val_loss: 5.0003e-05 - 618ms/epoch - 4ms/step
# Epoch 173/200
# 164/164 - 1s - loss: 3.9389e-06 - val_loss: 4.9533e-05 - 692ms/epoch - 4ms/step
# Epoch 174/200
# 164/164 - 1s - loss: 3.8950e-06 - val_loss: 4.9602e-05 - 690ms/epoch - 4ms/step
# Epoch 175/200
# 164/164 - 1s - loss: 3.7212e-06 - val_loss: 5.2866e-05 - 609ms/epoch - 4ms/step
# Epoch 176/200
# 164/164 - 1s - loss: 7.7122e-06 - val_loss: 5.2875e-05 - 576ms/epoch - 4ms/step
# Epoch 177/200
# 164/164 - 1s - loss: 6.8419e-06 - val_loss: 4.9878e-05 - 587ms/epoch - 4ms/step
# Epoch 178/200
# 164/164 - 1s - loss: 4.9087e-06 - val_loss: 5.0028e-05 - 586ms/epoch - 4ms/step
# Epoch 179/200
# 164/164 - 1s - loss: 3.7569e-06 - val_loss: 4.8661e-05 - 580ms/epoch - 4ms/step
# Epoch 180/200
# 164/164 - 1s - loss: 2.9412e-06 - val_loss: 4.8320e-05 - 629ms/epoch - 4ms/step
# Epoch 181/200
# 164/164 - 1s - loss: 2.8895e-06 - val_loss: 4.8886e-05 - 571ms/epoch - 3ms/step
# Epoch 182/200
# 164/164 - 1s - loss: 3.0773e-06 - val_loss: 4.8968e-05 - 589ms/epoch - 4ms/step
# Epoch 183/200
# 164/164 - 1s - loss: 3.1327e-06 - val_loss: 4.8903e-05 - 577ms/epoch - 4ms/step
# Epoch 184/200
# 164/164 - 1s - loss: 5.1629e-06 - val_loss: 4.9525e-05 - 601ms/epoch - 4ms/step
# Epoch 185/200
# 164/164 - 1s - loss: 1.0979e-05 - val_loss: 5.5073e-05 - 577ms/epoch - 4ms/step
# Epoch 186/200
# 164/164 - 1s - loss: 6.0579e-06 - val_loss: 5.1280e-05 - 586ms/epoch - 4ms/step
# Epoch 187/200
# 164/164 - 1s - loss: 7.7279e-06 - val_loss: 5.2379e-05 - 651ms/epoch - 4ms/step
# Epoch 188/200
# 164/164 - 1s - loss: 9.2979e-06 - val_loss: 5.5403e-05 - 597ms/epoch - 4ms/step
# Epoch 189/200
# 164/164 - 1s - loss: 8.7319e-06 - val_loss: 5.1262e-05 - 644ms/epoch - 4ms/step
# Epoch 190/200
# 164/164 - 1s - loss: 5.0543e-06 - val_loss: 4.9896e-05 - 586ms/epoch - 4ms/step
# Epoch 191/200
# 164/164 - 1s - loss: 3.5439e-06 - val_loss: 4.9116e-05 - 610ms/epoch - 4ms/step
# Epoch 192/200
# 164/164 - 1s - loss: 2.7652e-06 - val_loss: 4.8149e-05 - 589ms/epoch - 4ms/step
# Epoch 193/200
# 164/164 - 1s - loss: 2.4862e-06 - val_loss: 4.8950e-05 - 641ms/epoch - 4ms/step
# Epoch 194/200
# 164/164 - 1s - loss: 2.2397e-06 - val_loss: 4.8652e-05 - 591ms/epoch - 4ms/step
# Epoch 195/200
# 164/164 - 1s - loss: 2.9815e-05 - val_loss: 5.9032e-05 - 597ms/epoch - 4ms/step
# Epoch 196/200
# 164/164 - 1s - loss: 1.2321e-05 - val_loss: 5.2815e-05 - 594ms/epoch - 4ms/step
# Epoch 197/200
# 164/164 - 1s - loss: 7.2499e-06 - val_loss: 5.2145e-05 - 591ms/epoch - 4ms/step
# Epoch 198/200
# 164/164 - 1s - loss: 5.5448e-06 - val_loss: 5.0323e-05 - 616ms/epoch - 4ms/step
# Epoch 199/200
# 164/164 - 1s - loss: 4.1839e-06 - val_loss: 4.9300e-05 - 586ms/epoch - 4ms/step
# Epoch 200/200
# 164/164 - 1s - loss: 3.8320e-06 - val_loss: 4.8628e-05 - 606ms/epoch - 4ms/step

# %%
history_aug = model_aug.fit(X_train_aug, y_train_aug, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 213/213 - 1s - loss: 0.0223 - val_loss: 0.0055 - 1s/epoch - 5ms/step
# Epoch 2/200
# 213/213 - 1s - loss: 0.0040 - val_loss: 0.0039 - 966ms/epoch - 5ms/step
# Epoch 3/200
# 213/213 - 1s - loss: 0.0026 - val_loss: 0.0031 - 854ms/epoch - 4ms/step
# Epoch 4/200
# 213/213 - 1s - loss: 0.0020 - val_loss: 0.0028 - 1s/epoch - 5ms/step
# Epoch 5/200
# 213/213 - 1s - loss: 0.0016 - val_loss: 0.0026 - 1s/epoch - 5ms/step
# Epoch 6/200
# 213/213 - 1s - loss: 0.0014 - val_loss: 0.0025 - 807ms/epoch - 4ms/step
# Epoch 7/200
# 213/213 - 1s - loss: 0.0013 - val_loss: 0.0023 - 787ms/epoch - 4ms/step
# Epoch 8/200
# 213/213 - 1s - loss: 0.0012 - val_loss: 0.0021 - 873ms/epoch - 4ms/step
# Epoch 9/200
# 213/213 - 1s - loss: 0.0012 - val_loss: 0.0020 - 892ms/epoch - 4ms/step
# Epoch 10/200
# 213/213 - 1s - loss: 9.5735e-04 - val_loss: 0.0023 - 842ms/epoch - 4ms/step
# Epoch 11/200
# 213/213 - 1s - loss: 9.3173e-04 - val_loss: 0.0019 - 834ms/epoch - 4ms/step
# Epoch 12/200
# 213/213 - 1s - loss: 9.0420e-04 - val_loss: 0.0019 - 1s/epoch - 5ms/step
# Epoch 13/200
# 213/213 - 1s - loss: 9.0520e-04 - val_loss: 0.0019 - 1s/epoch - 6ms/step
# Epoch 14/200
# 213/213 - 1s - loss: 8.7831e-04 - val_loss: 0.0018 - 1s/epoch - 6ms/step
# Epoch 15/200
# 213/213 - 1s - loss: 7.6106e-04 - val_loss: 0.0017 - 1s/epoch - 5ms/step
# Epoch 16/200
# 213/213 - 1s - loss: 7.2363e-04 - val_loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 17/200
# 213/213 - 1s - loss: 7.6429e-04 - val_loss: 0.0016 - 909ms/epoch - 4ms/step
# Epoch 18/200
# 213/213 - 1s - loss: 7.7762e-04 - val_loss: 0.0016 - 717ms/epoch - 3ms/step
# Epoch 19/200
# 213/213 - 1s - loss: 6.5702e-04 - val_loss: 0.0015 - 1s/epoch - 6ms/step
# Epoch 20/200
# 213/213 - 1s - loss: 7.0867e-04 - val_loss: 0.0014 - 1s/epoch - 5ms/step
# Epoch 21/200
# 213/213 - 1s - loss: 6.6499e-04 - val_loss: 0.0016 - 1s/epoch - 6ms/step
# Epoch 22/200
# 213/213 - 1s - loss: 7.4176e-04 - val_loss: 0.0015 - 1s/epoch - 6ms/step
# Epoch 23/200
# 213/213 - 1s - loss: 8.4819e-04 - val_loss: 0.0014 - 973ms/epoch - 5ms/step
# Epoch 24/200
# 213/213 - 1s - loss: 6.8208e-04 - val_loss: 0.0014 - 967ms/epoch - 5ms/step
# Epoch 25/200
# 213/213 - 1s - loss: 5.6626e-04 - val_loss: 0.0013 - 880ms/epoch - 4ms/step
# Epoch 26/200
# 213/213 - 1s - loss: 5.2342e-04 - val_loss: 0.0013 - 1s/epoch - 5ms/step
# Epoch 27/200
# 213/213 - 1s - loss: 5.0118e-04 - val_loss: 0.0012 - 970ms/epoch - 5ms/step
# Epoch 28/200
# 213/213 - 1s - loss: 5.1250e-04 - val_loss: 0.0014 - 984ms/epoch - 5ms/step
# Epoch 29/200
# 213/213 - 1s - loss: 5.6473e-04 - val_loss: 0.0011 - 1s/epoch - 5ms/step
# Epoch 30/200
# 213/213 - 1s - loss: 6.4449e-04 - val_loss: 0.0012 - 1s/epoch - 5ms/step
# Epoch 31/200
# 213/213 - 2s - loss: 5.6381e-04 - val_loss: 0.0013 - 2s/epoch - 7ms/step
# Epoch 32/200
# 213/213 - 1s - loss: 5.3331e-04 - val_loss: 9.9504e-04 - 1s/epoch - 7ms/step
# Epoch 33/200
# 213/213 - 1s - loss: 4.6712e-04 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 34/200
# 213/213 - 1s - loss: 5.8084e-04 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 35/200
# 213/213 - 1s - loss: 6.2931e-04 - val_loss: 0.0013 - 1s/epoch - 6ms/step
# Epoch 36/200
# 213/213 - 1s - loss: 5.6864e-04 - val_loss: 0.0014 - 1s/epoch - 7ms/step
# Epoch 37/200
# 213/213 - 1s - loss: 5.4699e-04 - val_loss: 0.0013 - 1s/epoch - 7ms/step
# Epoch 38/200
# 213/213 - 1s - loss: 5.7404e-04 - val_loss: 0.0014 - 1s/epoch - 6ms/step
# Epoch 39/200
# 213/213 - 1s - loss: 7.1592e-04 - val_loss: 0.0014 - 1s/epoch - 6ms/step
# Epoch 40/200
# 213/213 - 1s - loss: 5.8137e-04 - val_loss: 0.0011 - 1s/epoch - 6ms/step
# Epoch 41/200
# 213/213 - 1s - loss: 4.1356e-04 - val_loss: 0.0011 - 1s/epoch - 6ms/step
# Epoch 42/200
# 213/213 - 1s - loss: 4.9072e-04 - val_loss: 9.9410e-04 - 1s/epoch - 6ms/step
# Epoch 43/200
# 213/213 - 1s - loss: 4.5721e-04 - val_loss: 0.0010 - 1s/epoch - 6ms/step
# Epoch 44/200
# 213/213 - 1s - loss: 3.6601e-04 - val_loss: 0.0010 - 1s/epoch - 6ms/step
# Epoch 45/200
# 213/213 - 1s - loss: 4.0296e-04 - val_loss: 0.0011 - 1s/epoch - 6ms/step
# Epoch 46/200
# 213/213 - 1s - loss: 4.2622e-04 - val_loss: 9.8248e-04 - 1s/epoch - 6ms/step
# Epoch 47/200
# 213/213 - 1s - loss: 3.5539e-04 - val_loss: 8.4257e-04 - 1s/epoch - 6ms/step
# Epoch 48/200
# 213/213 - 1s - loss: 3.3156e-04 - val_loss: 8.9932e-04 - 1s/epoch - 6ms/step
# Epoch 49/200
# 213/213 - 1s - loss: 3.0242e-04 - val_loss: 7.8197e-04 - 1s/epoch - 6ms/step
# Epoch 50/200
# 213/213 - 1s - loss: 3.5459e-04 - val_loss: 0.0010 - 1s/epoch - 6ms/step
# Epoch 51/200
# 213/213 - 1s - loss: 3.8379e-04 - val_loss: 0.0013 - 1s/epoch - 6ms/step
# Epoch 52/200
# 213/213 - 1s - loss: 4.2509e-04 - val_loss: 0.0014 - 1s/epoch - 6ms/step
# Epoch 53/200
# 213/213 - 1s - loss: 4.1089e-04 - val_loss: 0.0010 - 1s/epoch - 6ms/step
# Epoch 54/200
# 213/213 - 1s - loss: 3.8450e-04 - val_loss: 9.3055e-04 - 1s/epoch - 6ms/step
# Epoch 55/200
# 213/213 - 1s - loss: 3.1497e-04 - val_loss: 0.0010 - 1s/epoch - 6ms/step
# Epoch 56/200
# 213/213 - 1s - loss: 3.2156e-04 - val_loss: 8.9768e-04 - 1s/epoch - 5ms/step
# Epoch 57/200
# 213/213 - 1s - loss: 3.0577e-04 - val_loss: 7.9647e-04 - 1s/epoch - 6ms/step
# Epoch 58/200
# 213/213 - 1s - loss: 2.9039e-04 - val_loss: 8.5076e-04 - 1s/epoch - 5ms/step
# Epoch 59/200
# 213/213 - 1s - loss: 8.1154e-04 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 60/200
# 213/213 - 2s - loss: 5.7671e-04 - val_loss: 0.0012 - 2s/epoch - 7ms/step
# Epoch 61/200
# 213/213 - 1s - loss: 4.1710e-04 - val_loss: 9.3790e-04 - 1s/epoch - 7ms/step
# Epoch 62/200
# 213/213 - 1s - loss: 3.1506e-04 - val_loss: 8.6403e-04 - 1s/epoch - 6ms/step
# Epoch 63/200
# 213/213 - 1s - loss: 2.3593e-04 - val_loss: 8.8827e-04 - 1s/epoch - 7ms/step
# Epoch 64/200
# 213/213 - 1s - loss: 2.4017e-04 - val_loss: 8.4790e-04 - 1s/epoch - 7ms/step
# Epoch 65/200
# 213/213 - 2s - loss: 2.3126e-04 - val_loss: 8.6887e-04 - 2s/epoch - 8ms/step
# Epoch 66/200
# 213/213 - 2s - loss: 2.3228e-04 - val_loss: 7.8501e-04 - 2s/epoch - 8ms/step
# Epoch 67/200
# 213/213 - 2s - loss: 2.2031e-04 - val_loss: 8.2756e-04 - 2s/epoch - 8ms/step
# Epoch 68/200
# 213/213 - 2s - loss: 3.4228e-04 - val_loss: 8.4094e-04 - 2s/epoch - 8ms/step
# Epoch 69/200
# 213/213 - 2s - loss: 2.8118e-04 - val_loss: 8.6826e-04 - 2s/epoch - 8ms/step
# Epoch 70/200
# 213/213 - 2s - loss: 2.9031e-04 - val_loss: 8.2204e-04 - 2s/epoch - 8ms/step
# Epoch 71/200
# 213/213 - 2s - loss: 3.2979e-04 - val_loss: 8.2217e-04 - 2s/epoch - 8ms/step
# Epoch 72/200
# 213/213 - 1s - loss: 2.9483e-04 - val_loss: 8.3654e-04 - 1s/epoch - 7ms/step
# Epoch 73/200
# 213/213 - 2s - loss: 2.5491e-04 - val_loss: 8.4821e-04 - 2s/epoch - 7ms/step
# Epoch 74/200
# 213/213 - 2s - loss: 2.4721e-04 - val_loss: 8.4968e-04 - 2s/epoch - 7ms/step
# Epoch 75/200
# 213/213 - 1s - loss: 2.7257e-04 - val_loss: 9.2051e-04 - 1s/epoch - 6ms/step
# Epoch 76/200
# 213/213 - 1s - loss: 2.9624e-04 - val_loss: 7.8740e-04 - 1s/epoch - 6ms/step
# Epoch 77/200
# 213/213 - 1s - loss: 2.3335e-04 - val_loss: 8.2653e-04 - 1s/epoch - 6ms/step
# Epoch 78/200
# 213/213 - 1s - loss: 2.1421e-04 - val_loss: 7.4184e-04 - 1s/epoch - 6ms/step
# Epoch 79/200
# 213/213 - 1s - loss: 2.1690e-04 - val_loss: 7.4594e-04 - 1s/epoch - 6ms/step
# Epoch 80/200
# 213/213 - 1s - loss: 1.9293e-04 - val_loss: 7.5032e-04 - 1s/epoch - 6ms/step
# Epoch 81/200
# 213/213 - 1s - loss: 1.9827e-04 - val_loss: 7.9596e-04 - 1s/epoch - 6ms/step
# Epoch 82/200
# 213/213 - 1s - loss: 2.2729e-04 - val_loss: 7.5875e-04 - 1s/epoch - 6ms/step
# Epoch 83/200
# 213/213 - 1s - loss: 2.4181e-04 - val_loss: 9.1314e-04 - 1s/epoch - 6ms/step
# Epoch 84/200
# 213/213 - 1s - loss: 2.4518e-04 - val_loss: 7.4579e-04 - 1s/epoch - 6ms/step
# Epoch 85/200
# 213/213 - 1s - loss: 2.0065e-04 - val_loss: 7.8857e-04 - 1s/epoch - 6ms/step
# Epoch 86/200
# 213/213 - 1s - loss: 1.9310e-04 - val_loss: 7.3351e-04 - 1s/epoch - 6ms/step
# Epoch 87/200
# 213/213 - 1s - loss: 2.3712e-04 - val_loss: 6.9080e-04 - 1s/epoch - 6ms/step
# Epoch 88/200
# 213/213 - 1s - loss: 2.2548e-04 - val_loss: 7.6589e-04 - 1s/epoch - 6ms/step
# Epoch 89/200
# 213/213 - 1s - loss: 2.5071e-04 - val_loss: 7.1975e-04 - 1s/epoch - 6ms/step
# Epoch 90/200
# 213/213 - 1s - loss: 2.6061e-04 - val_loss: 7.5434e-04 - 1s/epoch - 6ms/step
# Epoch 91/200
# 213/213 - 1s - loss: 2.1053e-04 - val_loss: 7.3096e-04 - 1s/epoch - 6ms/step
# Epoch 92/200
# 213/213 - 1s - loss: 2.4285e-04 - val_loss: 8.1780e-04 - 1s/epoch - 6ms/step
# Epoch 93/200
# 213/213 - 1s - loss: 1.9578e-04 - val_loss: 8.0222e-04 - 1s/epoch - 6ms/step
# Epoch 94/200
# 213/213 - 1s - loss: 1.8652e-04 - val_loss: 7.4778e-04 - 1s/epoch - 6ms/step
# Epoch 95/200
# 213/213 - 1s - loss: 1.8173e-04 - val_loss: 7.1438e-04 - 1s/epoch - 6ms/step
# Epoch 96/200
# 213/213 - 1s - loss: 2.7029e-04 - val_loss: 7.8742e-04 - 1s/epoch - 6ms/step
# Epoch 97/200
# 213/213 - 1s - loss: 2.4230e-04 - val_loss: 7.4718e-04 - 1s/epoch - 6ms/step
# Epoch 98/200
# 213/213 - 1s - loss: 1.9905e-04 - val_loss: 7.1452e-04 - 1s/epoch - 5ms/step
# Epoch 99/200
# 213/213 - 1s - loss: 1.6154e-04 - val_loss: 7.0666e-04 - 1s/epoch - 6ms/step
# Epoch 100/200
# 213/213 - 1s - loss: 1.8112e-04 - val_loss: 7.6623e-04 - 1s/epoch - 6ms/step
# Epoch 101/200
# 213/213 - 1s - loss: 2.1246e-04 - val_loss: 7.0370e-04 - 1s/epoch - 6ms/step
# Epoch 102/200
# 213/213 - 1s - loss: 2.0561e-04 - val_loss: 6.9585e-04 - 1s/epoch - 6ms/step
# Epoch 103/200
# 213/213 - 1s - loss: 1.7700e-04 - val_loss: 6.6548e-04 - 1s/epoch - 6ms/step
# Epoch 104/200
# 213/213 - 1s - loss: 1.7817e-04 - val_loss: 7.6026e-04 - 1s/epoch - 6ms/step
# Epoch 105/200
# 213/213 - 1s - loss: 1.6102e-04 - val_loss: 7.4100e-04 - 1s/epoch - 6ms/step
# Epoch 106/200
# 213/213 - 1s - loss: 1.6267e-04 - val_loss: 6.9112e-04 - 1s/epoch - 6ms/step
# Epoch 107/200
# 213/213 - 1s - loss: 1.5231e-04 - val_loss: 9.1213e-04 - 1s/epoch - 6ms/step
# Epoch 108/200
# 213/213 - 1s - loss: 3.2857e-04 - val_loss: 7.0403e-04 - 1s/epoch - 6ms/step
# Epoch 109/200
# 213/213 - 1s - loss: 1.9890e-04 - val_loss: 6.7439e-04 - 1s/epoch - 6ms/step
# Epoch 110/200
# 213/213 - 1s - loss: 1.9478e-04 - val_loss: 7.0300e-04 - 1s/epoch - 6ms/step
# Epoch 111/200
# 213/213 - 1s - loss: 1.6379e-04 - val_loss: 7.0987e-04 - 1s/epoch - 6ms/step
# Epoch 112/200
# 213/213 - 1s - loss: 1.3391e-04 - val_loss: 6.8319e-04 - 1s/epoch - 6ms/step
# Epoch 113/200
# 213/213 - 1s - loss: 1.4780e-04 - val_loss: 7.2229e-04 - 1s/epoch - 6ms/step
# Epoch 114/200
# 213/213 - 1s - loss: 1.5921e-04 - val_loss: 6.9685e-04 - 1s/epoch - 6ms/step
# Epoch 115/200
# 213/213 - 1s - loss: 1.7540e-04 - val_loss: 7.5916e-04 - 1s/epoch - 6ms/step
# Epoch 116/200
# 213/213 - 1s - loss: 1.6886e-04 - val_loss: 7.3318e-04 - 1s/epoch - 6ms/step
# Epoch 117/200
# 213/213 - 1s - loss: 1.7457e-04 - val_loss: 7.2327e-04 - 1s/epoch - 6ms/step
# Epoch 118/200
# 213/213 - 1s - loss: 1.5937e-04 - val_loss: 7.0335e-04 - 1s/epoch - 6ms/step
# Epoch 119/200
# 213/213 - 1s - loss: 1.4145e-04 - val_loss: 6.9742e-04 - 1s/epoch - 6ms/step
# Epoch 120/200
# 213/213 - 1s - loss: 1.4521e-04 - val_loss: 7.2858e-04 - 1s/epoch - 6ms/step
# Epoch 121/200
# 213/213 - 1s - loss: 1.5266e-04 - val_loss: 7.2024e-04 - 1s/epoch - 6ms/step
# Epoch 122/200
# 213/213 - 1s - loss: 1.8325e-04 - val_loss: 7.4498e-04 - 1s/epoch - 6ms/step
# Epoch 123/200
# 213/213 - 1s - loss: 1.8495e-04 - val_loss: 7.4581e-04 - 1s/epoch - 6ms/step
# Epoch 124/200
# 213/213 - 1s - loss: 1.7630e-04 - val_loss: 7.3564e-04 - 1s/epoch - 6ms/step
# Epoch 125/200
# 213/213 - 1s - loss: 1.6271e-04 - val_loss: 7.3322e-04 - 1s/epoch - 6ms/step
# Epoch 126/200
# 213/213 - 1s - loss: 1.3333e-04 - val_loss: 6.4051e-04 - 1s/epoch - 6ms/step
# Epoch 127/200
# 213/213 - 1s - loss: 1.2329e-04 - val_loss: 7.2257e-04 - 1s/epoch - 6ms/step
# Epoch 128/200
# 213/213 - 1s - loss: 1.3809e-04 - val_loss: 6.9526e-04 - 1s/epoch - 6ms/step
# Epoch 129/200
# 213/213 - 1s - loss: 1.4811e-04 - val_loss: 6.9554e-04 - 1s/epoch - 5ms/step
# Epoch 130/200
# 213/213 - 1s - loss: 1.7637e-04 - val_loss: 7.7056e-04 - 1s/epoch - 6ms/step
# Epoch 131/200
# 213/213 - 1s - loss: 1.4774e-04 - val_loss: 6.9664e-04 - 1s/epoch - 6ms/step
# Epoch 132/200
# 213/213 - 1s - loss: 1.4420e-04 - val_loss: 6.6386e-04 - 1s/epoch - 7ms/step
# Epoch 133/200
# 213/213 - 1s - loss: 1.6150e-04 - val_loss: 7.7907e-04 - 1s/epoch - 6ms/step
# Epoch 134/200
# 213/213 - 1s - loss: 1.3171e-04 - val_loss: 6.7166e-04 - 1s/epoch - 6ms/step
# Epoch 135/200
# 213/213 - 1s - loss: 1.3644e-04 - val_loss: 7.2338e-04 - 1s/epoch - 6ms/step
# Epoch 136/200
# 213/213 - 1s - loss: 1.6361e-04 - val_loss: 7.8347e-04 - 1s/epoch - 7ms/step
# Epoch 137/200
# 213/213 - 1s - loss: 2.4548e-04 - val_loss: 9.0431e-04 - 1s/epoch - 6ms/step
# Epoch 138/200
# 213/213 - 1s - loss: 1.7290e-04 - val_loss: 6.6831e-04 - 1s/epoch - 6ms/step
# Epoch 139/200
# 213/213 - 2s - loss: 1.6106e-04 - val_loss: 7.2451e-04 - 2s/epoch - 7ms/step
# Epoch 140/200
# 213/213 - 1s - loss: 1.3963e-04 - val_loss: 7.6071e-04 - 1s/epoch - 7ms/step
# Epoch 141/200
# 213/213 - 1s - loss: 1.2225e-04 - val_loss: 6.9259e-04 - 1s/epoch - 6ms/step
# Epoch 142/200
# 213/213 - 1s - loss: 1.1589e-04 - val_loss: 6.7766e-04 - 1s/epoch - 6ms/step
# Epoch 143/200
# 213/213 - 1s - loss: 1.2890e-04 - val_loss: 6.9055e-04 - 1s/epoch - 6ms/step
# Epoch 144/200
# 213/213 - 1s - loss: 1.2870e-04 - val_loss: 6.7863e-04 - 1s/epoch - 6ms/step
# Epoch 145/200
# 213/213 - 1s - loss: 1.0664e-04 - val_loss: 6.9607e-04 - 1s/epoch - 6ms/step
# Epoch 146/200
# 213/213 - 1s - loss: 1.4524e-04 - val_loss: 7.2043e-04 - 1s/epoch - 6ms/step
# Epoch 147/200
# 213/213 - 1s - loss: 1.4632e-04 - val_loss: 6.6319e-04 - 1s/epoch - 6ms/step
# Epoch 148/200
# 213/213 - 1s - loss: 1.4857e-04 - val_loss: 7.2203e-04 - 1s/epoch - 6ms/step
# Epoch 149/200
# 213/213 - 1s - loss: 1.5294e-04 - val_loss: 6.9289e-04 - 1s/epoch - 6ms/step
# Epoch 150/200
# 213/213 - 1s - loss: 1.6841e-04 - val_loss: 7.3839e-04 - 1s/epoch - 5ms/step
# Epoch 151/200
# 213/213 - 1s - loss: 1.4074e-04 - val_loss: 6.6088e-04 - 1s/epoch - 6ms/step
# Epoch 152/200
# 213/213 - 1s - loss: 1.6191e-04 - val_loss: 7.9052e-04 - 1s/epoch - 5ms/step
# Epoch 153/200
# 213/213 - 1s - loss: 1.4771e-04 - val_loss: 6.8795e-04 - 1s/epoch - 6ms/step
# Epoch 154/200
# 213/213 - 1s - loss: 1.3587e-04 - val_loss: 6.4013e-04 - 1s/epoch - 6ms/step
# Epoch 155/200
# 213/213 - 1s - loss: 1.4527e-04 - val_loss: 6.5668e-04 - 1s/epoch - 6ms/step
# Epoch 156/200
# 213/213 - 1s - loss: 1.2153e-04 - val_loss: 6.6904e-04 - 1s/epoch - 6ms/step
# Epoch 157/200
# 213/213 - 1s - loss: 1.0503e-04 - val_loss: 6.7184e-04 - 1s/epoch - 6ms/step
# Epoch 158/200
# 213/213 - 1s - loss: 1.0447e-04 - val_loss: 6.7814e-04 - 1s/epoch - 6ms/step
# Epoch 159/200
# 213/213 - 1s - loss: 1.2067e-04 - val_loss: 6.7869e-04 - 1s/epoch - 6ms/step
# Epoch 160/200
# 213/213 - 1s - loss: 1.2855e-04 - val_loss: 7.0919e-04 - 1s/epoch - 6ms/step
# Epoch 161/200
# 213/213 - 1s - loss: 1.2914e-04 - val_loss: 6.7064e-04 - 1s/epoch - 6ms/step
# Epoch 162/200
# 213/213 - 1s - loss: 1.0690e-04 - val_loss: 6.8524e-04 - 1s/epoch - 6ms/step
# Epoch 163/200
# 213/213 - 1s - loss: 1.2404e-04 - val_loss: 7.0668e-04 - 1s/epoch - 6ms/step
# Epoch 164/200
# 213/213 - 1s - loss: 1.4146e-04 - val_loss: 6.6058e-04 - 1s/epoch - 6ms/step
# Epoch 165/200
# 213/213 - 1s - loss: 1.3953e-04 - val_loss: 7.4000e-04 - 1s/epoch - 7ms/step
# Epoch 166/200
# 213/213 - 1s - loss: 1.3430e-04 - val_loss: 7.3458e-04 - 1s/epoch - 6ms/step
# Epoch 167/200
# 213/213 - 1s - loss: 1.7555e-04 - val_loss: 8.1987e-04 - 1s/epoch - 6ms/step
# Epoch 168/200
# 213/213 - 1s - loss: 1.3780e-04 - val_loss: 6.9823e-04 - 1s/epoch - 6ms/step
# Epoch 169/200
# 213/213 - 1s - loss: 1.1854e-04 - val_loss: 6.8447e-04 - 1s/epoch - 6ms/step
# Epoch 170/200
# 213/213 - 1s - loss: 1.0272e-04 - val_loss: 6.7683e-04 - 1s/epoch - 6ms/step
# Epoch 171/200
# 213/213 - 1s - loss: 9.2786e-05 - val_loss: 7.0439e-04 - 1s/epoch - 6ms/step
# Epoch 172/200
# 213/213 - 1s - loss: 1.0142e-04 - val_loss: 6.9536e-04 - 1s/epoch - 6ms/step
# Epoch 173/200
# 213/213 - 1s - loss: 1.0610e-04 - val_loss: 6.9227e-04 - 1s/epoch - 7ms/step
# Epoch 174/200
# 213/213 - 1s - loss: 1.4244e-04 - val_loss: 7.1420e-04 - 1s/epoch - 6ms/step
# Epoch 175/200
# 213/213 - 1s - loss: 1.5012e-04 - val_loss: 7.1947e-04 - 1s/epoch - 6ms/step
# Epoch 176/200
# 213/213 - 1s - loss: 1.3378e-04 - val_loss: 7.2895e-04 - 1s/epoch - 6ms/step
# Epoch 177/200
# 213/213 - 1s - loss: 1.1928e-04 - val_loss: 6.8781e-04 - 1s/epoch - 6ms/step
# Epoch 178/200
# 213/213 - 1s - loss: 1.2853e-04 - val_loss: 6.5711e-04 - 1s/epoch - 5ms/step
# Epoch 179/200
# 213/213 - 1s - loss: 1.1021e-04 - val_loss: 6.9955e-04 - 1s/epoch - 6ms/step
# Epoch 180/200
# 213/213 - 1s - loss: 9.9528e-05 - val_loss: 7.7268e-04 - 1s/epoch - 6ms/step
# Epoch 181/200
# 213/213 - 1s - loss: 1.4199e-04 - val_loss: 6.9624e-04 - 1s/epoch - 6ms/step
# Epoch 182/200
# 213/213 - 1s - loss: 1.1907e-04 - val_loss: 6.7197e-04 - 1s/epoch - 6ms/step
# Epoch 183/200
# 213/213 - 1s - loss: 1.0187e-04 - val_loss: 6.9602e-04 - 1s/epoch - 6ms/step
# Epoch 184/200
# 213/213 - 1s - loss: 1.0545e-04 - val_loss: 6.8701e-04 - 1s/epoch - 6ms/step
# Epoch 185/200
# 213/213 - 1s - loss: 1.3459e-04 - val_loss: 6.9281e-04 - 1s/epoch - 6ms/step
# Epoch 186/200
# 213/213 - 1s - loss: 1.0271e-04 - val_loss: 7.1775e-04 - 1s/epoch - 6ms/step
# Epoch 187/200
# 213/213 - 1s - loss: 1.1324e-04 - val_loss: 7.1549e-04 - 1s/epoch - 6ms/step
# Epoch 188/200
# 213/213 - 1s - loss: 1.0762e-04 - val_loss: 7.0644e-04 - 1s/epoch - 6ms/step
# Epoch 189/200
# 213/213 - 1s - loss: 1.1488e-04 - val_loss: 7.2328e-04 - 1s/epoch - 6ms/step
# Epoch 190/200
# 213/213 - 1s - loss: 1.2792e-04 - val_loss: 7.0395e-04 - 1s/epoch - 6ms/step
# Epoch 191/200
# 213/213 - 1s - loss: 1.1216e-04 - val_loss: 6.8556e-04 - 1s/epoch - 6ms/step
# Epoch 192/200
# 213/213 - 1s - loss: 1.0391e-04 - val_loss: 6.9483e-04 - 1s/epoch - 6ms/step
# Epoch 193/200
# 213/213 - 1s - loss: 8.4865e-05 - val_loss: 6.8596e-04 - 1s/epoch - 6ms/step
# Epoch 194/200
# 213/213 - 1s - loss: 1.0715e-04 - val_loss: 7.6107e-04 - 1s/epoch - 6ms/step
# Epoch 195/200
# 213/213 - 1s - loss: 1.1752e-04 - val_loss: 7.2975e-04 - 1s/epoch - 6ms/step
# Epoch 196/200
# 213/213 - 1s - loss: 1.1682e-04 - val_loss: 7.2041e-04 - 1s/epoch - 5ms/step
# Epoch 197/200
# 213/213 - 1s - loss: 1.2088e-04 - val_loss: 6.9267e-04 - 1s/epoch - 6ms/step
# Epoch 198/200
# 213/213 - 1s - loss: 1.1553e-04 - val_loss: 7.2144e-04 - 1s/epoch - 6ms/step
# Epoch 199/200
# 213/213 - 1s - loss: 9.6193e-05 - val_loss: 6.9238e-04 - 1s/epoch - 6ms/step
# Epoch 200/200
# 213/213 - 1s - loss: 9.8405e-05 - val_loss: 6.8334e-04 - 1s/epoch - 6ms/step

# %%
# Extraia os valores de loss do histórico
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Non Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Extraia os valores de loss do histórico
train_loss = history_aug.history['loss']
val_loss = history_aug.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_hat = model.predict(X_test)
print(y_hat.shape)

y_hat_aug = model_aug.predict(X_test)
print(y_hat_aug.shape)
# Out:
# 176/176 [==============================] - 1s 2ms/step
# (5612, 3)
# 176/176 [==============================] - 0s 2ms/step
# (5612, 3)

# %%
PredDF = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat,columns=['yh1','yh2','yh3'])],axis=1)

PredDF_aug = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat_aug,columns=['yh1','yh2','yh3'])],axis=1)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Correlation

# %%
PredDF.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.827983 -0.105019 -0.631326
# y2 -0.107525  0.913718  0.174840
# y3 -0.642838  0.188263  0.825372

# %%
PredDF_aug.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.597151 -0.100857 -0.520425
# y2 -0.123603  0.735375  0.050205
# y3 -0.569694  0.171046  0.530689

# %% [markdown]
# ## R2

# %%
print('Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF['y1'], PredDF['yh1']))
print('')
print('')
plt.scatter(PredDF['y1'], PredDF['yh1'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF['y2'], PredDF['yh2']))
print('')
print('')
plt.scatter(PredDF['y2'], PredDF['yh2'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF['y3'], PredDF['yh3']))
print('')
print('')
plt.scatter(PredDF['y3'], PredDF['yh3'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
# plt.show()


print('PredDF_aug: Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF_aug['y1'], PredDF_aug['yh1']))
print('')
print('')
plt.scatter(PredDF_aug['y1'], PredDF_aug['yh1'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF_aug['y2'], PredDF_aug['yh2']))
print('')
print('')
plt.scatter(PredDF_aug['y2'], PredDF_aug['yh2'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF_aug['y3'], PredDF_aug['yh3']))
print('')
print('')
plt.scatter(PredDF_aug['y3'], PredDF_aug['yh3'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
# plt.show()
# Out:
# Resultados Holdout Enn
#
# 0.6834090999305192
#
#
# Resultados Holdout Etn
#
# 0.8342679511320472
#
#
# Resultados Holdout Ett
#
# 0.6795588311001006
#
#
# PredDF_aug: Resultados Holdout Enn
#
# 0.1047850655988668
#
#
# PredDF_aug: Resultados Holdout Etn
#
# 0.5089925574370247
#
#
# PredDF_aug: Resultados Holdout Ett
#
# -0.06145890694430434
# Text(0, 0.5, 'Predicted')

# %%
ind_tr1= y_test.Enn
ind_tr2= y_test.Etn
ind_tr3= y_test.Ett
y_test.loc[ind_tr1.index,'Enn'] = y_hat[:,0]
y_test.loc[ind_tr2.index,'Etn'] = y_hat[:,1]
y_test.loc[ind_tr3.index,'Ett'] = y_hat[:,2]

ind_tr1_aug= y_test.Enn
ind_tr2_aug= y_test.Etn
ind_tr3_aug= y_test.Ett
y_test.loc[ind_tr1_aug.index,'Enn'] = y_hat_aug[:,0]
y_test.loc[ind_tr2_aug.index,'Etn'] = y_hat_aug[:,1]
y_test.loc[ind_tr3_aug.index,'Ett'] = y_hat_aug[:,2]

# %%
ind_tes1= y_test.Enn
ind_tes2= y_test.Etn
ind_tes3= y_test.Ett
df.loc[ind_tes1.index,'Enn'] = y_test.Enn
df.loc[ind_tes2.index,'Etn'] = y_test.Etn
df.loc[ind_tes3.index,'Ett'] = y_test.Ett

df_aug = df
ind_tes1_aug= y_test.Enn
ind_tes2_aug= y_test.Etn
ind_tes3_aug= y_test.Ett
df_aug.loc[ind_tes1_aug.index,'Enn'] = y_test.Enn
df_aug.loc[ind_tes2_aug.index,'Etn'] = y_test.Etn
df_aug.loc[ind_tes3_aug.index,'Ett'] = y_test.Ett

# %%
display(df[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
display(df_aug[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df.iloc[a,4]
    j=df.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df.iloc[a,1]
    df2.iloc[ind,2]=df.iloc[a,2]
    df2.iloc[ind,3]=df.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100

Enn_MLP_35=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35.mat', {'Enn_MLP_35': Enn_MLP_35}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35.mat', {'Etn_MLP_35': Etn_MLP_35})
spio.savemat('Ett_MLP_35.mat', {'Ett_MLP_35': Ett_MLP_35})
# Out:
# n1= 199 m1= 210
# ncases= 41790

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df_aug.iloc[a,4]
    j=df_aug.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df_aug.iloc[a,1]
    df2.iloc[ind,2]=df_aug.iloc[a,2]
    df2.iloc[ind,3]=df_aug.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100
    
Enn_MLP_35_aug=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35_aug=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35_aug=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35_aug.mat', {'Enn_MLP_35_aug': Enn_MLP_35_aug}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35_aug.mat', {'Etn_MLP_35_aug': Etn_MLP_35_aug})
spio.savemat('Ett_MLP_35_aug.mat', {'Ett_MLP_35_aug': Ett_MLP_35_aug})
# Out:
# n1= 199 m1= 210
# ncases= 41790
