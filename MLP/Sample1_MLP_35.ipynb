# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.io as sio
from scipy import io as spio
from tqdm import tqdm
import cv2
from sklearn import metrics


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Split Data

# %%
def tic():
    #Homemade version of matlab tic and toc functions
    import time
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    import time
    if 'startTime_for_tictoc' in globals():
        print ('\nElapsed time is ')
        print (str(time.time() - startTime_for_tictoc))
        print('seconds.\n')
    else:
        print ('\nToc: start time not set\n')

# %%
data1= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_1/RDM_Sample_1.mat')
angles1= data1['RDM']['angles'][0][0]
Enn1= data1['RDM']['Strains'][0][0][0][0][5]
Etn1= data1['RDM']['Strains'][0][0][0][0][4]
Ett1= data1['RDM']['Strains'][0][0][0][0][3]
CM1= data1['RDM']['CM'][0][0]

data2= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles2= data2['RDM']['angles'][0][0]
Enn2= data2['RDM']['Strains'][0][0][0][0][5]
Etn2= data2['RDM']['Strains'][0][0][0][0][4]
Ett2= data2['RDM']['Strains'][0][0][0][0][3]
CM2= data2['RDM']['CM'][0][0]

data3= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_2/RDM_Sample_2.mat')
angles3= data3['RDM']['angles'][0][0]
Enn3= data3['RDM']['Strains'][0][0][0][0][5]
Etn3= data3['RDM']['Strains'][0][0][0][0][4]
Ett3= data3['RDM']['Strains'][0][0][0][0][3]
CM3= data3['RDM']['CM'][0][0]

# %%
print(angles1.shape)
print(angles2.shape)
# Out:
# (199, 210)
# (405, 419)

# %%
data= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_1/RDM_Sample_1.mat')
angles= data['RDM']['angles'][0][0]
Enn= data['RDM']['Strains'][0][0][0][0][5]
Etn= data['RDM']['Strains'][0][0][0][0][4]
Ett= data['RDM']['Strains'][0][0][0][0][3]
CM= data['RDM']['CM'][0][0]

indPred= CM==1
wndSize= 35
n,m = angles.shape

print('n=', n , 'm=', m )

stride= int((wndSize-1)/2)
ncases= sum(sum(CM[stride:n-stride,stride:m-stride]==1))

Y= np.zeros((ncases,5))
X0= np.zeros((ncases, wndSize**2))
X1= np.zeros((ncases,1))

cnt=0
for i in range(0+stride,n-stride):
  for j in range(0+stride,m-stride):
    if CM[i,j] == 1:
      indX= range(i-stride,i+stride+1)
      indY= range(j-stride,j+stride+1)
      Maux = angles[indX, :][:, indY]
      row= [Enn[i,j], Etn[i,j], Ett[i,j],i,j]
      Y[cnt,:]= row
      X0[cnt,:]= Maux.flatten()
      X1[cnt,:]= angles[i,j]
      cnt= cnt+1
      prog=cnt/ncases*100
# Out:
# n= 199 m= 210

# %%
Y1=Y[:,1]

df = pd.DataFrame({'Angles': X1.flatten()}) 
df['Enn'] = Y[:,0].flatten()
df['Etn'] = Y[:,1].flatten()
df['Ett'] = Y[:,2].flatten()
df['i'] = Y[:,3].flatten()
df['j'] = Y[:,4].flatten()

# %%
df
# Out:
#         Angles       Enn       Etn       Ett      i      j
# 0     1.313459 -0.017009 -0.002484  0.038714   17.0   34.0
# 1     1.313459 -0.016244 -0.003890  0.037659   17.0   35.0
# 2     1.272007 -0.017141 -0.007839  0.037039   17.0   36.0
# 3     1.272007 -0.019593 -0.010020  0.035548   17.0   37.0
# 4     1.272007 -0.022577 -0.014142  0.030379   17.0   38.0
# ...        ...       ...       ...       ...    ...    ...
# 9818  4.195007 -0.004654 -0.005557  0.007156  181.0  159.0
# 9819  4.238703 -0.004897 -0.006364  0.009789  181.0  160.0
# 9820  4.319165 -0.005968 -0.007196  0.012413  181.0  161.0
# 9821  4.319165 -0.006667 -0.009246  0.013235  181.0  162.0
# 9822  4.319165 -0.008136 -0.010317  0.014301  181.0  163.0
#
# [9823 rows x 6 columns]

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ## Added noise

# %%
import numpy as np

def augment_data(angles_arr, enn_arr, etn_arr, ett_arr, noise_stddev, noise_prob):
    angle_aug = []
    enn_aug = []
    etn_aug = []
    ett_aug = []
    for angle, enn, etn, ett in zip(angles_arr, enn_arr, etn_arr, ett_arr):
        noise = np.random.normal(0, noise_stddev)
        augmented_angle_ = angle + noise
        augmented_enn_ = enn + noise
        augmented_etn_ = etn + noise
        augmented_ett_ = ett + noise
        
        angle_aug.append(angle)
        enn_aug.append(enn)
        etn_aug.append(etn)
        ett_aug.append(ett)
        
        if np.random.rand() < noise_prob:
            angle_aug.append(augmented_angle_)
            enn_aug.append(augmented_enn_)
            etn_aug.append(augmented_etn_)
            ett_aug.append(augmented_ett_)

    return np.array(angle_aug), np.array(enn_aug), np.array(etn_aug), np.array(ett_aug)

X = X0
y = df.iloc[:,1:4]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Load your input and target data
angle_data = X_train
enn_data = y_train['Enn']
etn_data = y_train['Etn']
ett_data = y_train['Ett']

# Generate augmented input and target data
augmented_angle_data, augmented_enn_data, augmented_etn_data, augmented_ett_data = augment_data(angle_data, enn_data, etn_data, ett_data, 0.2, 0.3)

X_train_aug = augmented_angle_data
y_train_aug = pd.DataFrame(list(zip(augmented_enn_data,augmented_etn_data,augmented_ett_data)),columns=['Enn','Etn','Ett'])

print(X_train.shape, X_train_aug.shape)
print(y_train.shape, y_train_aug.shape)
# Out:
# (6876, 1225) (8934, 1225)
# (6876, 3) (8934, 3)

# %% [markdown]
# # Model

# %%
# Scaling not augmented data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
print(X_train.shape)

X_test = scaler.transform(X_test)
print(X_test.shape)

# Scaling augmented data
scaler_aug = StandardScaler()
X_train_aug = scaler_aug.fit_transform(X_train_aug)
print(X_train_aug.shape)

X_test_aug = scaler_aug.transform(X_train_aug)
# Out:
# (6876, 1225)
# (2947, 1225)
# (8934, 1225)

# %%
# Import necessary libraries
from sklearn.pipeline import Pipeline
from tensorflow import keras
import numpy as np


model = keras.Sequential([
    keras.layers.Flatten(input_shape=(1225,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dense(3)
])

model_aug = keras.Sequential([
    keras.layers.Flatten(input_shape=(1225,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(128, activation='relu'), 
    keras.layers.Dense(3)  
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
model_aug.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
batch_ = 64
epochs_ = 200
history = model.fit(X_train, y_train, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 86/86 - 1s - loss: 0.0483 - val_loss: 0.0043 - 938ms/epoch - 11ms/step
# Epoch 2/200
# 86/86 - 0s - loss: 0.0025 - val_loss: 0.0022 - 366ms/epoch - 4ms/step
# Epoch 3/200
# 86/86 - 0s - loss: 0.0010 - val_loss: 0.0018 - 425ms/epoch - 5ms/step
# Epoch 4/200
# 86/86 - 0s - loss: 6.1199e-04 - val_loss: 0.0015 - 394ms/epoch - 5ms/step
# Epoch 5/200
# 86/86 - 0s - loss: 4.0723e-04 - val_loss: 0.0014 - 423ms/epoch - 5ms/step
# Epoch 6/200
# 86/86 - 1s - loss: 2.9918e-04 - val_loss: 0.0012 - 517ms/epoch - 6ms/step
# Epoch 7/200
# 86/86 - 0s - loss: 2.2771e-04 - val_loss: 0.0012 - 461ms/epoch - 5ms/step
# Epoch 8/200
# 86/86 - 0s - loss: 1.8499e-04 - val_loss: 0.0012 - 411ms/epoch - 5ms/step
# Epoch 9/200
# 86/86 - 0s - loss: 1.5780e-04 - val_loss: 0.0011 - 384ms/epoch - 4ms/step
# Epoch 10/200
# 86/86 - 0s - loss: 1.3919e-04 - val_loss: 0.0011 - 387ms/epoch - 4ms/step
# Epoch 11/200
# 86/86 - 0s - loss: 1.3214e-04 - val_loss: 0.0010 - 409ms/epoch - 5ms/step
# Epoch 12/200
# 86/86 - 0s - loss: 1.2831e-04 - val_loss: 9.9876e-04 - 392ms/epoch - 5ms/step
# Epoch 13/200
# 86/86 - 0s - loss: 1.2074e-04 - val_loss: 9.4585e-04 - 389ms/epoch - 5ms/step
# Epoch 14/200
# 86/86 - 0s - loss: 1.2745e-04 - val_loss: 9.4466e-04 - 394ms/epoch - 5ms/step
# Epoch 15/200
# 86/86 - 0s - loss: 1.3521e-04 - val_loss: 9.1137e-04 - 386ms/epoch - 4ms/step
# Epoch 16/200
# 86/86 - 0s - loss: 1.5288e-04 - val_loss: 8.5601e-04 - 393ms/epoch - 5ms/step
# Epoch 17/200
# 86/86 - 0s - loss: 1.5093e-04 - val_loss: 8.0367e-04 - 392ms/epoch - 5ms/step
# Epoch 18/200
# 86/86 - 0s - loss: 1.3700e-04 - val_loss: 7.6670e-04 - 391ms/epoch - 5ms/step
# Epoch 19/200
# 86/86 - 0s - loss: 1.2232e-04 - val_loss: 7.1045e-04 - 394ms/epoch - 5ms/step
# Epoch 20/200
# 86/86 - 0s - loss: 1.1214e-04 - val_loss: 6.7566e-04 - 394ms/epoch - 5ms/step
# Epoch 21/200
# 86/86 - 0s - loss: 1.0531e-04 - val_loss: 6.4350e-04 - 396ms/epoch - 5ms/step
# Epoch 22/200
# 86/86 - 0s - loss: 1.0206e-04 - val_loss: 6.2557e-04 - 392ms/epoch - 5ms/step
# Epoch 23/200
# 86/86 - 0s - loss: 9.6088e-05 - val_loss: 6.0542e-04 - 388ms/epoch - 5ms/step
# Epoch 24/200
# 86/86 - 0s - loss: 8.8844e-05 - val_loss: 5.5810e-04 - 390ms/epoch - 5ms/step
# Epoch 25/200
# 86/86 - 0s - loss: 8.7272e-05 - val_loss: 5.5690e-04 - 389ms/epoch - 5ms/step
# Epoch 26/200
# 86/86 - 0s - loss: 8.0466e-05 - val_loss: 5.3007e-04 - 388ms/epoch - 5ms/step
# Epoch 27/200
# 86/86 - 0s - loss: 7.6698e-05 - val_loss: 5.1694e-04 - 389ms/epoch - 5ms/step
# Epoch 28/200
# 86/86 - 0s - loss: 7.4564e-05 - val_loss: 4.8369e-04 - 382ms/epoch - 4ms/step
# Epoch 29/200
# 86/86 - 0s - loss: 8.0197e-05 - val_loss: 4.6863e-04 - 385ms/epoch - 4ms/step
# Epoch 30/200
# 86/86 - 0s - loss: 7.2337e-05 - val_loss: 4.3514e-04 - 396ms/epoch - 5ms/step
# Epoch 31/200
# 86/86 - 0s - loss: 6.8239e-05 - val_loss: 4.2860e-04 - 388ms/epoch - 5ms/step
# Epoch 32/200
# 86/86 - 0s - loss: 6.4604e-05 - val_loss: 4.1215e-04 - 387ms/epoch - 5ms/step
# Epoch 33/200
# 86/86 - 0s - loss: 6.0844e-05 - val_loss: 4.0224e-04 - 391ms/epoch - 5ms/step
# Epoch 34/200
# 86/86 - 0s - loss: 5.8038e-05 - val_loss: 3.7629e-04 - 386ms/epoch - 4ms/step
# Epoch 35/200
# 86/86 - 0s - loss: 5.3370e-05 - val_loss: 3.5645e-04 - 391ms/epoch - 5ms/step
# Epoch 36/200
# 86/86 - 0s - loss: 5.0610e-05 - val_loss: 3.6144e-04 - 389ms/epoch - 5ms/step
# Epoch 37/200
# 86/86 - 0s - loss: 5.0792e-05 - val_loss: 3.3282e-04 - 385ms/epoch - 4ms/step
# Epoch 38/200
# 86/86 - 0s - loss: 5.0071e-05 - val_loss: 3.1614e-04 - 400ms/epoch - 5ms/step
# Epoch 39/200
# 86/86 - 0s - loss: 4.4995e-05 - val_loss: 3.0595e-04 - 387ms/epoch - 5ms/step
# Epoch 40/200
# 86/86 - 0s - loss: 4.4112e-05 - val_loss: 3.0511e-04 - 389ms/epoch - 5ms/step
# Epoch 41/200
# 86/86 - 0s - loss: 4.0813e-05 - val_loss: 2.8585e-04 - 401ms/epoch - 5ms/step
# Epoch 42/200
# 86/86 - 0s - loss: 3.7824e-05 - val_loss: 2.8148e-04 - 387ms/epoch - 4ms/step
# Epoch 43/200
# 86/86 - 0s - loss: 3.7802e-05 - val_loss: 2.6714e-04 - 392ms/epoch - 5ms/step
# Epoch 44/200
# 86/86 - 0s - loss: 3.3897e-05 - val_loss: 2.5622e-04 - 390ms/epoch - 5ms/step
# Epoch 45/200
# 86/86 - 0s - loss: 3.6046e-05 - val_loss: 2.4741e-04 - 390ms/epoch - 5ms/step
# Epoch 46/200
# 86/86 - 0s - loss: 3.1378e-05 - val_loss: 2.4193e-04 - 402ms/epoch - 5ms/step
# Epoch 47/200
# 86/86 - 0s - loss: 2.8943e-05 - val_loss: 2.3565e-04 - 387ms/epoch - 5ms/step
# Epoch 48/200
# 86/86 - 0s - loss: 2.8880e-05 - val_loss: 2.3154e-04 - 387ms/epoch - 4ms/step
# Epoch 49/200
# 86/86 - 0s - loss: 2.6394e-05 - val_loss: 2.2598e-04 - 392ms/epoch - 5ms/step
# Epoch 50/200
# 86/86 - 0s - loss: 2.4260e-05 - val_loss: 2.1966e-04 - 387ms/epoch - 4ms/step
# Epoch 51/200
# 86/86 - 0s - loss: 2.5989e-05 - val_loss: 2.0715e-04 - 390ms/epoch - 5ms/step
# Epoch 52/200
# 86/86 - 0s - loss: 2.5979e-05 - val_loss: 2.0741e-04 - 392ms/epoch - 5ms/step
# Epoch 53/200
# 86/86 - 0s - loss: 2.6784e-05 - val_loss: 2.0332e-04 - 410ms/epoch - 5ms/step
# Epoch 54/200
# 86/86 - 0s - loss: 2.7134e-05 - val_loss: 1.9784e-04 - 400ms/epoch - 5ms/step
# Epoch 55/200
# 86/86 - 0s - loss: 2.8831e-05 - val_loss: 1.9092e-04 - 391ms/epoch - 5ms/step
# Epoch 56/200
# 86/86 - 0s - loss: 3.0053e-05 - val_loss: 1.8083e-04 - 410ms/epoch - 5ms/step
# Epoch 57/200
# 86/86 - 0s - loss: 2.5758e-05 - val_loss: 1.7365e-04 - 396ms/epoch - 5ms/step
# Epoch 58/200
# 86/86 - 0s - loss: 2.3078e-05 - val_loss: 1.6397e-04 - 395ms/epoch - 5ms/step
# Epoch 59/200
# 86/86 - 0s - loss: 2.0609e-05 - val_loss: 1.6588e-04 - 408ms/epoch - 5ms/step
# Epoch 60/200
# 86/86 - 0s - loss: 1.7442e-05 - val_loss: 1.5454e-04 - 409ms/epoch - 5ms/step
# Epoch 61/200
# 86/86 - 0s - loss: 1.6523e-05 - val_loss: 1.5564e-04 - 388ms/epoch - 5ms/step
# Epoch 62/200
# 86/86 - 0s - loss: 1.5780e-05 - val_loss: 1.4644e-04 - 390ms/epoch - 5ms/step
# Epoch 63/200
# 86/86 - 0s - loss: 1.6661e-05 - val_loss: 1.4640e-04 - 397ms/epoch - 5ms/step
# Epoch 64/200
# 86/86 - 0s - loss: 1.6299e-05 - val_loss: 1.4599e-04 - 447ms/epoch - 5ms/step
# Epoch 65/200
# 86/86 - 1s - loss: 1.7738e-05 - val_loss: 1.3709e-04 - 616ms/epoch - 7ms/step
# Epoch 66/200
# 86/86 - 0s - loss: 1.7376e-05 - val_loss: 1.3323e-04 - 423ms/epoch - 5ms/step
# Epoch 67/200
# 86/86 - 0s - loss: 1.7191e-05 - val_loss: 1.2767e-04 - 389ms/epoch - 5ms/step
# Epoch 68/200
# 86/86 - 0s - loss: 1.5254e-05 - val_loss: 1.2907e-04 - 389ms/epoch - 5ms/step
# Epoch 69/200
# 86/86 - 0s - loss: 1.6589e-05 - val_loss: 1.2513e-04 - 387ms/epoch - 5ms/step
# Epoch 70/200
# 86/86 - 0s - loss: 1.5374e-05 - val_loss: 1.1802e-04 - 412ms/epoch - 5ms/step
# Epoch 71/200
# 86/86 - 0s - loss: 1.5845e-05 - val_loss: 1.1422e-04 - 386ms/epoch - 4ms/step
# Epoch 72/200
# 86/86 - 0s - loss: 1.3351e-05 - val_loss: 1.1206e-04 - 396ms/epoch - 5ms/step
# Epoch 73/200
# 86/86 - 0s - loss: 1.2624e-05 - val_loss: 1.0854e-04 - 412ms/epoch - 5ms/step
# Epoch 74/200
# 86/86 - 0s - loss: 1.1899e-05 - val_loss: 1.0558e-04 - 385ms/epoch - 4ms/step
# Epoch 75/200
# 86/86 - 0s - loss: 1.1358e-05 - val_loss: 1.0345e-04 - 399ms/epoch - 5ms/step
# Epoch 76/200
# 86/86 - 0s - loss: 1.0701e-05 - val_loss: 1.0263e-04 - 403ms/epoch - 5ms/step
# Epoch 77/200
# 86/86 - 0s - loss: 1.0779e-05 - val_loss: 9.9247e-05 - 388ms/epoch - 5ms/step
# Epoch 78/200
# 86/86 - 0s - loss: 1.1837e-05 - val_loss: 9.8582e-05 - 389ms/epoch - 5ms/step
# Epoch 79/200
# 86/86 - 0s - loss: 1.3001e-05 - val_loss: 9.6860e-05 - 384ms/epoch - 4ms/step
# Epoch 80/200
# 86/86 - 0s - loss: 1.0885e-05 - val_loss: 9.4247e-05 - 386ms/epoch - 4ms/step
# Epoch 81/200
# 86/86 - 0s - loss: 9.8695e-06 - val_loss: 9.1592e-05 - 388ms/epoch - 5ms/step
# Epoch 82/200
# 86/86 - 0s - loss: 8.9318e-06 - val_loss: 8.8925e-05 - 388ms/epoch - 5ms/step
# Epoch 83/200
# 86/86 - 0s - loss: 1.0126e-05 - val_loss: 8.6311e-05 - 395ms/epoch - 5ms/step
# Epoch 84/200
# 86/86 - 0s - loss: 9.4862e-06 - val_loss: 8.5943e-05 - 392ms/epoch - 5ms/step
# Epoch 85/200
# 86/86 - 0s - loss: 8.7799e-06 - val_loss: 8.2017e-05 - 382ms/epoch - 4ms/step
# Epoch 86/200
# 86/86 - 0s - loss: 8.0259e-06 - val_loss: 8.0926e-05 - 390ms/epoch - 5ms/step
# Epoch 87/200
# 86/86 - 0s - loss: 7.9312e-06 - val_loss: 8.0000e-05 - 386ms/epoch - 4ms/step
# Epoch 88/200
# 86/86 - 0s - loss: 8.2764e-06 - val_loss: 8.0702e-05 - 382ms/epoch - 4ms/step
# Epoch 89/200
# 86/86 - 0s - loss: 9.9836e-06 - val_loss: 7.8745e-05 - 394ms/epoch - 5ms/step
# Epoch 90/200
# 86/86 - 0s - loss: 1.1388e-05 - val_loss: 7.6889e-05 - 390ms/epoch - 5ms/step
# Epoch 91/200
# 86/86 - 0s - loss: 1.0451e-05 - val_loss: 7.5236e-05 - 427ms/epoch - 5ms/step
# Epoch 92/200
# 86/86 - 0s - loss: 9.3460e-06 - val_loss: 6.7181e-05 - 389ms/epoch - 5ms/step
# Epoch 93/200
# 86/86 - 0s - loss: 1.0000e-05 - val_loss: 6.8907e-05 - 389ms/epoch - 5ms/step
# Epoch 94/200
# 86/86 - 0s - loss: 9.5988e-06 - val_loss: 6.5492e-05 - 392ms/epoch - 5ms/step
# Epoch 95/200
# 86/86 - 0s - loss: 7.7059e-06 - val_loss: 6.2378e-05 - 383ms/epoch - 4ms/step
# Epoch 96/200
# 86/86 - 0s - loss: 6.4832e-06 - val_loss: 6.1797e-05 - 387ms/epoch - 4ms/step
# Epoch 97/200
# 86/86 - 0s - loss: 7.2004e-06 - val_loss: 6.4397e-05 - 395ms/epoch - 5ms/step
# Epoch 98/200
# 86/86 - 0s - loss: 7.6237e-06 - val_loss: 6.4176e-05 - 391ms/epoch - 5ms/step
# Epoch 99/200
# 86/86 - 0s - loss: 8.9969e-06 - val_loss: 5.9737e-05 - 385ms/epoch - 4ms/step
# Epoch 100/200
# 86/86 - 0s - loss: 9.0188e-06 - val_loss: 5.9769e-05 - 391ms/epoch - 5ms/step
# Epoch 101/200
# 86/86 - 0s - loss: 9.5011e-06 - val_loss: 5.6201e-05 - 385ms/epoch - 4ms/step
# Epoch 102/200
# 86/86 - 0s - loss: 1.1138e-05 - val_loss: 5.4817e-05 - 400ms/epoch - 5ms/step
# Epoch 103/200
# 86/86 - 0s - loss: 1.6151e-05 - val_loss: 5.9731e-05 - 392ms/epoch - 5ms/step
# Epoch 104/200
# 86/86 - 0s - loss: 1.5515e-05 - val_loss: 5.1241e-05 - 389ms/epoch - 5ms/step
# Epoch 105/200
# 86/86 - 0s - loss: 9.6215e-06 - val_loss: 4.8816e-05 - 397ms/epoch - 5ms/step
# Epoch 106/200
# 86/86 - 0s - loss: 7.8857e-06 - val_loss: 4.6082e-05 - 389ms/epoch - 5ms/step
# Epoch 107/200
# 86/86 - 0s - loss: 5.6805e-06 - val_loss: 4.4916e-05 - 388ms/epoch - 5ms/step
# Epoch 108/200
# 86/86 - 0s - loss: 4.1485e-06 - val_loss: 4.4037e-05 - 394ms/epoch - 5ms/step
# Epoch 109/200
# 86/86 - 0s - loss: 3.6313e-06 - val_loss: 4.3859e-05 - 388ms/epoch - 5ms/step
# Epoch 110/200
# 86/86 - 0s - loss: 2.9661e-06 - val_loss: 4.3282e-05 - 400ms/epoch - 5ms/step
# Epoch 111/200
# 86/86 - 0s - loss: 2.6395e-06 - val_loss: 4.2825e-05 - 388ms/epoch - 5ms/step
# Epoch 112/200
# 86/86 - 0s - loss: 2.6356e-06 - val_loss: 4.3075e-05 - 386ms/epoch - 4ms/step
# Epoch 113/200
# 86/86 - 0s - loss: 2.7265e-06 - val_loss: 4.2223e-05 - 392ms/epoch - 5ms/step
# Epoch 114/200
# 86/86 - 0s - loss: 2.8102e-06 - val_loss: 4.2408e-05 - 387ms/epoch - 4ms/step
# Epoch 115/200
# 86/86 - 0s - loss: 2.8388e-06 - val_loss: 4.1953e-05 - 387ms/epoch - 4ms/step
# Epoch 116/200
# 86/86 - 0s - loss: 2.8958e-06 - val_loss: 4.1992e-05 - 392ms/epoch - 5ms/step
# Epoch 117/200
# 86/86 - 0s - loss: 3.0645e-06 - val_loss: 4.1548e-05 - 387ms/epoch - 4ms/step
# Epoch 118/200
# 86/86 - 0s - loss: 6.0832e-06 - val_loss: 4.6482e-05 - 389ms/epoch - 5ms/step
# Epoch 119/200
# 86/86 - 0s - loss: 9.0999e-06 - val_loss: 4.3807e-05 - 403ms/epoch - 5ms/step
# Epoch 120/200
# 86/86 - 0s - loss: 8.7804e-06 - val_loss: 4.2606e-05 - 395ms/epoch - 5ms/step
# Epoch 121/200
# 86/86 - 0s - loss: 1.0087e-05 - val_loss: 4.4524e-05 - 429ms/epoch - 5ms/step
# Epoch 122/200
# 86/86 - 0s - loss: 1.1305e-05 - val_loss: 3.9284e-05 - 439ms/epoch - 5ms/step
# Epoch 123/200
# 86/86 - 0s - loss: 7.9758e-06 - val_loss: 3.8986e-05 - 453ms/epoch - 5ms/step
# Epoch 124/200
# 86/86 - 0s - loss: 6.7131e-06 - val_loss: 3.7152e-05 - 400ms/epoch - 5ms/step
# Epoch 125/200
# 86/86 - 0s - loss: 4.8852e-06 - val_loss: 3.6576e-05 - 393ms/epoch - 5ms/step
# Epoch 126/200
# 86/86 - 0s - loss: 3.8466e-06 - val_loss: 3.5761e-05 - 459ms/epoch - 5ms/step
# Epoch 127/200
# 86/86 - 0s - loss: 3.1591e-06 - val_loss: 3.4856e-05 - 406ms/epoch - 5ms/step
# Epoch 128/200
# 86/86 - 0s - loss: 2.8652e-06 - val_loss: 3.3435e-05 - 410ms/epoch - 5ms/step
# Epoch 129/200
# 86/86 - 0s - loss: 2.7985e-06 - val_loss: 3.4336e-05 - 396ms/epoch - 5ms/step
# Epoch 130/200
# 86/86 - 0s - loss: 2.4770e-06 - val_loss: 3.3331e-05 - 386ms/epoch - 4ms/step
# Epoch 131/200
# 86/86 - 0s - loss: 2.4433e-06 - val_loss: 3.3189e-05 - 415ms/epoch - 5ms/step
# Epoch 132/200
# 86/86 - 0s - loss: 2.8228e-06 - val_loss: 3.2963e-05 - 405ms/epoch - 5ms/step
# Epoch 133/200
# 86/86 - 0s - loss: 2.8607e-06 - val_loss: 3.2910e-05 - 382ms/epoch - 4ms/step
# Epoch 134/200
# 86/86 - 0s - loss: 3.3182e-06 - val_loss: 3.3334e-05 - 401ms/epoch - 5ms/step
# Epoch 135/200
# 86/86 - 0s - loss: 3.9686e-06 - val_loss: 3.4470e-05 - 397ms/epoch - 5ms/step
# Epoch 136/200
# 86/86 - 0s - loss: 3.9080e-06 - val_loss: 3.2564e-05 - 390ms/epoch - 5ms/step
# Epoch 137/200
# 86/86 - 0s - loss: 4.3734e-06 - val_loss: 3.2216e-05 - 393ms/epoch - 5ms/step
# Epoch 138/200
# 86/86 - 0s - loss: 4.5822e-06 - val_loss: 3.3030e-05 - 400ms/epoch - 5ms/step
# Epoch 139/200
# 86/86 - 1s - loss: 4.4849e-06 - val_loss: 3.3705e-05 - 529ms/epoch - 6ms/step
# Epoch 140/200
# 86/86 - 0s - loss: 4.8405e-06 - val_loss: 3.4047e-05 - 414ms/epoch - 5ms/step
# Epoch 141/200
# 86/86 - 0s - loss: 5.5590e-06 - val_loss: 3.2872e-05 - 384ms/epoch - 4ms/step
# Epoch 142/200
# 86/86 - 0s - loss: 7.6206e-06 - val_loss: 3.5073e-05 - 399ms/epoch - 5ms/step
# Epoch 143/200
# 86/86 - 0s - loss: 4.1938e-05 - val_loss: 1.1001e-04 - 387ms/epoch - 4ms/step
# Epoch 144/200
# 86/86 - 0s - loss: 6.9598e-05 - val_loss: 5.3041e-05 - 386ms/epoch - 4ms/step
# Epoch 145/200
# 86/86 - 0s - loss: 3.5812e-05 - val_loss: 4.3790e-05 - 394ms/epoch - 5ms/step
# Epoch 146/200
# 86/86 - 0s - loss: 2.2051e-05 - val_loss: 3.3467e-05 - 391ms/epoch - 5ms/step
# Epoch 147/200
# 86/86 - 0s - loss: 1.5403e-05 - val_loss: 3.1646e-05 - 395ms/epoch - 5ms/step
# Epoch 148/200
# 86/86 - 0s - loss: 1.2261e-05 - val_loss: 2.8194e-05 - 410ms/epoch - 5ms/step
# Epoch 149/200
# 86/86 - 0s - loss: 9.8574e-06 - val_loss: 2.6188e-05 - 382ms/epoch - 4ms/step
# Epoch 150/200
# 86/86 - 0s - loss: 8.0474e-06 - val_loss: 2.6720e-05 - 395ms/epoch - 5ms/step
# Epoch 151/200
# 86/86 - 0s - loss: 7.2843e-06 - val_loss: 2.6560e-05 - 385ms/epoch - 4ms/step
# Epoch 152/200
# 86/86 - 0s - loss: 6.3561e-06 - val_loss: 2.5056e-05 - 480ms/epoch - 6ms/step
# Epoch 153/200
# 86/86 - 0s - loss: 5.6221e-06 - val_loss: 2.4565e-05 - 461ms/epoch - 5ms/step
# Epoch 154/200
# 86/86 - 0s - loss: 4.9601e-06 - val_loss: 2.4213e-05 - 390ms/epoch - 5ms/step
# Epoch 155/200
# 86/86 - 0s - loss: 4.7731e-06 - val_loss: 2.4728e-05 - 396ms/epoch - 5ms/step
# Epoch 156/200
# 86/86 - 0s - loss: 4.4275e-06 - val_loss: 2.4205e-05 - 386ms/epoch - 4ms/step
# Epoch 157/200
# 86/86 - 0s - loss: 3.8618e-06 - val_loss: 2.3126e-05 - 390ms/epoch - 5ms/step
# Epoch 158/200
# 86/86 - 0s - loss: 3.3548e-06 - val_loss: 2.3590e-05 - 395ms/epoch - 5ms/step
# Epoch 159/200
# 86/86 - 0s - loss: 3.2917e-06 - val_loss: 2.3682e-05 - 386ms/epoch - 4ms/step
# Epoch 160/200
# 86/86 - 0s - loss: 3.2929e-06 - val_loss: 2.3083e-05 - 391ms/epoch - 5ms/step
# Epoch 161/200
# 86/86 - 0s - loss: 3.0637e-06 - val_loss: 2.3333e-05 - 392ms/epoch - 5ms/step
# Epoch 162/200
# 86/86 - 0s - loss: 3.8095e-06 - val_loss: 2.3455e-05 - 389ms/epoch - 5ms/step
# Epoch 163/200
# 86/86 - 0s - loss: 4.0704e-06 - val_loss: 2.2884e-05 - 392ms/epoch - 5ms/step
# Epoch 164/200
# 86/86 - 0s - loss: 3.5219e-06 - val_loss: 2.2884e-05 - 418ms/epoch - 5ms/step
# Epoch 165/200
# 86/86 - 0s - loss: 3.1631e-06 - val_loss: 2.3596e-05 - 456ms/epoch - 5ms/step
# Epoch 166/200
# 86/86 - 0s - loss: 2.8620e-06 - val_loss: 2.2882e-05 - 448ms/epoch - 5ms/step
# Epoch 167/200
# 86/86 - 0s - loss: 3.2182e-06 - val_loss: 2.4294e-05 - 404ms/epoch - 5ms/step
# Epoch 168/200
# 86/86 - 0s - loss: 3.6924e-06 - val_loss: 2.4372e-05 - 390ms/epoch - 5ms/step
# Epoch 169/200
# 86/86 - 0s - loss: 3.5380e-06 - val_loss: 2.3696e-05 - 392ms/epoch - 5ms/step
# Epoch 170/200
# 86/86 - 0s - loss: 3.7561e-06 - val_loss: 2.2587e-05 - 387ms/epoch - 4ms/step
# Epoch 171/200
# 86/86 - 0s - loss: 3.5334e-06 - val_loss: 2.3569e-05 - 397ms/epoch - 5ms/step
# Epoch 172/200
# 86/86 - 0s - loss: 3.0866e-06 - val_loss: 2.3319e-05 - 391ms/epoch - 5ms/step
# Epoch 173/200
# 86/86 - 0s - loss: 2.8666e-06 - val_loss: 2.2346e-05 - 386ms/epoch - 4ms/step
# Epoch 174/200
# 86/86 - 0s - loss: 3.1900e-06 - val_loss: 2.3781e-05 - 390ms/epoch - 5ms/step
# Epoch 175/200
# 86/86 - 0s - loss: 4.5477e-06 - val_loss: 2.9386e-05 - 387ms/epoch - 4ms/step
# Epoch 176/200
# 86/86 - 0s - loss: 7.6991e-06 - val_loss: 2.4307e-05 - 391ms/epoch - 5ms/step
# Epoch 177/200
# 86/86 - 0s - loss: 7.3697e-06 - val_loss: 2.5641e-05 - 395ms/epoch - 5ms/step
# Epoch 178/200
# 86/86 - 0s - loss: 6.8791e-06 - val_loss: 2.4484e-05 - 386ms/epoch - 4ms/step
# Epoch 179/200
# 86/86 - 0s - loss: 5.0728e-06 - val_loss: 2.2826e-05 - 393ms/epoch - 5ms/step
# Epoch 180/200
# 86/86 - 0s - loss: 3.7014e-06 - val_loss: 2.1884e-05 - 390ms/epoch - 5ms/step
# Epoch 181/200
# 86/86 - 0s - loss: 2.9267e-06 - val_loss: 2.1618e-05 - 387ms/epoch - 4ms/step
# Epoch 182/200
# 86/86 - 0s - loss: 2.8284e-06 - val_loss: 2.1681e-05 - 393ms/epoch - 5ms/step
# Epoch 183/200
# 86/86 - 0s - loss: 2.2658e-06 - val_loss: 2.0774e-05 - 384ms/epoch - 4ms/step
# Epoch 184/200
# 86/86 - 0s - loss: 1.9713e-06 - val_loss: 2.0449e-05 - 390ms/epoch - 5ms/step
# Epoch 185/200
# 86/86 - 0s - loss: 1.8821e-06 - val_loss: 2.1248e-05 - 393ms/epoch - 5ms/step
# Epoch 186/200
# 86/86 - 0s - loss: 2.0095e-06 - val_loss: 2.0286e-05 - 388ms/epoch - 5ms/step
# Epoch 187/200
# 86/86 - 0s - loss: 1.7955e-06 - val_loss: 2.1203e-05 - 390ms/epoch - 5ms/step
# Epoch 188/200
# 86/86 - 0s - loss: 1.7950e-06 - val_loss: 2.0386e-05 - 391ms/epoch - 5ms/step
# Epoch 189/200
# 86/86 - 0s - loss: 1.4405e-06 - val_loss: 2.0546e-05 - 388ms/epoch - 5ms/step
# Epoch 190/200
# 86/86 - 0s - loss: 1.3318e-05 - val_loss: 6.2818e-05 - 396ms/epoch - 5ms/step
# Epoch 191/200
# 86/86 - 0s - loss: 3.3846e-05 - val_loss: 4.1449e-05 - 382ms/epoch - 4ms/step
# Epoch 192/200
# 86/86 - 0s - loss: 1.6399e-05 - val_loss: 2.9169e-05 - 393ms/epoch - 5ms/step
# Epoch 193/200
# 86/86 - 0s - loss: 9.8958e-06 - val_loss: 2.4751e-05 - 392ms/epoch - 5ms/step
# Epoch 194/200
# 86/86 - 0s - loss: 5.8151e-06 - val_loss: 2.3768e-05 - 389ms/epoch - 5ms/step
# Epoch 195/200
# 86/86 - 0s - loss: 4.8885e-06 - val_loss: 2.2046e-05 - 391ms/epoch - 5ms/step
# Epoch 196/200
# 86/86 - 0s - loss: 3.7549e-06 - val_loss: 2.1657e-05 - 389ms/epoch - 5ms/step
# Epoch 197/200
# 86/86 - 0s - loss: 2.9297e-06 - val_loss: 2.1361e-05 - 389ms/epoch - 5ms/step
# Epoch 198/200
# 86/86 - 0s - loss: 2.8379e-06 - val_loss: 2.1192e-05 - 390ms/epoch - 5ms/step
# Epoch 199/200
# 86/86 - 0s - loss: 2.3501e-06 - val_loss: 2.1481e-05 - 388ms/epoch - 5ms/step
# Epoch 200/200
# 86/86 - 0s - loss: 2.1980e-06 - val_loss: 2.1144e-05 - 388ms/epoch - 5ms/step

# %%
history_aug = model_aug.fit(X_train_aug, y_train_aug, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 112/112 - 1s - loss: 0.0479 - val_loss: 0.0110 - 981ms/epoch - 9ms/step
# Epoch 2/200
# 112/112 - 1s - loss: 0.0062 - val_loss: 0.0076 - 772ms/epoch - 7ms/step
# Epoch 3/200
# 112/112 - 1s - loss: 0.0037 - val_loss: 0.0059 - 684ms/epoch - 6ms/step
# Epoch 4/200
# 112/112 - 1s - loss: 0.0025 - val_loss: 0.0052 - 710ms/epoch - 6ms/step
# Epoch 5/200
# 112/112 - 0s - loss: 0.0019 - val_loss: 0.0045 - 497ms/epoch - 4ms/step
# Epoch 6/200
# 112/112 - 0s - loss: 0.0016 - val_loss: 0.0043 - 491ms/epoch - 4ms/step
# Epoch 7/200
# 112/112 - 0s - loss: 0.0014 - val_loss: 0.0039 - 490ms/epoch - 4ms/step
# Epoch 8/200
# 112/112 - 1s - loss: 0.0011 - val_loss: 0.0039 - 526ms/epoch - 5ms/step
# Epoch 9/200
# 112/112 - 1s - loss: 0.0012 - val_loss: 0.0036 - 682ms/epoch - 6ms/step
# Epoch 10/200
# 112/112 - 1s - loss: 0.0012 - val_loss: 0.0032 - 517ms/epoch - 5ms/step
# Epoch 11/200
# 112/112 - 1s - loss: 0.0010 - val_loss: 0.0030 - 612ms/epoch - 5ms/step
# Epoch 12/200
# 112/112 - 0s - loss: 8.7314e-04 - val_loss: 0.0031 - 485ms/epoch - 4ms/step
# Epoch 13/200
# 112/112 - 1s - loss: 7.9103e-04 - val_loss: 0.0026 - 614ms/epoch - 5ms/step
# Epoch 14/200
# 112/112 - 1s - loss: 7.7290e-04 - val_loss: 0.0028 - 510ms/epoch - 5ms/step
# Epoch 15/200
# 112/112 - 1s - loss: 7.5497e-04 - val_loss: 0.0025 - 656ms/epoch - 6ms/step
# Epoch 16/200
# 112/112 - 0s - loss: 7.7839e-04 - val_loss: 0.0027 - 484ms/epoch - 4ms/step
# Epoch 17/200
# 112/112 - 1s - loss: 7.5375e-04 - val_loss: 0.0025 - 561ms/epoch - 5ms/step
# Epoch 18/200
# 112/112 - 1s - loss: 6.6877e-04 - val_loss: 0.0025 - 542ms/epoch - 5ms/step
# Epoch 19/200
# 112/112 - 0s - loss: 6.2260e-04 - val_loss: 0.0024 - 488ms/epoch - 4ms/step
# Epoch 20/200
# 112/112 - 0s - loss: 6.4177e-04 - val_loss: 0.0024 - 492ms/epoch - 4ms/step
# Epoch 21/200
# 112/112 - 0s - loss: 5.9947e-04 - val_loss: 0.0022 - 482ms/epoch - 4ms/step
# Epoch 22/200
# 112/112 - 0s - loss: 5.9043e-04 - val_loss: 0.0022 - 492ms/epoch - 4ms/step
# Epoch 23/200
# 112/112 - 0s - loss: 5.9798e-04 - val_loss: 0.0021 - 498ms/epoch - 4ms/step
# Epoch 24/200
# 112/112 - 0s - loss: 5.8590e-04 - val_loss: 0.0022 - 485ms/epoch - 4ms/step
# Epoch 25/200
# 112/112 - 0s - loss: 5.7306e-04 - val_loss: 0.0019 - 499ms/epoch - 4ms/step
# Epoch 26/200
# 112/112 - 0s - loss: 5.2014e-04 - val_loss: 0.0019 - 478ms/epoch - 4ms/step
# Epoch 27/200
# 112/112 - 0s - loss: 5.2871e-04 - val_loss: 0.0019 - 488ms/epoch - 4ms/step
# Epoch 28/200
# 112/112 - 0s - loss: 4.5509e-04 - val_loss: 0.0019 - 479ms/epoch - 4ms/step
# Epoch 29/200
# 112/112 - 0s - loss: 4.1552e-04 - val_loss: 0.0018 - 485ms/epoch - 4ms/step
# Epoch 30/200
# 112/112 - 0s - loss: 3.8176e-04 - val_loss: 0.0017 - 480ms/epoch - 4ms/step
# Epoch 31/200
# 112/112 - 0s - loss: 4.0391e-04 - val_loss: 0.0017 - 483ms/epoch - 4ms/step
# Epoch 32/200
# 112/112 - 1s - loss: 3.9639e-04 - val_loss: 0.0018 - 518ms/epoch - 5ms/step
# Epoch 33/200
# 112/112 - 1s - loss: 4.7982e-04 - val_loss: 0.0017 - 664ms/epoch - 6ms/step
# Epoch 34/200
# 112/112 - 1s - loss: 5.0791e-04 - val_loss: 0.0016 - 783ms/epoch - 7ms/step
# Epoch 35/200
# 112/112 - 1s - loss: 5.6880e-04 - val_loss: 0.0018 - 670ms/epoch - 6ms/step
# Epoch 36/200
# 112/112 - 1s - loss: 5.6711e-04 - val_loss: 0.0018 - 814ms/epoch - 7ms/step
# Epoch 37/200
# 112/112 - 1s - loss: 5.4520e-04 - val_loss: 0.0016 - 568ms/epoch - 5ms/step
# Epoch 38/200
# 112/112 - 1s - loss: 4.7642e-04 - val_loss: 0.0017 - 603ms/epoch - 5ms/step
# Epoch 39/200
# 112/112 - 1s - loss: 5.2026e-04 - val_loss: 0.0017 - 556ms/epoch - 5ms/step
# Epoch 40/200
# 112/112 - 1s - loss: 4.9968e-04 - val_loss: 0.0017 - 651ms/epoch - 6ms/step
# Epoch 41/200
# 112/112 - 1s - loss: 4.3132e-04 - val_loss: 0.0015 - 590ms/epoch - 5ms/step
# Epoch 42/200
# 112/112 - 1s - loss: 4.1096e-04 - val_loss: 0.0016 - 598ms/epoch - 5ms/step
# Epoch 43/200
# 112/112 - 1s - loss: 4.0235e-04 - val_loss: 0.0015 - 574ms/epoch - 5ms/step
# Epoch 44/200
# 112/112 - 0s - loss: 3.3530e-04 - val_loss: 0.0014 - 480ms/epoch - 4ms/step
# Epoch 45/200
# 112/112 - 1s - loss: 3.1618e-04 - val_loss: 0.0014 - 600ms/epoch - 5ms/step
# Epoch 46/200
# 112/112 - 1s - loss: 3.7922e-04 - val_loss: 0.0015 - 636ms/epoch - 6ms/step
# Epoch 47/200
# 112/112 - 1s - loss: 3.1774e-04 - val_loss: 0.0013 - 630ms/epoch - 6ms/step
# Epoch 48/200
# 112/112 - 1s - loss: 3.8913e-04 - val_loss: 0.0014 - 738ms/epoch - 7ms/step
# Epoch 49/200
# 112/112 - 1s - loss: 4.0468e-04 - val_loss: 0.0014 - 540ms/epoch - 5ms/step
# Epoch 50/200
# 112/112 - 1s - loss: 3.8546e-04 - val_loss: 0.0013 - 743ms/epoch - 7ms/step
# Epoch 51/200
# 112/112 - 1s - loss: 3.8591e-04 - val_loss: 0.0013 - 710ms/epoch - 6ms/step
# Epoch 52/200
# 112/112 - 1s - loss: 3.8617e-04 - val_loss: 0.0013 - 632ms/epoch - 6ms/step
# Epoch 53/200
# 112/112 - 1s - loss: 4.1074e-04 - val_loss: 0.0013 - 589ms/epoch - 5ms/step
# Epoch 54/200
# 112/112 - 0s - loss: 3.7980e-04 - val_loss: 0.0012 - 480ms/epoch - 4ms/step
# Epoch 55/200
# 112/112 - 1s - loss: 3.3845e-04 - val_loss: 0.0012 - 502ms/epoch - 4ms/step
# Epoch 56/200
# 112/112 - 0s - loss: 4.4673e-04 - val_loss: 0.0013 - 485ms/epoch - 4ms/step
# Epoch 57/200
# 112/112 - 0s - loss: 4.2463e-04 - val_loss: 0.0013 - 487ms/epoch - 4ms/step
# Epoch 58/200
# 112/112 - 1s - loss: 3.8265e-04 - val_loss: 0.0013 - 504ms/epoch - 5ms/step
# Epoch 59/200
# 112/112 - 1s - loss: 3.4740e-04 - val_loss: 0.0012 - 501ms/epoch - 4ms/step
# Epoch 60/200
# 112/112 - 0s - loss: 3.4115e-04 - val_loss: 0.0011 - 490ms/epoch - 4ms/step
# Epoch 61/200
# 112/112 - 0s - loss: 4.0287e-04 - val_loss: 0.0012 - 483ms/epoch - 4ms/step
# Epoch 62/200
# 112/112 - 0s - loss: 3.8699e-04 - val_loss: 0.0012 - 489ms/epoch - 4ms/step
# Epoch 63/200
# 112/112 - 0s - loss: 3.1704e-04 - val_loss: 0.0011 - 494ms/epoch - 4ms/step
# Epoch 64/200
# 112/112 - 1s - loss: 3.3174e-04 - val_loss: 0.0013 - 539ms/epoch - 5ms/step
# Epoch 65/200
# 112/112 - 0s - loss: 3.8503e-04 - val_loss: 0.0012 - 486ms/epoch - 4ms/step
# Epoch 66/200
# 112/112 - 0s - loss: 4.0715e-04 - val_loss: 0.0011 - 485ms/epoch - 4ms/step
# Epoch 67/200
# 112/112 - 0s - loss: 3.4400e-04 - val_loss: 0.0012 - 481ms/epoch - 4ms/step
# Epoch 68/200
# 112/112 - 1s - loss: 4.0136e-04 - val_loss: 0.0011 - 640ms/epoch - 6ms/step
# Epoch 69/200
# 112/112 - 0s - loss: 3.6470e-04 - val_loss: 0.0015 - 469ms/epoch - 4ms/step
# Epoch 70/200
# 112/112 - 0s - loss: 3.7323e-04 - val_loss: 0.0010 - 490ms/epoch - 4ms/step
# Epoch 71/200
# 112/112 - 0s - loss: 4.0368e-04 - val_loss: 0.0011 - 482ms/epoch - 4ms/step
# Epoch 72/200
# 112/112 - 0s - loss: 4.6691e-04 - val_loss: 0.0012 - 492ms/epoch - 4ms/step
# Epoch 73/200
# 112/112 - 0s - loss: 5.9649e-04 - val_loss: 0.0018 - 487ms/epoch - 4ms/step
# Epoch 74/200
# 112/112 - 0s - loss: 6.8650e-04 - val_loss: 0.0012 - 483ms/epoch - 4ms/step
# Epoch 75/200
# 112/112 - 0s - loss: 5.1955e-04 - val_loss: 0.0013 - 484ms/epoch - 4ms/step
# Epoch 76/200
# 112/112 - 0s - loss: 5.0247e-04 - val_loss: 0.0013 - 480ms/epoch - 4ms/step
# Epoch 77/200
# 112/112 - 0s - loss: 3.8251e-04 - val_loss: 0.0010 - 486ms/epoch - 4ms/step
# Epoch 78/200
# 112/112 - 0s - loss: 2.5789e-04 - val_loss: 0.0010 - 490ms/epoch - 4ms/step
# Epoch 79/200
# 112/112 - 0s - loss: 2.4043e-04 - val_loss: 8.9753e-04 - 497ms/epoch - 4ms/step
# Epoch 80/200
# 112/112 - 0s - loss: 3.0666e-04 - val_loss: 9.4074e-04 - 488ms/epoch - 4ms/step
# Epoch 81/200
# 112/112 - 0s - loss: 2.6539e-04 - val_loss: 0.0010 - 485ms/epoch - 4ms/step
# Epoch 82/200
# 112/112 - 0s - loss: 2.0797e-04 - val_loss: 9.3334e-04 - 481ms/epoch - 4ms/step
# Epoch 83/200
# 112/112 - 0s - loss: 2.1784e-04 - val_loss: 9.2994e-04 - 488ms/epoch - 4ms/step
# Epoch 84/200
# 112/112 - 0s - loss: 1.7709e-04 - val_loss: 0.0010 - 483ms/epoch - 4ms/step
# Epoch 85/200
# 112/112 - 0s - loss: 1.6096e-04 - val_loss: 9.2028e-04 - 483ms/epoch - 4ms/step
# Epoch 86/200
# 112/112 - 0s - loss: 1.3173e-04 - val_loss: 8.3416e-04 - 482ms/epoch - 4ms/step
# Epoch 87/200
# 112/112 - 0s - loss: 1.2542e-04 - val_loss: 8.5934e-04 - 479ms/epoch - 4ms/step
# Epoch 88/200
# 112/112 - 0s - loss: 1.5970e-04 - val_loss: 8.9631e-04 - 484ms/epoch - 4ms/step
# Epoch 89/200
# 112/112 - 1s - loss: 1.8472e-04 - val_loss: 8.9221e-04 - 523ms/epoch - 5ms/step
# Epoch 90/200
# 112/112 - 0s - loss: 2.2399e-04 - val_loss: 9.1734e-04 - 487ms/epoch - 4ms/step
# Epoch 91/200
# 112/112 - 1s - loss: 2.4525e-04 - val_loss: 9.2729e-04 - 699ms/epoch - 6ms/step
# Epoch 92/200
# 112/112 - 1s - loss: 2.5396e-04 - val_loss: 0.0010 - 673ms/epoch - 6ms/step
# Epoch 93/200
# 112/112 - 1s - loss: 4.0111e-04 - val_loss: 0.0013 - 559ms/epoch - 5ms/step
# Epoch 94/200
# 112/112 - 1s - loss: 4.0522e-04 - val_loss: 0.0012 - 662ms/epoch - 6ms/step
# Epoch 95/200
# 112/112 - 1s - loss: 4.5794e-04 - val_loss: 0.0014 - 528ms/epoch - 5ms/step
# Epoch 96/200
# 112/112 - 1s - loss: 4.1633e-04 - val_loss: 0.0012 - 524ms/epoch - 5ms/step
# Epoch 97/200
# 112/112 - 1s - loss: 3.8719e-04 - val_loss: 0.0010 - 515ms/epoch - 5ms/step
# Epoch 98/200
# 112/112 - 1s - loss: 2.7794e-04 - val_loss: 0.0012 - 504ms/epoch - 4ms/step
# Epoch 99/200
# 112/112 - 1s - loss: 2.0367e-04 - val_loss: 8.8260e-04 - 513ms/epoch - 5ms/step
# Epoch 100/200
# 112/112 - 1s - loss: 1.6701e-04 - val_loss: 0.0011 - 502ms/epoch - 4ms/step
# Epoch 101/200
# 112/112 - 1s - loss: 1.7724e-04 - val_loss: 0.0011 - 517ms/epoch - 5ms/step
# Epoch 102/200
# 112/112 - 1s - loss: 2.1029e-04 - val_loss: 9.0902e-04 - 502ms/epoch - 4ms/step
# Epoch 103/200
# 112/112 - 1s - loss: 2.2014e-04 - val_loss: 9.7330e-04 - 516ms/epoch - 5ms/step
# Epoch 104/200
# 112/112 - 1s - loss: 2.3517e-04 - val_loss: 9.4832e-04 - 505ms/epoch - 5ms/step
# Epoch 105/200
# 112/112 - 1s - loss: 1.8265e-04 - val_loss: 8.8460e-04 - 510ms/epoch - 5ms/step
# Epoch 106/200
# 112/112 - 1s - loss: 1.5206e-04 - val_loss: 9.2678e-04 - 504ms/epoch - 5ms/step
# Epoch 107/200
# 112/112 - 1s - loss: 1.2282e-04 - val_loss: 8.6971e-04 - 513ms/epoch - 5ms/step
# Epoch 108/200
# 112/112 - 1s - loss: 1.1184e-04 - val_loss: 8.0219e-04 - 503ms/epoch - 4ms/step
# Epoch 109/200
# 112/112 - 1s - loss: 1.3016e-04 - val_loss: 8.8749e-04 - 506ms/epoch - 5ms/step
# Epoch 110/200
# 112/112 - 1s - loss: 1.4701e-04 - val_loss: 8.9649e-04 - 506ms/epoch - 5ms/step
# Epoch 111/200
# 112/112 - 1s - loss: 1.5502e-04 - val_loss: 9.7364e-04 - 503ms/epoch - 4ms/step
# Epoch 112/200
# 112/112 - 1s - loss: 1.9027e-04 - val_loss: 8.4724e-04 - 513ms/epoch - 5ms/step
# Epoch 113/200
# 112/112 - 1s - loss: 2.3503e-04 - val_loss: 0.0014 - 503ms/epoch - 4ms/step
# Epoch 114/200
# 112/112 - 1s - loss: 3.7775e-04 - val_loss: 9.4006e-04 - 511ms/epoch - 5ms/step
# Epoch 115/200
# 112/112 - 0s - loss: 3.8682e-04 - val_loss: 0.0013 - 500ms/epoch - 4ms/step
# Epoch 116/200
# 112/112 - 1s - loss: 3.5487e-04 - val_loss: 0.0011 - 517ms/epoch - 5ms/step
# Epoch 117/200
# 112/112 - 0s - loss: 2.6299e-04 - val_loss: 0.0011 - 498ms/epoch - 4ms/step
# Epoch 118/200
# 112/112 - 1s - loss: 2.2578e-04 - val_loss: 9.3765e-04 - 513ms/epoch - 5ms/step
# Epoch 119/200
# 112/112 - 0s - loss: 1.9046e-04 - val_loss: 9.7782e-04 - 499ms/epoch - 4ms/step
# Epoch 120/200
# 112/112 - 1s - loss: 1.5180e-04 - val_loss: 8.1870e-04 - 510ms/epoch - 5ms/step
# Epoch 121/200
# 112/112 - 1s - loss: 1.3898e-04 - val_loss: 8.3112e-04 - 503ms/epoch - 4ms/step
# Epoch 122/200
# 112/112 - 1s - loss: 1.5395e-04 - val_loss: 8.5040e-04 - 510ms/epoch - 5ms/step
# Epoch 123/200
# 112/112 - 1s - loss: 1.4149e-04 - val_loss: 7.8200e-04 - 503ms/epoch - 4ms/step
# Epoch 124/200
# 112/112 - 1s - loss: 1.2947e-04 - val_loss: 8.4785e-04 - 510ms/epoch - 5ms/step
# Epoch 125/200
# 112/112 - 1s - loss: 1.4636e-04 - val_loss: 0.0010 - 513ms/epoch - 5ms/step
# Epoch 126/200
# 112/112 - 1s - loss: 1.5109e-04 - val_loss: 9.6560e-04 - 510ms/epoch - 5ms/step
# Epoch 127/200
# 112/112 - 1s - loss: 1.6923e-04 - val_loss: 8.4594e-04 - 526ms/epoch - 5ms/step
# Epoch 128/200
# 112/112 - 1s - loss: 1.3641e-04 - val_loss: 8.3739e-04 - 660ms/epoch - 6ms/step
# Epoch 129/200
# 112/112 - 0s - loss: 1.2393e-04 - val_loss: 0.0011 - 491ms/epoch - 4ms/step
# Epoch 130/200
# 112/112 - 1s - loss: 1.1901e-04 - val_loss: 8.1379e-04 - 506ms/epoch - 5ms/step
# Epoch 131/200
# 112/112 - 1s - loss: 1.0364e-04 - val_loss: 8.5658e-04 - 504ms/epoch - 4ms/step
# Epoch 132/200
# 112/112 - 1s - loss: 1.3774e-04 - val_loss: 9.2805e-04 - 506ms/epoch - 5ms/step
# Epoch 133/200
# 112/112 - 1s - loss: 1.7581e-04 - val_loss: 9.4832e-04 - 502ms/epoch - 4ms/step
# Epoch 134/200
# 112/112 - 1s - loss: 2.4278e-04 - val_loss: 0.0011 - 507ms/epoch - 5ms/step
# Epoch 135/200
# 112/112 - 0s - loss: 2.4513e-04 - val_loss: 8.5920e-04 - 498ms/epoch - 4ms/step
# Epoch 136/200
# 112/112 - 1s - loss: 1.8407e-04 - val_loss: 9.2617e-04 - 505ms/epoch - 5ms/step
# Epoch 137/200
# 112/112 - 1s - loss: 1.4183e-04 - val_loss: 0.0011 - 544ms/epoch - 5ms/step
# Epoch 138/200
# 112/112 - 1s - loss: 1.7878e-04 - val_loss: 8.7486e-04 - 511ms/epoch - 5ms/step
# Epoch 139/200
# 112/112 - 1s - loss: 2.5984e-04 - val_loss: 0.0015 - 503ms/epoch - 4ms/step
# Epoch 140/200
# 112/112 - 1s - loss: 4.1392e-04 - val_loss: 9.5118e-04 - 504ms/epoch - 5ms/step
# Epoch 141/200
# 112/112 - 1s - loss: 2.9332e-04 - val_loss: 8.4978e-04 - 503ms/epoch - 4ms/step
# Epoch 142/200
# 112/112 - 1s - loss: 2.1224e-04 - val_loss: 9.2223e-04 - 504ms/epoch - 5ms/step
# Epoch 143/200
# 112/112 - 1s - loss: 1.7305e-04 - val_loss: 8.6711e-04 - 508ms/epoch - 5ms/step
# Epoch 144/200
# 112/112 - 0s - loss: 1.3146e-04 - val_loss: 8.5373e-04 - 498ms/epoch - 4ms/step
# Epoch 145/200
# 112/112 - 1s - loss: 1.0496e-04 - val_loss: 8.3820e-04 - 509ms/epoch - 5ms/step
# Epoch 146/200
# 112/112 - 1s - loss: 9.3199e-05 - val_loss: 8.8318e-04 - 511ms/epoch - 5ms/step
# Epoch 147/200
# 112/112 - 1s - loss: 8.8526e-05 - val_loss: 8.3347e-04 - 670ms/epoch - 6ms/step
# Epoch 148/200
# 112/112 - 0s - loss: 8.2965e-05 - val_loss: 8.4768e-04 - 493ms/epoch - 4ms/step
# Epoch 149/200
# 112/112 - 1s - loss: 9.8902e-05 - val_loss: 8.2829e-04 - 518ms/epoch - 5ms/step
# Epoch 150/200
# 112/112 - 1s - loss: 1.0471e-04 - val_loss: 7.4921e-04 - 511ms/epoch - 5ms/step
# Epoch 151/200
# 112/112 - 1s - loss: 1.0237e-04 - val_loss: 9.0519e-04 - 516ms/epoch - 5ms/step
# Epoch 152/200
# 112/112 - 1s - loss: 1.0844e-04 - val_loss: 8.1095e-04 - 504ms/epoch - 5ms/step
# Epoch 153/200
# 112/112 - 1s - loss: 1.0519e-04 - val_loss: 8.2897e-04 - 514ms/epoch - 5ms/step
# Epoch 154/200
# 112/112 - 1s - loss: 1.0639e-04 - val_loss: 7.8755e-04 - 502ms/epoch - 4ms/step
# Epoch 155/200
# 112/112 - 1s - loss: 2.0995e-04 - val_loss: 8.9780e-04 - 513ms/epoch - 5ms/step
# Epoch 156/200
# 112/112 - 0s - loss: 2.9147e-04 - val_loss: 9.3698e-04 - 500ms/epoch - 4ms/step
# Epoch 157/200
# 112/112 - 1s - loss: 2.6255e-04 - val_loss: 9.0629e-04 - 516ms/epoch - 5ms/step
# Epoch 158/200
# 112/112 - 1s - loss: 1.8024e-04 - val_loss: 8.6320e-04 - 503ms/epoch - 4ms/step
# Epoch 159/200
# 112/112 - 1s - loss: 1.6954e-04 - val_loss: 8.3278e-04 - 516ms/epoch - 5ms/step
# Epoch 160/200
# 112/112 - 1s - loss: 1.8954e-04 - val_loss: 9.6005e-04 - 503ms/epoch - 4ms/step
# Epoch 161/200
# 112/112 - 1s - loss: 1.4860e-04 - val_loss: 7.9660e-04 - 600ms/epoch - 5ms/step
# Epoch 162/200
# 112/112 - 1s - loss: 1.2248e-04 - val_loss: 7.9912e-04 - 563ms/epoch - 5ms/step
# Epoch 163/200
# 112/112 - 1s - loss: 9.5945e-05 - val_loss: 8.2724e-04 - 566ms/epoch - 5ms/step
# Epoch 164/200
# 112/112 - 1s - loss: 7.5897e-05 - val_loss: 8.1296e-04 - 554ms/epoch - 5ms/step
# Epoch 165/200
# 112/112 - 1s - loss: 6.2523e-05 - val_loss: 7.6436e-04 - 559ms/epoch - 5ms/step
# Epoch 166/200
# 112/112 - 1s - loss: 4.8417e-05 - val_loss: 7.5692e-04 - 552ms/epoch - 5ms/step
# Epoch 167/200
# 112/112 - 1s - loss: 5.2507e-05 - val_loss: 8.0402e-04 - 561ms/epoch - 5ms/step
# Epoch 168/200
# 112/112 - 1s - loss: 5.2880e-05 - val_loss: 7.3510e-04 - 553ms/epoch - 5ms/step
# Epoch 169/200
# 112/112 - 1s - loss: 6.5496e-05 - val_loss: 8.8740e-04 - 606ms/epoch - 5ms/step
# Epoch 170/200
# 112/112 - 1s - loss: 6.8202e-05 - val_loss: 7.9454e-04 - 557ms/epoch - 5ms/step
# Epoch 171/200
# 112/112 - 1s - loss: 9.4164e-05 - val_loss: 8.7429e-04 - 551ms/epoch - 5ms/step
# Epoch 172/200
# 112/112 - 1s - loss: 1.6280e-04 - val_loss: 7.6446e-04 - 549ms/epoch - 5ms/step
# Epoch 173/200
# 112/112 - 1s - loss: 2.1429e-04 - val_loss: 8.1862e-04 - 548ms/epoch - 5ms/step
# Epoch 174/200
# 112/112 - 1s - loss: 1.8030e-04 - val_loss: 9.6055e-04 - 563ms/epoch - 5ms/step
# Epoch 175/200
# 112/112 - 1s - loss: 2.8980e-04 - val_loss: 9.9811e-04 - 579ms/epoch - 5ms/step
# Epoch 176/200
# 112/112 - 1s - loss: 2.5539e-04 - val_loss: 8.5378e-04 - 557ms/epoch - 5ms/step
# Epoch 177/200
# 112/112 - 1s - loss: 1.7117e-04 - val_loss: 8.6176e-04 - 564ms/epoch - 5ms/step
# Epoch 178/200
# 112/112 - 1s - loss: 1.1819e-04 - val_loss: 7.5467e-04 - 637ms/epoch - 6ms/step
# Epoch 179/200
# 112/112 - 1s - loss: 9.9190e-05 - val_loss: 7.9296e-04 - 636ms/epoch - 6ms/step
# Epoch 180/200
# 112/112 - 1s - loss: 8.7534e-05 - val_loss: 8.8162e-04 - 681ms/epoch - 6ms/step
# Epoch 181/200
# 112/112 - 1s - loss: 8.1030e-05 - val_loss: 8.6225e-04 - 611ms/epoch - 5ms/step
# Epoch 182/200
# 112/112 - 1s - loss: 7.0815e-05 - val_loss: 7.8990e-04 - 622ms/epoch - 6ms/step
# Epoch 183/200
# 112/112 - 1s - loss: 5.9367e-05 - val_loss: 7.2404e-04 - 595ms/epoch - 5ms/step
# Epoch 184/200
# 112/112 - 1s - loss: 5.5765e-05 - val_loss: 7.5530e-04 - 861ms/epoch - 8ms/step
# Epoch 185/200
# 112/112 - 1s - loss: 5.1897e-05 - val_loss: 9.1264e-04 - 651ms/epoch - 6ms/step
# Epoch 186/200
# 112/112 - 1s - loss: 9.1934e-05 - val_loss: 7.7496e-04 - 521ms/epoch - 5ms/step
# Epoch 187/200
# 112/112 - 1s - loss: 1.1371e-04 - val_loss: 8.3596e-04 - 517ms/epoch - 5ms/step
# Epoch 188/200
# 112/112 - 1s - loss: 1.3041e-04 - val_loss: 8.5669e-04 - 532ms/epoch - 5ms/step
# Epoch 189/200
# 112/112 - 1s - loss: 2.0147e-04 - val_loss: 9.4541e-04 - 526ms/epoch - 5ms/step
# Epoch 190/200
# 112/112 - 1s - loss: 1.9993e-04 - val_loss: 9.5907e-04 - 504ms/epoch - 5ms/step
# Epoch 191/200
# 112/112 - 1s - loss: 1.5474e-04 - val_loss: 7.6627e-04 - 532ms/epoch - 5ms/step
# Epoch 192/200
# 112/112 - 1s - loss: 1.2912e-04 - val_loss: 7.4941e-04 - 518ms/epoch - 5ms/step
# Epoch 193/200
# 112/112 - 1s - loss: 1.0445e-04 - val_loss: 7.8025e-04 - 534ms/epoch - 5ms/step
# Epoch 194/200
# 112/112 - 1s - loss: 8.7592e-05 - val_loss: 7.2692e-04 - 504ms/epoch - 4ms/step
# Epoch 195/200
# 112/112 - 1s - loss: 6.6688e-05 - val_loss: 7.2711e-04 - 522ms/epoch - 5ms/step
# Epoch 196/200
# 112/112 - 1s - loss: 6.0187e-05 - val_loss: 6.5787e-04 - 508ms/epoch - 5ms/step
# Epoch 197/200
# 112/112 - 1s - loss: 6.3601e-05 - val_loss: 7.0216e-04 - 556ms/epoch - 5ms/step
# Epoch 198/200
# 112/112 - 1s - loss: 5.7441e-05 - val_loss: 8.2803e-04 - 568ms/epoch - 5ms/step
# Epoch 199/200
# 112/112 - 1s - loss: 7.8259e-05 - val_loss: 7.0824e-04 - 504ms/epoch - 4ms/step
# Epoch 200/200
# 112/112 - 1s - loss: 7.7336e-05 - val_loss: 7.1127e-04 - 519ms/epoch - 5ms/step

# %%
# Extraia os valores de loss do histórico
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Non Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Extraia os valores de loss do histórico
train_loss = history_aug.history['loss']
val_loss = history_aug.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_hat = model.predict(X_test)
print(y_hat.shape)

y_hat_aug = model_aug.predict(X_test)
print(y_hat_aug.shape)
# Out:
# 93/93 [==============================] - 0s 1ms/step
# (2947, 3)
# 93/93 [==============================] - 0s 2ms/step
# (2947, 3)

# %%
PredDF = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat,columns=['yh1','yh2','yh3'])],axis=1)

PredDF_aug = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat_aug,columns=['yh1','yh2','yh3'])],axis=1)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Correlation

# %%
PredDF.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.932796 -0.093865 -0.509920
# y2 -0.119439  0.931351  0.141688
# y3 -0.530994  0.107206  0.945580

# %%
PredDF_aug.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.709882 -0.100154 -0.417788
# y2 -0.120661  0.688320  0.056625
# y3 -0.372382  0.132423  0.733563

# %% [markdown]
# ## R2

# %%
print('Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF['y1'], PredDF['yh1']))
print('')
print('')
# plt.scatter(PredDF['y1'], PredDF['yh1'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF['y2'], PredDF['yh2']))
print('')
print('')
# plt.scatter(PredDF['y2'], PredDF['yh2'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF['y3'], PredDF['yh3']))
print('')
print('')
# plt.scatter(PredDF['y3'], PredDF['yh3'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()


print('PredDF_aug: Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF_aug['y1'], PredDF_aug['yh1']))
print('')
print('')
# plt.scatter(PredDF_aug['y1'], PredDF_aug['yh1'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF_aug['y2'], PredDF_aug['yh2']))
print('')
print('')
# plt.scatter(PredDF_aug['y2'], PredDF_aug['yh2'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF_aug['y3'], PredDF_aug['yh3']))
# print('')
# print('')
# plt.scatter(PredDF_aug['y3'], PredDF_aug['yh3'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()
# Out:
# Resultados Holdout Enn
#
# 0.868786371038481
#
#
# Resultados Holdout Etn
#
# 0.8645521103711359
#
#
# Resultados Holdout Ett
#
# 0.8931185028314536
#
#
# PredDF_aug: Resultados Holdout Enn
#
# 0.27936089780879825
#
#
# PredDF_aug: Resultados Holdout Etn
#
# 0.19082902292332393
#
#
# PredDF_aug: Resultados Holdout Ett
#
# 0.33333262860586566

# %% [markdown]
# # Back to .mat

# %%
ind_tr1= y_test.Enn
ind_tr2= y_test.Etn
ind_tr3= y_test.Ett
y_test.loc[ind_tr1.index,'Enn'] = y_hat[:,0]
y_test.loc[ind_tr2.index,'Etn'] = y_hat[:,1]
y_test.loc[ind_tr3.index,'Ett'] = y_hat[:,2]

ind_tr1_aug= y_test.Enn
ind_tr2_aug= y_test.Etn
ind_tr3_aug= y_test.Ett
y_test.loc[ind_tr1_aug.index,'Enn'] = y_hat_aug[:,0]
y_test.loc[ind_tr2_aug.index,'Etn'] = y_hat_aug[:,1]
y_test.loc[ind_tr3_aug.index,'Ett'] = y_hat_aug[:,2]

# %%
ind_tes1= y_test.Enn
ind_tes2= y_test.Etn
ind_tes3= y_test.Ett
df.loc[ind_tes1.index,'Enn'] = y_test.Enn
df.loc[ind_tes2.index,'Etn'] = y_test.Etn
df.loc[ind_tes3.index,'Ett'] = y_test.Ett

df_aug = df
ind_tes1_aug= y_test.Enn
ind_tes2_aug= y_test.Etn
ind_tes3_aug= y_test.Ett
df_aug.loc[ind_tes1_aug.index,'Enn'] = y_test.Enn
df_aug.loc[ind_tes2_aug.index,'Etn'] = y_test.Etn
df_aug.loc[ind_tes3_aug.index,'Ett'] = y_test.Ett

# %%
display(df[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
display(df_aug[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df.iloc[a,4]
    j=df.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df.iloc[a,1]
    df2.iloc[ind,2]=df.iloc[a,2]
    df2.iloc[ind,3]=df.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100

Enn_MLP_35=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35.mat', {'Enn_MLP_35': Enn_MLP_35}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35.mat', {'Etn_MLP_35': Etn_MLP_35})
spio.savemat('Ett_MLP_35.mat', {'Ett_MLP_35': Ett_MLP_35})
# Out:
# n1= 199 m1= 210
# ncases= 41790

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df_aug.iloc[a,4]
    j=df_aug.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df_aug.iloc[a,1]
    df2.iloc[ind,2]=df_aug.iloc[a,2]
    df2.iloc[ind,3]=df_aug.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100
    
Enn_MLP_35_aug=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35_aug=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35_aug=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35_aug.mat', {'Enn_MLP_35_aug': Enn_MLP_35_aug}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35_aug.mat', {'Etn_MLP_35_aug': Etn_MLP_35_aug})
spio.savemat('Ett_MLP_35_aug.mat', {'Ett_MLP_35_aug': Ett_MLP_35_aug})
# Out:
# n1= 199 m1= 210
# ncases= 41790
