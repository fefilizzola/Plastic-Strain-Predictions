# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.io as sio
from scipy import io as spio
from tqdm import tqdm
import cv2
from sklearn import metrics


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Split Data

# %%
def tic():
    #Homemade version of matlab tic and toc functions
    import time
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    import time
    if 'startTime_for_tictoc' in globals():
        print ('\nElapsed time is ')
        print (str(time.time() - startTime_for_tictoc))
        print('seconds.\n')
    else:
        print ('\nToc: start time not set\n')

# %%
data= sio.loadmat('/Users/fernanda/Documents/Tese_Mestrado/GitHub/Plastic-Strain-Predictions/data/Sample_1/RDM_Sample_1.mat')
angles= data['RDM']['angles'][0][0]
Enn= data['RDM']['Strains'][0][0][0][0][5]
Etn= data['RDM']['Strains'][0][0][0][0][4]
Ett= data['RDM']['Strains'][0][0][0][0][3]
CM= data['RDM']['CM'][0][0]

indPred= CM==1
wndSize= 35
n,m = angles.shape

print('n=', n , 'm=', m )

stride= int((wndSize-1)/2)
ncases= sum(sum(CM[stride:n-stride,stride:m-stride]==1))

Y= np.zeros((ncases,5))
X0= np.zeros((ncases, wndSize**2))
X1= np.zeros((ncases,1))

cnt=0
for i in range(0+stride,n-stride):
  for j in range(0+stride,m-stride):
    if CM[i,j] == 1:
      indX= range(i-stride,i+stride+1)
      indY= range(j-stride,j+stride+1)
      Maux = angles[indX, :][:, indY]
      row= [Enn[i,j], Etn[i,j], Ett[i,j],i,j]
      Y[cnt,:]= row
      X0[cnt,:]= Maux.flatten()
      X1[cnt,:]= angles[i,j]
      cnt= cnt+1
      prog=cnt/ncases*100
# Out:
# n= 199 m= 210

# %%
Y1=Y[:,1]

df = pd.DataFrame({'Angles': X1.flatten()}) 
df['Enn'] = Y[:,0].flatten()
df['Etn'] = Y[:,1].flatten()
df['Ett'] = Y[:,2].flatten()
df['i'] = Y[:,3].flatten()
df['j'] = Y[:,4].flatten()

# %%
df
# Out:
#         Angles       Enn       Etn       Ett      i      j
# 0     1.313459 -0.017009 -0.002484  0.038714   17.0   34.0
# 1     1.313459 -0.016244 -0.003890  0.037659   17.0   35.0
# 2     1.272007 -0.017141 -0.007839  0.037039   17.0   36.0
# 3     1.272007 -0.019593 -0.010020  0.035548   17.0   37.0
# 4     1.272007 -0.022577 -0.014142  0.030379   17.0   38.0
# ...        ...       ...       ...       ...    ...    ...
# 9818  4.195007 -0.004654 -0.005557  0.007156  181.0  159.0
# 9819  4.238703 -0.004897 -0.006364  0.009789  181.0  160.0
# 9820  4.319165 -0.005968 -0.007196  0.012413  181.0  161.0
# 9821  4.319165 -0.006667 -0.009246  0.013235  181.0  162.0
# 9822  4.319165 -0.008136 -0.010317  0.014301  181.0  163.0
#
# [9823 rows x 6 columns]

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ## Added noise

# %%
import numpy as np

def augment_data(angles_arr, enn_arr, etn_arr, ett_arr, noise_stddev, noise_prob):
    angle_aug = []
    enn_aug = []
    etn_aug = []
    ett_aug = []
    for angle, enn, etn, ett in zip(angles_arr, enn_arr, etn_arr, ett_arr):
        noise = np.random.normal(0, noise_stddev)
        augmented_angle_ = angle + noise
        augmented_enn_ = enn + noise
        augmented_etn_ = etn + noise
        augmented_ett_ = ett + noise
        
        angle_aug.append(angle)
        enn_aug.append(enn)
        etn_aug.append(etn)
        ett_aug.append(ett)
        
        if np.random.rand() < noise_prob:
            angle_aug.append(augmented_angle_)
            enn_aug.append(augmented_enn_)
            etn_aug.append(augmented_etn_)
            ett_aug.append(augmented_ett_)

    return np.array(angle_aug), np.array(enn_aug), np.array(etn_aug), np.array(ett_aug)

X = X0
y = df.iloc[:,1:4]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Load your input and target data
angle_data = X_train
enn_data = y_train['Enn']
etn_data = y_train['Etn']
ett_data = y_train['Ett']

# Generate augmented input and target data
augmented_angle_data, augmented_enn_data, augmented_etn_data, augmented_ett_data = augment_data(angle_data, enn_data, etn_data, ett_data, 0.2, 0.3)

X_train_aug = augmented_angle_data
y_train_aug = pd.DataFrame(list(zip(augmented_enn_data,augmented_etn_data,augmented_ett_data)),columns=['Enn','Etn','Ett'])

print(X_train.shape, X_train_aug.shape)
print(y_train.shape, y_train_aug.shape)
# Out:
# (6876, 1225) (8939, 1225)
# (6876, 3) (8939, 3)

# %% [markdown]
# # Model

# %%
# Scaling not augmented data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
print(X_train.shape)

X_test = scaler.transform(X_test)
print(X_test.shape)

# Scaling augmented data
scaler_aug = StandardScaler()
X_train_aug = scaler_aug.fit_transform(X_train_aug)
print(X_train_aug.shape)

X_test_aug = scaler_aug.transform(X_train_aug)
# Out:
# (6876, 1225)
# (2947, 1225)
# (8939, 1225)

# %%
# Import necessary libraries
from sklearn.pipeline import Pipeline
from tensorflow import keras
import numpy as np


model = keras.Sequential([
    keras.layers.Flatten(input_shape=(1225,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dense(3)
])

model_aug = keras.Sequential([
    keras.layers.Flatten(input_shape=(1225,)),  
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dense(128, activation='relu'), 
    keras.layers.Dense(3)  
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
model_aug.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
batch_ = 64
epochs_ = 200
history = model.fit(X_train, y_train, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 86/86 - 1s - loss: 0.0508 - val_loss: 0.0050 - 714ms/epoch - 8ms/step
# Epoch 2/200
# 86/86 - 0s - loss: 0.0029 - val_loss: 0.0027 - 351ms/epoch - 4ms/step
# Epoch 3/200
# 86/86 - 0s - loss: 0.0012 - val_loss: 0.0020 - 352ms/epoch - 4ms/step
# Epoch 4/200
# 86/86 - 0s - loss: 6.8365e-04 - val_loss: 0.0018 - 399ms/epoch - 5ms/step
# Epoch 5/200
# 86/86 - 0s - loss: 4.4679e-04 - val_loss: 0.0016 - 420ms/epoch - 5ms/step
# Epoch 6/200
# 86/86 - 0s - loss: 3.1342e-04 - val_loss: 0.0016 - 424ms/epoch - 5ms/step
# Epoch 7/200
# 86/86 - 0s - loss: 2.4647e-04 - val_loss: 0.0015 - 389ms/epoch - 5ms/step
# Epoch 8/200
# 86/86 - 0s - loss: 1.9372e-04 - val_loss: 0.0014 - 374ms/epoch - 4ms/step
# Epoch 9/200
# 86/86 - 0s - loss: 1.6211e-04 - val_loss: 0.0014 - 388ms/epoch - 5ms/step
# Epoch 10/200
# 86/86 - 0s - loss: 1.3947e-04 - val_loss: 0.0013 - 378ms/epoch - 4ms/step
# Epoch 11/200
# 86/86 - 0s - loss: 1.3040e-04 - val_loss: 0.0013 - 377ms/epoch - 4ms/step
# Epoch 12/200
# 86/86 - 0s - loss: 1.3972e-04 - val_loss: 0.0013 - 382ms/epoch - 4ms/step
# Epoch 13/200
# 86/86 - 0s - loss: 1.5916e-04 - val_loss: 0.0012 - 382ms/epoch - 4ms/step
# Epoch 14/200
# 86/86 - 0s - loss: 1.6066e-04 - val_loss: 0.0012 - 380ms/epoch - 4ms/step
# Epoch 15/200
# 86/86 - 0s - loss: 1.5028e-04 - val_loss: 0.0011 - 380ms/epoch - 4ms/step
# Epoch 16/200
# 86/86 - 0s - loss: 1.6190e-04 - val_loss: 0.0011 - 376ms/epoch - 4ms/step
# Epoch 17/200
# 86/86 - 0s - loss: 1.5919e-04 - val_loss: 0.0010 - 384ms/epoch - 4ms/step
# Epoch 18/200
# 86/86 - 0s - loss: 1.6945e-04 - val_loss: 0.0010 - 378ms/epoch - 4ms/step
# Epoch 19/200
# 86/86 - 0s - loss: 1.6692e-04 - val_loss: 9.3801e-04 - 376ms/epoch - 4ms/step
# Epoch 20/200
# 86/86 - 0s - loss: 1.5003e-04 - val_loss: 8.5629e-04 - 385ms/epoch - 4ms/step
# Epoch 21/200
# 86/86 - 0s - loss: 1.3631e-04 - val_loss: 8.2608e-04 - 372ms/epoch - 4ms/step
# Epoch 22/200
# 86/86 - 0s - loss: 1.2976e-04 - val_loss: 7.6856e-04 - 486ms/epoch - 6ms/step
# Epoch 23/200
# 86/86 - 0s - loss: 1.2986e-04 - val_loss: 7.1116e-04 - 369ms/epoch - 4ms/step
# Epoch 24/200
# 86/86 - 0s - loss: 1.2005e-04 - val_loss: 6.9734e-04 - 384ms/epoch - 4ms/step
# Epoch 25/200
# 86/86 - 0s - loss: 1.1952e-04 - val_loss: 6.7861e-04 - 385ms/epoch - 4ms/step
# Epoch 26/200
# 86/86 - 0s - loss: 1.0242e-04 - val_loss: 6.3151e-04 - 383ms/epoch - 4ms/step
# Epoch 27/200
# 86/86 - 0s - loss: 1.0133e-04 - val_loss: 6.0772e-04 - 379ms/epoch - 4ms/step
# Epoch 28/200
# 86/86 - 0s - loss: 9.9655e-05 - val_loss: 5.4804e-04 - 388ms/epoch - 5ms/step
# Epoch 29/200
# 86/86 - 0s - loss: 8.9425e-05 - val_loss: 5.2381e-04 - 405ms/epoch - 5ms/step
# Epoch 30/200
# 86/86 - 0s - loss: 8.4125e-05 - val_loss: 5.1295e-04 - 379ms/epoch - 4ms/step
# Epoch 31/200
# 86/86 - 0s - loss: 7.5256e-05 - val_loss: 5.0020e-04 - 385ms/epoch - 4ms/step
# Epoch 32/200
# 86/86 - 0s - loss: 6.6304e-05 - val_loss: 4.6768e-04 - 380ms/epoch - 4ms/step
# Epoch 33/200
# 86/86 - 0s - loss: 6.3864e-05 - val_loss: 4.7613e-04 - 388ms/epoch - 5ms/step
# Epoch 34/200
# 86/86 - 0s - loss: 6.3355e-05 - val_loss: 4.4401e-04 - 381ms/epoch - 4ms/step
# Epoch 35/200
# 86/86 - 0s - loss: 6.2439e-05 - val_loss: 4.2355e-04 - 379ms/epoch - 4ms/step
# Epoch 36/200
# 86/86 - 0s - loss: 5.8046e-05 - val_loss: 4.1042e-04 - 384ms/epoch - 4ms/step
# Epoch 37/200
# 86/86 - 0s - loss: 5.9482e-05 - val_loss: 4.0079e-04 - 383ms/epoch - 4ms/step
# Epoch 38/200
# 86/86 - 0s - loss: 5.8999e-05 - val_loss: 3.7329e-04 - 399ms/epoch - 5ms/step
# Epoch 39/200
# 86/86 - 0s - loss: 6.1743e-05 - val_loss: 3.6504e-04 - 485ms/epoch - 6ms/step
# Epoch 40/200
# 86/86 - 0s - loss: 5.9520e-05 - val_loss: 3.3537e-04 - 366ms/epoch - 4ms/step
# Epoch 41/200
# 86/86 - 0s - loss: 5.6815e-05 - val_loss: 3.2415e-04 - 382ms/epoch - 4ms/step
# Epoch 42/200
# 86/86 - 0s - loss: 5.7222e-05 - val_loss: 3.1231e-04 - 396ms/epoch - 5ms/step
# Epoch 43/200
# 86/86 - 0s - loss: 5.5684e-05 - val_loss: 2.9391e-04 - 379ms/epoch - 4ms/step
# Epoch 44/200
# 86/86 - 0s - loss: 4.8151e-05 - val_loss: 2.8905e-04 - 378ms/epoch - 4ms/step
# Epoch 45/200
# 86/86 - 0s - loss: 4.3965e-05 - val_loss: 2.7350e-04 - 382ms/epoch - 4ms/step
# Epoch 46/200
# 86/86 - 0s - loss: 4.2377e-05 - val_loss: 2.5763e-04 - 376ms/epoch - 4ms/step
# Epoch 47/200
# 86/86 - 0s - loss: 3.9591e-05 - val_loss: 2.4986e-04 - 384ms/epoch - 4ms/step
# Epoch 48/200
# 86/86 - 0s - loss: 3.7679e-05 - val_loss: 2.4308e-04 - 379ms/epoch - 4ms/step
# Epoch 49/200
# 86/86 - 0s - loss: 3.4396e-05 - val_loss: 2.3460e-04 - 380ms/epoch - 4ms/step
# Epoch 50/200
# 86/86 - 0s - loss: 3.0123e-05 - val_loss: 2.2555e-04 - 383ms/epoch - 4ms/step
# Epoch 51/200
# 86/86 - 0s - loss: 3.2451e-05 - val_loss: 2.2338e-04 - 376ms/epoch - 4ms/step
# Epoch 52/200
# 86/86 - 0s - loss: 3.6472e-05 - val_loss: 2.1649e-04 - 376ms/epoch - 4ms/step
# Epoch 53/200
# 86/86 - 0s - loss: 3.3130e-05 - val_loss: 2.0282e-04 - 382ms/epoch - 4ms/step
# Epoch 54/200
# 86/86 - 0s - loss: 2.9909e-05 - val_loss: 1.9923e-04 - 378ms/epoch - 4ms/step
# Epoch 55/200
# 86/86 - 0s - loss: 2.9756e-05 - val_loss: 1.9204e-04 - 382ms/epoch - 4ms/step
# Epoch 56/200
# 86/86 - 0s - loss: 2.9301e-05 - val_loss: 1.9400e-04 - 379ms/epoch - 4ms/step
# Epoch 57/200
# 86/86 - 0s - loss: 2.8550e-05 - val_loss: 1.8165e-04 - 480ms/epoch - 6ms/step
# Epoch 58/200
# 86/86 - 0s - loss: 2.8923e-05 - val_loss: 1.8757e-04 - 367ms/epoch - 4ms/step
# Epoch 59/200
# 86/86 - 0s - loss: 3.0952e-05 - val_loss: 1.8103e-04 - 383ms/epoch - 4ms/step
# Epoch 60/200
# 86/86 - 0s - loss: 3.0942e-05 - val_loss: 1.6633e-04 - 375ms/epoch - 4ms/step
# Epoch 61/200
# 86/86 - 0s - loss: 3.1032e-05 - val_loss: 1.5116e-04 - 383ms/epoch - 4ms/step
# Epoch 62/200
# 86/86 - 0s - loss: 2.7260e-05 - val_loss: 1.4271e-04 - 378ms/epoch - 4ms/step
# Epoch 63/200
# 86/86 - 0s - loss: 2.4221e-05 - val_loss: 1.4743e-04 - 375ms/epoch - 4ms/step
# Epoch 64/200
# 86/86 - 0s - loss: 2.4301e-05 - val_loss: 1.3471e-04 - 383ms/epoch - 4ms/step
# Epoch 65/200
# 86/86 - 0s - loss: 2.2928e-05 - val_loss: 1.3485e-04 - 376ms/epoch - 4ms/step
# Epoch 66/200
# 86/86 - 0s - loss: 2.0718e-05 - val_loss: 1.2660e-04 - 381ms/epoch - 4ms/step
# Epoch 67/200
# 86/86 - 0s - loss: 1.8422e-05 - val_loss: 1.2823e-04 - 383ms/epoch - 4ms/step
# Epoch 68/200
# 86/86 - 0s - loss: 1.9361e-05 - val_loss: 1.2715e-04 - 380ms/epoch - 4ms/step
# Epoch 69/200
# 86/86 - 0s - loss: 2.0899e-05 - val_loss: 1.2507e-04 - 381ms/epoch - 4ms/step
# Epoch 70/200
# 86/86 - 0s - loss: 2.1867e-05 - val_loss: 1.1734e-04 - 381ms/epoch - 4ms/step
# Epoch 71/200
# 86/86 - 0s - loss: 2.1741e-05 - val_loss: 1.1567e-04 - 376ms/epoch - 4ms/step
# Epoch 72/200
# 86/86 - 0s - loss: 2.2924e-05 - val_loss: 1.0809e-04 - 461ms/epoch - 5ms/step
# Epoch 73/200
# 86/86 - 0s - loss: 2.3724e-05 - val_loss: 1.0643e-04 - 388ms/epoch - 5ms/step
# Epoch 74/200
# 86/86 - 0s - loss: 2.3801e-05 - val_loss: 9.8667e-05 - 371ms/epoch - 4ms/step
# Epoch 75/200
# 86/86 - 0s - loss: 2.1828e-05 - val_loss: 9.6424e-05 - 383ms/epoch - 4ms/step
# Epoch 76/200
# 86/86 - 0s - loss: 1.8071e-05 - val_loss: 9.4922e-05 - 379ms/epoch - 4ms/step
# Epoch 77/200
# 86/86 - 0s - loss: 1.5956e-05 - val_loss: 9.5070e-05 - 375ms/epoch - 4ms/step
# Epoch 78/200
# 86/86 - 0s - loss: 1.7748e-05 - val_loss: 8.6454e-05 - 381ms/epoch - 4ms/step
# Epoch 79/200
# 86/86 - 0s - loss: 1.7480e-05 - val_loss: 8.7194e-05 - 382ms/epoch - 4ms/step
# Epoch 80/200
# 86/86 - 0s - loss: 1.7377e-05 - val_loss: 8.3710e-05 - 383ms/epoch - 4ms/step
# Epoch 81/200
# 86/86 - 0s - loss: 1.3577e-05 - val_loss: 8.1264e-05 - 379ms/epoch - 4ms/step
# Epoch 82/200
# 86/86 - 0s - loss: 1.2630e-05 - val_loss: 8.1316e-05 - 376ms/epoch - 4ms/step
# Epoch 83/200
# 86/86 - 0s - loss: 1.1986e-05 - val_loss: 7.9929e-05 - 382ms/epoch - 4ms/step
# Epoch 84/200
# 86/86 - 0s - loss: 1.0788e-05 - val_loss: 7.5811e-05 - 378ms/epoch - 4ms/step
# Epoch 85/200
# 86/86 - 0s - loss: 1.0481e-05 - val_loss: 7.4505e-05 - 385ms/epoch - 4ms/step
# Epoch 86/200
# 86/86 - 0s - loss: 1.1853e-05 - val_loss: 8.1892e-05 - 386ms/epoch - 4ms/step
# Epoch 87/200
# 86/86 - 0s - loss: 1.5565e-05 - val_loss: 7.2553e-05 - 380ms/epoch - 4ms/step
# Epoch 88/200
# 86/86 - 0s - loss: 1.5011e-05 - val_loss: 7.2314e-05 - 482ms/epoch - 6ms/step
# Epoch 89/200
# 86/86 - 0s - loss: 1.4756e-05 - val_loss: 6.8515e-05 - 370ms/epoch - 4ms/step
# Epoch 90/200
# 86/86 - 0s - loss: 1.5715e-05 - val_loss: 6.7694e-05 - 377ms/epoch - 4ms/step
# Epoch 91/200
# 86/86 - 0s - loss: 1.4326e-05 - val_loss: 6.3572e-05 - 382ms/epoch - 4ms/step
# Epoch 92/200
# 86/86 - 0s - loss: 1.2527e-05 - val_loss: 6.0502e-05 - 376ms/epoch - 4ms/step
# Epoch 93/200
# 86/86 - 0s - loss: 1.2359e-05 - val_loss: 6.2198e-05 - 377ms/epoch - 4ms/step
# Epoch 94/200
# 86/86 - 0s - loss: 1.3012e-05 - val_loss: 5.9766e-05 - 384ms/epoch - 4ms/step
# Epoch 95/200
# 86/86 - 0s - loss: 1.2414e-05 - val_loss: 5.9090e-05 - 380ms/epoch - 4ms/step
# Epoch 96/200
# 86/86 - 0s - loss: 2.2253e-05 - val_loss: 6.2141e-05 - 373ms/epoch - 4ms/step
# Epoch 97/200
# 86/86 - 0s - loss: 2.2147e-05 - val_loss: 5.7648e-05 - 379ms/epoch - 4ms/step
# Epoch 98/200
# 86/86 - 0s - loss: 1.7167e-05 - val_loss: 5.5748e-05 - 377ms/epoch - 4ms/step
# Epoch 99/200
# 86/86 - 0s - loss: 1.4070e-05 - val_loss: 5.0939e-05 - 377ms/epoch - 4ms/step
# Epoch 100/200
# 86/86 - 0s - loss: 1.3137e-05 - val_loss: 5.2082e-05 - 406ms/epoch - 5ms/step
# Epoch 101/200
# 86/86 - 0s - loss: 1.1270e-05 - val_loss: 4.8553e-05 - 392ms/epoch - 5ms/step
# Epoch 102/200
# 86/86 - 0s - loss: 9.5829e-06 - val_loss: 5.0053e-05 - 412ms/epoch - 5ms/step
# Epoch 103/200
# 86/86 - 0s - loss: 1.0650e-05 - val_loss: 5.0410e-05 - 377ms/epoch - 4ms/step
# Epoch 104/200
# 86/86 - 0s - loss: 1.0427e-05 - val_loss: 4.7029e-05 - 377ms/epoch - 4ms/step
# Epoch 105/200
# 86/86 - 0s - loss: 9.0612e-06 - val_loss: 4.6204e-05 - 380ms/epoch - 4ms/step
# Epoch 106/200
# 86/86 - 0s - loss: 1.2259e-05 - val_loss: 5.0765e-05 - 378ms/epoch - 4ms/step
# Epoch 107/200
# 86/86 - 0s - loss: 6.0938e-05 - val_loss: 9.4174e-05 - 481ms/epoch - 6ms/step
# Epoch 108/200
# 86/86 - 0s - loss: 6.0092e-05 - val_loss: 5.4428e-05 - 371ms/epoch - 4ms/step
# Epoch 109/200
# 86/86 - 0s - loss: 3.0426e-05 - val_loss: 4.3114e-05 - 377ms/epoch - 4ms/step
# Epoch 110/200
# 86/86 - 0s - loss: 2.1949e-05 - val_loss: 4.3813e-05 - 379ms/epoch - 4ms/step
# Epoch 111/200
# 86/86 - 0s - loss: 1.6093e-05 - val_loss: 3.6211e-05 - 380ms/epoch - 4ms/step
# Epoch 112/200
# 86/86 - 0s - loss: 1.0948e-05 - val_loss: 3.5321e-05 - 378ms/epoch - 4ms/step
# Epoch 113/200
# 86/86 - 0s - loss: 8.3401e-06 - val_loss: 3.4763e-05 - 388ms/epoch - 5ms/step
# Epoch 114/200
# 86/86 - 0s - loss: 6.4489e-06 - val_loss: 3.3280e-05 - 418ms/epoch - 5ms/step
# Epoch 115/200
# 86/86 - 0s - loss: 5.0936e-06 - val_loss: 3.1978e-05 - 373ms/epoch - 4ms/step
# Epoch 116/200
# 86/86 - 0s - loss: 4.2486e-06 - val_loss: 3.1711e-05 - 384ms/epoch - 4ms/step
# Epoch 117/200
# 86/86 - 0s - loss: 4.0344e-06 - val_loss: 3.2845e-05 - 381ms/epoch - 4ms/step
# Epoch 118/200
# 86/86 - 0s - loss: 3.7984e-06 - val_loss: 3.1667e-05 - 379ms/epoch - 4ms/step
# Epoch 119/200
# 86/86 - 0s - loss: 3.5504e-06 - val_loss: 3.1883e-05 - 383ms/epoch - 4ms/step
# Epoch 120/200
# 86/86 - 0s - loss: 3.9303e-06 - val_loss: 3.2777e-05 - 378ms/epoch - 4ms/step
# Epoch 121/200
# 86/86 - 0s - loss: 7.0836e-06 - val_loss: 3.2399e-05 - 378ms/epoch - 4ms/step
# Epoch 122/200
# 86/86 - 0s - loss: 5.9778e-06 - val_loss: 3.2370e-05 - 389ms/epoch - 5ms/step
# Epoch 123/200
# 86/86 - 0s - loss: 5.8786e-06 - val_loss: 3.2295e-05 - 413ms/epoch - 5ms/step
# Epoch 124/200
# 86/86 - 0s - loss: 5.8745e-06 - val_loss: 3.2279e-05 - 473ms/epoch - 5ms/step
# Epoch 125/200
# 86/86 - 0s - loss: 7.5727e-06 - val_loss: 3.5330e-05 - 388ms/epoch - 5ms/step
# Epoch 126/200
# 86/86 - 0s - loss: 6.9232e-06 - val_loss: 3.2486e-05 - 382ms/epoch - 4ms/step
# Epoch 127/200
# 86/86 - 0s - loss: 6.2204e-06 - val_loss: 3.2678e-05 - 389ms/epoch - 5ms/step
# Epoch 128/200
# 86/86 - 0s - loss: 6.1007e-06 - val_loss: 3.3241e-05 - 396ms/epoch - 5ms/step
# Epoch 129/200
# 86/86 - 0s - loss: 5.5821e-06 - val_loss: 3.1800e-05 - 422ms/epoch - 5ms/step
# Epoch 130/200
# 86/86 - 0s - loss: 4.9437e-06 - val_loss: 3.0750e-05 - 464ms/epoch - 5ms/step
# Epoch 131/200
# 86/86 - 0s - loss: 5.6291e-06 - val_loss: 3.1348e-05 - 400ms/epoch - 5ms/step
# Epoch 132/200
# 86/86 - 0s - loss: 8.1124e-06 - val_loss: 3.1049e-05 - 379ms/epoch - 4ms/step
# Epoch 133/200
# 86/86 - 0s - loss: 7.2922e-06 - val_loss: 3.2332e-05 - 382ms/epoch - 4ms/step
# Epoch 134/200
# 86/86 - 0s - loss: 6.0166e-06 - val_loss: 3.3179e-05 - 377ms/epoch - 4ms/step
# Epoch 135/200
# 86/86 - 0s - loss: 6.7060e-06 - val_loss: 3.9317e-05 - 384ms/epoch - 4ms/step
# Epoch 136/200
# 86/86 - 0s - loss: 9.0677e-06 - val_loss: 3.3009e-05 - 377ms/epoch - 4ms/step
# Epoch 137/200
# 86/86 - 0s - loss: 1.3153e-05 - val_loss: 4.2128e-05 - 381ms/epoch - 4ms/step
# Epoch 138/200
# 86/86 - 0s - loss: 1.6575e-05 - val_loss: 3.5960e-05 - 384ms/epoch - 4ms/step
# Epoch 139/200
# 86/86 - 0s - loss: 1.3418e-05 - val_loss: 3.1633e-05 - 379ms/epoch - 4ms/step
# Epoch 140/200
# 86/86 - 0s - loss: 2.5662e-05 - val_loss: 4.1077e-05 - 390ms/epoch - 5ms/step
# Epoch 141/200
# 86/86 - 0s - loss: 1.7994e-05 - val_loss: 3.4222e-05 - 405ms/epoch - 5ms/step
# Epoch 142/200
# 86/86 - 0s - loss: 1.2144e-05 - val_loss: 3.2224e-05 - 381ms/epoch - 4ms/step
# Epoch 143/200
# 86/86 - 1s - loss: 8.9794e-06 - val_loss: 2.8754e-05 - 508ms/epoch - 6ms/step
# Epoch 144/200
# 86/86 - 0s - loss: 7.6240e-06 - val_loss: 2.8773e-05 - 363ms/epoch - 4ms/step
# Epoch 145/200
# 86/86 - 0s - loss: 8.1541e-06 - val_loss: 2.6824e-05 - 390ms/epoch - 5ms/step
# Epoch 146/200
# 86/86 - 0s - loss: 5.4629e-06 - val_loss: 2.5638e-05 - 394ms/epoch - 5ms/step
# Epoch 147/200
# 86/86 - 0s - loss: 5.4081e-06 - val_loss: 2.9121e-05 - 378ms/epoch - 4ms/step
# Epoch 148/200
# 86/86 - 0s - loss: 4.7098e-06 - val_loss: 2.4478e-05 - 499ms/epoch - 6ms/step
# Epoch 149/200
# 86/86 - 0s - loss: 3.7665e-06 - val_loss: 2.4902e-05 - 490ms/epoch - 6ms/step
# Epoch 150/200
# 86/86 - 0s - loss: 3.0901e-06 - val_loss: 2.4603e-05 - 452ms/epoch - 5ms/step
# Epoch 151/200
# 86/86 - 0s - loss: 3.1648e-06 - val_loss: 2.4037e-05 - 436ms/epoch - 5ms/step
# Epoch 152/200
# 86/86 - 0s - loss: 3.3044e-06 - val_loss: 2.7307e-05 - 404ms/epoch - 5ms/step
# Epoch 153/200
# 86/86 - 0s - loss: 4.5381e-06 - val_loss: 2.5584e-05 - 406ms/epoch - 5ms/step
# Epoch 154/200
# 86/86 - 0s - loss: 3.9766e-06 - val_loss: 2.5172e-05 - 401ms/epoch - 5ms/step
# Epoch 155/200
# 86/86 - 0s - loss: 3.7498e-06 - val_loss: 2.4265e-05 - 411ms/epoch - 5ms/step
# Epoch 156/200
# 86/86 - 0s - loss: 3.5201e-06 - val_loss: 2.4430e-05 - 409ms/epoch - 5ms/step
# Epoch 157/200
# 86/86 - 0s - loss: 3.3653e-06 - val_loss: 2.5814e-05 - 400ms/epoch - 5ms/step
# Epoch 158/200
# 86/86 - 0s - loss: 4.1094e-06 - val_loss: 2.6591e-05 - 412ms/epoch - 5ms/step
# Epoch 159/200
# 86/86 - 0s - loss: 4.6732e-06 - val_loss: 2.7971e-05 - 402ms/epoch - 5ms/step
# Epoch 160/200
# 86/86 - 1s - loss: 7.5048e-06 - val_loss: 2.9046e-05 - 520ms/epoch - 6ms/step
# Epoch 161/200
# 86/86 - 0s - loss: 7.8393e-06 - val_loss: 2.7893e-05 - 424ms/epoch - 5ms/step
# Epoch 162/200
# 86/86 - 0s - loss: 7.8140e-06 - val_loss: 2.6743e-05 - 432ms/epoch - 5ms/step
# Epoch 163/200
# 86/86 - 0s - loss: 6.2867e-06 - val_loss: 2.5616e-05 - 421ms/epoch - 5ms/step
# Epoch 164/200
# 86/86 - 0s - loss: 6.0817e-06 - val_loss: 2.6340e-05 - 401ms/epoch - 5ms/step
# Epoch 165/200
# 86/86 - 0s - loss: 5.5141e-06 - val_loss: 2.5183e-05 - 409ms/epoch - 5ms/step
# Epoch 166/200
# 86/86 - 0s - loss: 6.3437e-06 - val_loss: 2.6623e-05 - 420ms/epoch - 5ms/step
# Epoch 167/200
# 86/86 - 0s - loss: 1.1091e-05 - val_loss: 3.4934e-05 - 415ms/epoch - 5ms/step
# Epoch 168/200
# 86/86 - 0s - loss: 2.0187e-05 - val_loss: 3.9684e-05 - 410ms/epoch - 5ms/step
# Epoch 169/200
# 86/86 - 0s - loss: 1.9078e-05 - val_loss: 3.2030e-05 - 379ms/epoch - 4ms/step
# Epoch 170/200
# 86/86 - 0s - loss: 1.5018e-05 - val_loss: 3.0417e-05 - 382ms/epoch - 4ms/step
# Epoch 171/200
# 86/86 - 0s - loss: 8.7369e-06 - val_loss: 2.4479e-05 - 383ms/epoch - 4ms/step
# Epoch 172/200
# 86/86 - 0s - loss: 6.7693e-06 - val_loss: 2.9677e-05 - 381ms/epoch - 4ms/step
# Epoch 173/200
# 86/86 - 0s - loss: 8.6984e-06 - val_loss: 2.5783e-05 - 377ms/epoch - 4ms/step
# Epoch 174/200
# 86/86 - 0s - loss: 5.6991e-06 - val_loss: 2.3245e-05 - 388ms/epoch - 5ms/step
# Epoch 175/200
# 86/86 - 0s - loss: 3.7204e-06 - val_loss: 2.2849e-05 - 379ms/epoch - 4ms/step
# Epoch 176/200
# 86/86 - 0s - loss: 4.5883e-06 - val_loss: 2.3335e-05 - 379ms/epoch - 4ms/step
# Epoch 177/200
# 86/86 - 0s - loss: 4.2047e-06 - val_loss: 2.2872e-05 - 387ms/epoch - 5ms/step
# Epoch 178/200
# 86/86 - 0s - loss: 3.6871e-06 - val_loss: 2.2990e-05 - 383ms/epoch - 4ms/step
# Epoch 179/200
# 86/86 - 0s - loss: 2.8444e-06 - val_loss: 2.2147e-05 - 491ms/epoch - 6ms/step
# Epoch 180/200
# 86/86 - 0s - loss: 2.0003e-06 - val_loss: 2.1636e-05 - 366ms/epoch - 4ms/step
# Epoch 181/200
# 86/86 - 0s - loss: 2.0025e-06 - val_loss: 2.2031e-05 - 383ms/epoch - 4ms/step
# Epoch 182/200
# 86/86 - 0s - loss: 1.7578e-06 - val_loss: 2.1066e-05 - 391ms/epoch - 5ms/step
# Epoch 183/200
# 86/86 - 0s - loss: 1.6332e-06 - val_loss: 2.1573e-05 - 376ms/epoch - 4ms/step
# Epoch 184/200
# 86/86 - 0s - loss: 1.6761e-06 - val_loss: 2.1332e-05 - 377ms/epoch - 4ms/step
# Epoch 185/200
# 86/86 - 0s - loss: 1.5366e-06 - val_loss: 2.1360e-05 - 382ms/epoch - 4ms/step
# Epoch 186/200
# 86/86 - 0s - loss: 2.6813e-06 - val_loss: 2.4265e-05 - 380ms/epoch - 4ms/step
# Epoch 187/200
# 86/86 - 0s - loss: 4.2606e-06 - val_loss: 2.2703e-05 - 373ms/epoch - 4ms/step
# Epoch 188/200
# 86/86 - 0s - loss: 3.0802e-06 - val_loss: 2.1795e-05 - 382ms/epoch - 4ms/step
# Epoch 189/200
# 86/86 - 0s - loss: 2.8285e-06 - val_loss: 2.1750e-05 - 378ms/epoch - 4ms/step
# Epoch 190/200
# 86/86 - 0s - loss: 2.7965e-06 - val_loss: 2.1746e-05 - 382ms/epoch - 4ms/step
# Epoch 191/200
# 86/86 - 0s - loss: 2.5856e-06 - val_loss: 2.2572e-05 - 380ms/epoch - 4ms/step
# Epoch 192/200
# 86/86 - 0s - loss: 3.1391e-06 - val_loss: 2.2245e-05 - 378ms/epoch - 4ms/step
# Epoch 193/200
# 86/86 - 0s - loss: 2.6458e-06 - val_loss: 2.1804e-05 - 382ms/epoch - 4ms/step
# Epoch 194/200
# 86/86 - 0s - loss: 2.5169e-06 - val_loss: 2.1059e-05 - 379ms/epoch - 4ms/step
# Epoch 195/200
# 86/86 - 0s - loss: 3.1530e-06 - val_loss: 2.2308e-05 - 392ms/epoch - 5ms/step
# Epoch 196/200
# 86/86 - 0s - loss: 3.3168e-06 - val_loss: 2.2152e-05 - 385ms/epoch - 4ms/step
# Epoch 197/200
# 86/86 - 0s - loss: 2.9771e-06 - val_loss: 2.1739e-05 - 378ms/epoch - 4ms/step
# Epoch 198/200
# 86/86 - 0s - loss: 3.1823e-06 - val_loss: 2.1198e-05 - 479ms/epoch - 6ms/step
# Epoch 199/200
# 86/86 - 0s - loss: 3.1509e-06 - val_loss: 2.1708e-05 - 369ms/epoch - 4ms/step
# Epoch 200/200
# 86/86 - 0s - loss: 2.7045e-06 - val_loss: 2.0652e-05 - 384ms/epoch - 4ms/step

# %%
history_aug = model_aug.fit(X_train_aug, y_train_aug, epochs=epochs_, batch_size=batch_, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# 112/112 - 1s - loss: 0.0468 - val_loss: 0.0095 - 785ms/epoch - 7ms/step
# Epoch 2/200
# 112/112 - 0s - loss: 0.0055 - val_loss: 0.0067 - 449ms/epoch - 4ms/step
# Epoch 3/200
# 112/112 - 0s - loss: 0.0032 - val_loss: 0.0058 - 497ms/epoch - 4ms/step
# Epoch 4/200
# 112/112 - 0s - loss: 0.0022 - val_loss: 0.0047 - 489ms/epoch - 4ms/step
# Epoch 5/200
# 112/112 - 0s - loss: 0.0016 - val_loss: 0.0043 - 491ms/epoch - 4ms/step
# Epoch 6/200
# 112/112 - 0s - loss: 0.0013 - val_loss: 0.0038 - 486ms/epoch - 4ms/step
# Epoch 7/200
# 112/112 - 0s - loss: 0.0011 - val_loss: 0.0036 - 491ms/epoch - 4ms/step
# Epoch 8/200
# 112/112 - 0s - loss: 9.1214e-04 - val_loss: 0.0033 - 486ms/epoch - 4ms/step
# Epoch 9/200
# 112/112 - 0s - loss: 9.2495e-04 - val_loss: 0.0032 - 494ms/epoch - 4ms/step
# Epoch 10/200
# 112/112 - 1s - loss: 0.0010 - val_loss: 0.0031 - 580ms/epoch - 5ms/step
# Epoch 11/200
# 112/112 - 0s - loss: 8.5296e-04 - val_loss: 0.0029 - 491ms/epoch - 4ms/step
# Epoch 12/200
# 112/112 - 0s - loss: 7.9834e-04 - val_loss: 0.0030 - 492ms/epoch - 4ms/step
# Epoch 13/200
# 112/112 - 1s - loss: 7.8775e-04 - val_loss: 0.0026 - 620ms/epoch - 6ms/step
# Epoch 14/200
# 112/112 - 1s - loss: 6.5451e-04 - val_loss: 0.0026 - 589ms/epoch - 5ms/step
# Epoch 15/200
# 112/112 - 1s - loss: 6.4868e-04 - val_loss: 0.0028 - 551ms/epoch - 5ms/step
# Epoch 16/200
# 112/112 - 1s - loss: 6.2963e-04 - val_loss: 0.0024 - 550ms/epoch - 5ms/step
# Epoch 17/200
# 112/112 - 1s - loss: 6.1966e-04 - val_loss: 0.0024 - 563ms/epoch - 5ms/step
# Epoch 18/200
# 112/112 - 1s - loss: 5.7491e-04 - val_loss: 0.0023 - 557ms/epoch - 5ms/step
# Epoch 19/200
# 112/112 - 1s - loss: 5.4944e-04 - val_loss: 0.0023 - 547ms/epoch - 5ms/step
# Epoch 20/200
# 112/112 - 1s - loss: 5.3784e-04 - val_loss: 0.0022 - 556ms/epoch - 5ms/step
# Epoch 21/200
# 112/112 - 1s - loss: 5.5799e-04 - val_loss: 0.0021 - 504ms/epoch - 5ms/step
# Epoch 22/200
# 112/112 - 0s - loss: 5.4534e-04 - val_loss: 0.0021 - 488ms/epoch - 4ms/step
# Epoch 23/200
# 112/112 - 1s - loss: 5.3884e-04 - val_loss: 0.0021 - 501ms/epoch - 4ms/step
# Epoch 24/200
# 112/112 - 0s - loss: 5.6882e-04 - val_loss: 0.0019 - 492ms/epoch - 4ms/step
# Epoch 25/200
# 112/112 - 1s - loss: 5.3842e-04 - val_loss: 0.0020 - 501ms/epoch - 4ms/step
# Epoch 26/200
# 112/112 - 1s - loss: 5.4342e-04 - val_loss: 0.0018 - 597ms/epoch - 5ms/step
# Epoch 27/200
# 112/112 - 0s - loss: 4.4940e-04 - val_loss: 0.0018 - 482ms/epoch - 4ms/step
# Epoch 28/200
# 112/112 - 0s - loss: 5.1364e-04 - val_loss: 0.0016 - 490ms/epoch - 4ms/step
# Epoch 29/200
# 112/112 - 0s - loss: 4.9855e-04 - val_loss: 0.0020 - 492ms/epoch - 4ms/step
# Epoch 30/200
# 112/112 - 1s - loss: 5.5124e-04 - val_loss: 0.0017 - 517ms/epoch - 5ms/step
# Epoch 31/200
# 112/112 - 1s - loss: 5.0290e-04 - val_loss: 0.0017 - 542ms/epoch - 5ms/step
# Epoch 32/200
# 112/112 - 0s - loss: 4.1451e-04 - val_loss: 0.0016 - 488ms/epoch - 4ms/step
# Epoch 33/200
# 112/112 - 1s - loss: 4.3960e-04 - val_loss: 0.0015 - 507ms/epoch - 5ms/step
# Epoch 34/200
# 112/112 - 1s - loss: 3.6921e-04 - val_loss: 0.0015 - 511ms/epoch - 5ms/step
# Epoch 35/200
# 112/112 - 1s - loss: 5.0328e-04 - val_loss: 0.0017 - 502ms/epoch - 4ms/step
# Epoch 36/200
# 112/112 - 0s - loss: 5.0944e-04 - val_loss: 0.0016 - 493ms/epoch - 4ms/step
# Epoch 37/200
# 112/112 - 0s - loss: 4.5496e-04 - val_loss: 0.0016 - 489ms/epoch - 4ms/step
# Epoch 38/200
# 112/112 - 0s - loss: 4.7929e-04 - val_loss: 0.0015 - 493ms/epoch - 4ms/step
# Epoch 39/200
# 112/112 - 0s - loss: 4.9192e-04 - val_loss: 0.0015 - 490ms/epoch - 4ms/step
# Epoch 40/200
# 112/112 - 1s - loss: 4.0748e-04 - val_loss: 0.0014 - 507ms/epoch - 5ms/step
# Epoch 41/200
# 112/112 - 0s - loss: 3.5041e-04 - val_loss: 0.0014 - 496ms/epoch - 4ms/step
# Epoch 42/200
# 112/112 - 0s - loss: 3.8639e-04 - val_loss: 0.0014 - 497ms/epoch - 4ms/step
# Epoch 43/200
# 112/112 - 0s - loss: 3.7202e-04 - val_loss: 0.0014 - 496ms/epoch - 4ms/step
# Epoch 44/200
# 112/112 - 1s - loss: 4.1309e-04 - val_loss: 0.0017 - 597ms/epoch - 5ms/step
# Epoch 45/200
# 112/112 - 1s - loss: 4.1195e-04 - val_loss: 0.0014 - 513ms/epoch - 5ms/step
# Epoch 46/200
# 112/112 - 1s - loss: 4.1962e-04 - val_loss: 0.0014 - 501ms/epoch - 4ms/step
# Epoch 47/200
# 112/112 - 0s - loss: 3.8934e-04 - val_loss: 0.0014 - 494ms/epoch - 4ms/step
# Epoch 48/200
# 112/112 - 0s - loss: 3.5444e-04 - val_loss: 0.0013 - 498ms/epoch - 4ms/step
# Epoch 49/200
# 112/112 - 0s - loss: 3.7167e-04 - val_loss: 0.0015 - 492ms/epoch - 4ms/step
# Epoch 50/200
# 112/112 - 0s - loss: 3.6102e-04 - val_loss: 0.0014 - 498ms/epoch - 4ms/step
# Epoch 51/200
# 112/112 - 0s - loss: 3.7756e-04 - val_loss: 0.0013 - 492ms/epoch - 4ms/step
# Epoch 52/200
# 112/112 - 0s - loss: 4.1157e-04 - val_loss: 0.0014 - 496ms/epoch - 4ms/step
# Epoch 53/200
# 112/112 - 0s - loss: 3.9745e-04 - val_loss: 0.0012 - 493ms/epoch - 4ms/step
# Epoch 54/200
# 112/112 - 0s - loss: 3.8522e-04 - val_loss: 0.0012 - 497ms/epoch - 4ms/step
# Epoch 55/200
# 112/112 - 0s - loss: 3.8135e-04 - val_loss: 0.0013 - 493ms/epoch - 4ms/step
# Epoch 56/200
# 112/112 - 0s - loss: 4.7517e-04 - val_loss: 0.0014 - 493ms/epoch - 4ms/step
# Epoch 57/200
# 112/112 - 0s - loss: 5.7345e-04 - val_loss: 0.0014 - 498ms/epoch - 4ms/step
# Epoch 58/200
# 112/112 - 0s - loss: 5.4995e-04 - val_loss: 0.0013 - 494ms/epoch - 4ms/step
# Epoch 59/200
# 112/112 - 0s - loss: 5.9756e-04 - val_loss: 0.0015 - 498ms/epoch - 4ms/step
# Epoch 60/200
# 112/112 - 0s - loss: 5.6590e-04 - val_loss: 0.0013 - 493ms/epoch - 4ms/step
# Epoch 61/200
# 112/112 - 0s - loss: 4.4899e-04 - val_loss: 0.0013 - 499ms/epoch - 4ms/step
# Epoch 62/200
# 112/112 - 1s - loss: 3.7203e-04 - val_loss: 0.0012 - 590ms/epoch - 5ms/step
# Epoch 63/200
# 112/112 - 0s - loss: 2.7150e-04 - val_loss: 0.0011 - 488ms/epoch - 4ms/step
# Epoch 64/200
# 112/112 - 0s - loss: 2.7514e-04 - val_loss: 9.9726e-04 - 495ms/epoch - 4ms/step
# Epoch 65/200
# 112/112 - 0s - loss: 2.1955e-04 - val_loss: 0.0011 - 496ms/epoch - 4ms/step
# Epoch 66/200
# 112/112 - 0s - loss: 2.3675e-04 - val_loss: 0.0012 - 491ms/epoch - 4ms/step
# Epoch 67/200
# 112/112 - 0s - loss: 2.7696e-04 - val_loss: 0.0011 - 497ms/epoch - 4ms/step
# Epoch 68/200
# 112/112 - 0s - loss: 2.7508e-04 - val_loss: 0.0011 - 492ms/epoch - 4ms/step
# Epoch 69/200
# 112/112 - 0s - loss: 3.0734e-04 - val_loss: 0.0013 - 495ms/epoch - 4ms/step
# Epoch 70/200
# 112/112 - 0s - loss: 3.6549e-04 - val_loss: 0.0011 - 492ms/epoch - 4ms/step
# Epoch 71/200
# 112/112 - 0s - loss: 3.7218e-04 - val_loss: 0.0011 - 495ms/epoch - 4ms/step
# Epoch 72/200
# 112/112 - 0s - loss: 4.4762e-04 - val_loss: 0.0013 - 494ms/epoch - 4ms/step
# Epoch 73/200
# 112/112 - 0s - loss: 5.2131e-04 - val_loss: 0.0012 - 497ms/epoch - 4ms/step
# Epoch 74/200
# 112/112 - 0s - loss: 5.2176e-04 - val_loss: 0.0013 - 496ms/epoch - 4ms/step
# Epoch 75/200
# 112/112 - 0s - loss: 4.4721e-04 - val_loss: 0.0011 - 493ms/epoch - 4ms/step
# Epoch 76/200
# 112/112 - 1s - loss: 3.6137e-04 - val_loss: 9.8752e-04 - 520ms/epoch - 5ms/step
# Epoch 77/200
# 112/112 - 1s - loss: 3.0363e-04 - val_loss: 9.5930e-04 - 501ms/epoch - 4ms/step
# Epoch 78/200
# 112/112 - 1s - loss: 2.4780e-04 - val_loss: 9.7286e-04 - 500ms/epoch - 4ms/step
# Epoch 79/200
# 112/112 - 1s - loss: 2.9921e-04 - val_loss: 0.0011 - 576ms/epoch - 5ms/step
# Epoch 80/200
# 112/112 - 0s - loss: 2.8929e-04 - val_loss: 0.0010 - 490ms/epoch - 4ms/step
# Epoch 81/200
# 112/112 - 0s - loss: 2.7284e-04 - val_loss: 9.4566e-04 - 493ms/epoch - 4ms/step
# Epoch 82/200
# 112/112 - 0s - loss: 2.5478e-04 - val_loss: 9.8273e-04 - 495ms/epoch - 4ms/step
# Epoch 83/200
# 112/112 - 0s - loss: 2.5746e-04 - val_loss: 9.7218e-04 - 491ms/epoch - 4ms/step
# Epoch 84/200
# 112/112 - 0s - loss: 3.2159e-04 - val_loss: 9.7427e-04 - 499ms/epoch - 4ms/step
# Epoch 85/200
# 112/112 - 0s - loss: 3.0928e-04 - val_loss: 0.0010 - 492ms/epoch - 4ms/step
# Epoch 86/200
# 112/112 - 0s - loss: 3.8573e-04 - val_loss: 0.0012 - 497ms/epoch - 4ms/step
# Epoch 87/200
# 112/112 - 1s - loss: 3.7563e-04 - val_loss: 0.0011 - 505ms/epoch - 5ms/step
# Epoch 88/200
# 112/112 - 0s - loss: 3.5154e-04 - val_loss: 0.0011 - 496ms/epoch - 4ms/step
# Epoch 89/200
# 112/112 - 0s - loss: 3.3170e-04 - val_loss: 0.0011 - 496ms/epoch - 4ms/step
# Epoch 90/200
# 112/112 - 0s - loss: 5.2907e-04 - val_loss: 0.0015 - 489ms/epoch - 4ms/step
# Epoch 91/200
# 112/112 - 1s - loss: 5.1160e-04 - val_loss: 0.0015 - 550ms/epoch - 5ms/step
# Epoch 92/200
# 112/112 - 0s - loss: 4.5975e-04 - val_loss: 0.0012 - 492ms/epoch - 4ms/step
# Epoch 93/200
# 112/112 - 0s - loss: 3.2304e-04 - val_loss: 0.0010 - 499ms/epoch - 4ms/step
# Epoch 94/200
# 112/112 - 0s - loss: 3.1318e-04 - val_loss: 0.0011 - 493ms/epoch - 4ms/step
# Epoch 95/200
# 112/112 - 0s - loss: 2.6625e-04 - val_loss: 8.7689e-04 - 496ms/epoch - 4ms/step
# Epoch 96/200
# 112/112 - 0s - loss: 1.7281e-04 - val_loss: 9.4713e-04 - 493ms/epoch - 4ms/step
# Epoch 97/200
# 112/112 - 0s - loss: 1.3896e-04 - val_loss: 7.9377e-04 - 500ms/epoch - 4ms/step
# Epoch 98/200
# 112/112 - 1s - loss: 1.3012e-04 - val_loss: 8.2545e-04 - 581ms/epoch - 5ms/step
# Epoch 99/200
# 112/112 - 0s - loss: 1.1815e-04 - val_loss: 8.7530e-04 - 489ms/epoch - 4ms/step
# Epoch 100/200
# 112/112 - 0s - loss: 1.2285e-04 - val_loss: 8.4283e-04 - 497ms/epoch - 4ms/step
# Epoch 101/200
# 112/112 - 0s - loss: 1.4110e-04 - val_loss: 8.5155e-04 - 493ms/epoch - 4ms/step
# Epoch 102/200
# 112/112 - 0s - loss: 1.5275e-04 - val_loss: 8.7016e-04 - 493ms/epoch - 4ms/step
# Epoch 103/200
# 112/112 - 1s - loss: 1.7672e-04 - val_loss: 8.8678e-04 - 515ms/epoch - 5ms/step
# Epoch 104/200
# 112/112 - 1s - loss: 2.3659e-04 - val_loss: 9.5598e-04 - 508ms/epoch - 5ms/step
# Epoch 105/200
# 112/112 - 0s - loss: 2.3341e-04 - val_loss: 9.8323e-04 - 490ms/epoch - 4ms/step
# Epoch 106/200
# 112/112 - 0s - loss: 1.9801e-04 - val_loss: 8.7081e-04 - 495ms/epoch - 4ms/step
# Epoch 107/200
# 112/112 - 0s - loss: 2.0775e-04 - val_loss: 9.3588e-04 - 488ms/epoch - 4ms/step
# Epoch 108/200
# 112/112 - 0s - loss: 2.6707e-04 - val_loss: 9.8164e-04 - 493ms/epoch - 4ms/step
# Epoch 109/200
# 112/112 - 0s - loss: 2.7050e-04 - val_loss: 9.6608e-04 - 488ms/epoch - 4ms/step
# Epoch 110/200
# 112/112 - 0s - loss: 2.5016e-04 - val_loss: 9.2356e-04 - 499ms/epoch - 4ms/step
# Epoch 111/200
# 112/112 - 0s - loss: 2.3281e-04 - val_loss: 0.0010 - 490ms/epoch - 4ms/step
# Epoch 112/200
# 112/112 - 0s - loss: 2.1623e-04 - val_loss: 0.0010 - 496ms/epoch - 4ms/step
# Epoch 113/200
# 112/112 - 0s - loss: 2.1367e-04 - val_loss: 0.0011 - 491ms/epoch - 4ms/step
# Epoch 114/200
# 112/112 - 1s - loss: 2.5850e-04 - val_loss: 0.0011 - 597ms/epoch - 5ms/step
# Epoch 115/200
# 112/112 - 0s - loss: 2.2452e-04 - val_loss: 9.2489e-04 - 476ms/epoch - 4ms/step
# Epoch 116/200
# 112/112 - 0s - loss: 1.6221e-04 - val_loss: 8.8885e-04 - 493ms/epoch - 4ms/step
# Epoch 117/200
# 112/112 - 0s - loss: 1.6185e-04 - val_loss: 9.4600e-04 - 493ms/epoch - 4ms/step
# Epoch 118/200
# 112/112 - 0s - loss: 1.9906e-04 - val_loss: 8.9691e-04 - 492ms/epoch - 4ms/step
# Epoch 119/200
# 112/112 - 0s - loss: 1.4437e-04 - val_loss: 8.7084e-04 - 492ms/epoch - 4ms/step
# Epoch 120/200
# 112/112 - 0s - loss: 1.4217e-04 - val_loss: 8.7200e-04 - 494ms/epoch - 4ms/step
# Epoch 121/200
# 112/112 - 0s - loss: 1.3014e-04 - val_loss: 8.5753e-04 - 491ms/epoch - 4ms/step
# Epoch 122/200
# 112/112 - 0s - loss: 1.3084e-04 - val_loss: 8.0339e-04 - 496ms/epoch - 4ms/step
# Epoch 123/200
# 112/112 - 0s - loss: 1.2607e-04 - val_loss: 8.3339e-04 - 494ms/epoch - 4ms/step
# Epoch 124/200
# 112/112 - 0s - loss: 1.5383e-04 - val_loss: 7.8917e-04 - 488ms/epoch - 4ms/step
# Epoch 125/200
# 112/112 - 0s - loss: 1.3955e-04 - val_loss: 8.9873e-04 - 496ms/epoch - 4ms/step
# Epoch 126/200
# 112/112 - 0s - loss: 1.3110e-04 - val_loss: 9.6705e-04 - 489ms/epoch - 4ms/step
# Epoch 127/200
# 112/112 - 0s - loss: 1.6177e-04 - val_loss: 8.3609e-04 - 493ms/epoch - 4ms/step
# Epoch 128/200
# 112/112 - 0s - loss: 1.6092e-04 - val_loss: 9.3822e-04 - 493ms/epoch - 4ms/step
# Epoch 129/200
# 112/112 - 0s - loss: 1.7325e-04 - val_loss: 9.8682e-04 - 491ms/epoch - 4ms/step
# Epoch 130/200
# 112/112 - 0s - loss: 1.5087e-04 - val_loss: 8.1779e-04 - 489ms/epoch - 4ms/step
# Epoch 131/200
# 112/112 - 0s - loss: 1.3220e-04 - val_loss: 7.9109e-04 - 496ms/epoch - 4ms/step
# Epoch 132/200
# 112/112 - 0s - loss: 1.3369e-04 - val_loss: 8.5492e-04 - 490ms/epoch - 4ms/step
# Epoch 133/200
# 112/112 - 1s - loss: 1.2511e-04 - val_loss: 8.2889e-04 - 590ms/epoch - 5ms/step
# Epoch 134/200
# 112/112 - 0s - loss: 1.3282e-04 - val_loss: 8.6423e-04 - 486ms/epoch - 4ms/step
# Epoch 135/200
# 112/112 - 1s - loss: 1.2291e-04 - val_loss: 8.9190e-04 - 502ms/epoch - 4ms/step
# Epoch 136/200
# 112/112 - 0s - loss: 1.4371e-04 - val_loss: 9.0473e-04 - 497ms/epoch - 4ms/step
# Epoch 137/200
# 112/112 - 1s - loss: 1.3730e-04 - val_loss: 8.6856e-04 - 501ms/epoch - 4ms/step
# Epoch 138/200
# 112/112 - 0s - loss: 1.2445e-04 - val_loss: 8.4570e-04 - 495ms/epoch - 4ms/step
# Epoch 139/200
# 112/112 - 0s - loss: 1.9074e-04 - val_loss: 9.4294e-04 - 499ms/epoch - 4ms/step
# Epoch 140/200
# 112/112 - 0s - loss: 1.8917e-04 - val_loss: 0.0010 - 499ms/epoch - 4ms/step
# Epoch 141/200
# 112/112 - 0s - loss: 2.0025e-04 - val_loss: 8.9825e-04 - 491ms/epoch - 4ms/step
# Epoch 142/200
# 112/112 - 1s - loss: 1.3760e-04 - val_loss: 9.3919e-04 - 502ms/epoch - 4ms/step
# Epoch 143/200
# 112/112 - 0s - loss: 1.1771e-04 - val_loss: 8.8364e-04 - 494ms/epoch - 4ms/step
# Epoch 144/200
# 112/112 - 1s - loss: 1.2550e-04 - val_loss: 8.3873e-04 - 502ms/epoch - 4ms/step
# Epoch 145/200
# 112/112 - 0s - loss: 1.1964e-04 - val_loss: 8.4807e-04 - 496ms/epoch - 4ms/step
# Epoch 146/200
# 112/112 - 1s - loss: 1.0161e-04 - val_loss: 8.0966e-04 - 510ms/epoch - 5ms/step
# Epoch 147/200
# 112/112 - 0s - loss: 1.2180e-04 - val_loss: 8.6926e-04 - 492ms/epoch - 4ms/step
# Epoch 148/200
# 112/112 - 0s - loss: 1.1223e-04 - val_loss: 8.6610e-04 - 499ms/epoch - 4ms/step
# Epoch 149/200
# 112/112 - 0s - loss: 9.8224e-05 - val_loss: 7.9755e-04 - 496ms/epoch - 4ms/step
# Epoch 150/200
# 112/112 - 1s - loss: 1.0714e-04 - val_loss: 9.4070e-04 - 597ms/epoch - 5ms/step
# Epoch 151/200
# 112/112 - 0s - loss: 1.0849e-04 - val_loss: 8.1983e-04 - 480ms/epoch - 4ms/step
# Epoch 152/200
# 112/112 - 1s - loss: 9.4624e-05 - val_loss: 8.3803e-04 - 504ms/epoch - 5ms/step
# Epoch 153/200
# 112/112 - 0s - loss: 9.0924e-05 - val_loss: 7.8924e-04 - 495ms/epoch - 4ms/step
# Epoch 154/200
# 112/112 - 0s - loss: 1.0359e-04 - val_loss: 8.4916e-04 - 499ms/epoch - 4ms/step
# Epoch 155/200
# 112/112 - 0s - loss: 1.9686e-04 - val_loss: 8.6768e-04 - 493ms/epoch - 4ms/step
# Epoch 156/200
# 112/112 - 0s - loss: 1.6097e-04 - val_loss: 8.5359e-04 - 493ms/epoch - 4ms/step
# Epoch 157/200
# 112/112 - 0s - loss: 1.3226e-04 - val_loss: 8.0240e-04 - 487ms/epoch - 4ms/step
# Epoch 158/200
# 112/112 - 0s - loss: 1.1406e-04 - val_loss: 8.7285e-04 - 491ms/epoch - 4ms/step
# Epoch 159/200
# 112/112 - 1s - loss: 9.6339e-05 - val_loss: 7.5986e-04 - 502ms/epoch - 4ms/step
# Epoch 160/200
# 112/112 - 0s - loss: 1.0653e-04 - val_loss: 8.1773e-04 - 496ms/epoch - 4ms/step
# Epoch 161/200
# 112/112 - 0s - loss: 9.7612e-05 - val_loss: 8.4418e-04 - 497ms/epoch - 4ms/step
# Epoch 162/200
# 112/112 - 0s - loss: 9.4522e-05 - val_loss: 8.4027e-04 - 489ms/epoch - 4ms/step
# Epoch 163/200
# 112/112 - 0s - loss: 1.0425e-04 - val_loss: 9.2933e-04 - 498ms/epoch - 4ms/step
# Epoch 164/200
# 112/112 - 0s - loss: 9.2912e-05 - val_loss: 7.8588e-04 - 490ms/epoch - 4ms/step
# Epoch 165/200
# 112/112 - 1s - loss: 8.4268e-05 - val_loss: 8.3303e-04 - 502ms/epoch - 4ms/step
# Epoch 166/200
# 112/112 - 0s - loss: 8.2081e-05 - val_loss: 8.3558e-04 - 491ms/epoch - 4ms/step
# Epoch 167/200
# 112/112 - 0s - loss: 1.2644e-04 - val_loss: 0.0010 - 499ms/epoch - 4ms/step
# Epoch 168/200
# 112/112 - 0s - loss: 1.1563e-04 - val_loss: 7.2701e-04 - 494ms/epoch - 4ms/step
# Epoch 169/200
# 112/112 - 1s - loss: 8.2770e-05 - val_loss: 8.5190e-04 - 602ms/epoch - 5ms/step
# Epoch 170/200
# 112/112 - 0s - loss: 7.9574e-05 - val_loss: 7.7596e-04 - 481ms/epoch - 4ms/step
# Epoch 171/200
# 112/112 - 1s - loss: 8.5328e-05 - val_loss: 7.7787e-04 - 504ms/epoch - 5ms/step
# Epoch 172/200
# 112/112 - 0s - loss: 8.5724e-05 - val_loss: 8.5489e-04 - 494ms/epoch - 4ms/step
# Epoch 173/200
# 112/112 - 0s - loss: 7.6840e-05 - val_loss: 8.1368e-04 - 499ms/epoch - 4ms/step
# Epoch 174/200
# 112/112 - 0s - loss: 8.4885e-05 - val_loss: 7.6064e-04 - 496ms/epoch - 4ms/step
# Epoch 175/200
# 112/112 - 0s - loss: 8.5096e-05 - val_loss: 9.0777e-04 - 498ms/epoch - 4ms/step
# Epoch 176/200
# 112/112 - 0s - loss: 7.9116e-05 - val_loss: 7.5160e-04 - 499ms/epoch - 4ms/step
# Epoch 177/200
# 112/112 - 0s - loss: 8.7473e-05 - val_loss: 8.0995e-04 - 499ms/epoch - 4ms/step
# Epoch 178/200
# 112/112 - 0s - loss: 9.9285e-05 - val_loss: 8.6795e-04 - 499ms/epoch - 4ms/step
# Epoch 179/200
# 112/112 - 0s - loss: 1.2815e-04 - val_loss: 8.4674e-04 - 496ms/epoch - 4ms/step
# Epoch 180/200
# 112/112 - 0s - loss: 1.2227e-04 - val_loss: 8.2499e-04 - 500ms/epoch - 4ms/step
# Epoch 181/200
# 112/112 - 0s - loss: 1.1112e-04 - val_loss: 8.4857e-04 - 497ms/epoch - 4ms/step
# Epoch 182/200
# 112/112 - 1s - loss: 9.7617e-05 - val_loss: 9.6316e-04 - 501ms/epoch - 4ms/step
# Epoch 183/200
# 112/112 - 0s - loss: 7.8465e-05 - val_loss: 7.6072e-04 - 495ms/epoch - 4ms/step
# Epoch 184/200
# 112/112 - 0s - loss: 6.3841e-05 - val_loss: 7.9213e-04 - 500ms/epoch - 4ms/step
# Epoch 185/200
# 112/112 - 0s - loss: 6.4563e-05 - val_loss: 8.0508e-04 - 497ms/epoch - 4ms/step
# Epoch 186/200
# 112/112 - 0s - loss: 7.3054e-05 - val_loss: 7.7300e-04 - 498ms/epoch - 4ms/step
# Epoch 187/200
# 112/112 - 0s - loss: 6.5966e-05 - val_loss: 7.5338e-04 - 494ms/epoch - 4ms/step
# Epoch 188/200
# 112/112 - 1s - loss: 7.3132e-05 - val_loss: 8.5082e-04 - 602ms/epoch - 5ms/step
# Epoch 189/200
# 112/112 - 0s - loss: 8.5591e-05 - val_loss: 9.0578e-04 - 487ms/epoch - 4ms/step
# Epoch 190/200
# 112/112 - 1s - loss: 1.4537e-04 - val_loss: 8.4488e-04 - 502ms/epoch - 4ms/step
# Epoch 191/200
# 112/112 - 0s - loss: 1.4603e-04 - val_loss: 9.6298e-04 - 494ms/epoch - 4ms/step
# Epoch 192/200
# 112/112 - 0s - loss: 1.3402e-04 - val_loss: 8.7304e-04 - 495ms/epoch - 4ms/step
# Epoch 193/200
# 112/112 - 0s - loss: 9.6473e-05 - val_loss: 8.1966e-04 - 498ms/epoch - 4ms/step
# Epoch 194/200
# 112/112 - 0s - loss: 8.1076e-05 - val_loss: 7.8136e-04 - 495ms/epoch - 4ms/step
# Epoch 195/200
# 112/112 - 1s - loss: 7.5040e-05 - val_loss: 8.9765e-04 - 501ms/epoch - 4ms/step
# Epoch 196/200
# 112/112 - 0s - loss: 6.5162e-05 - val_loss: 7.9843e-04 - 493ms/epoch - 4ms/step
# Epoch 197/200
# 112/112 - 0s - loss: 6.3321e-05 - val_loss: 8.0178e-04 - 499ms/epoch - 4ms/step
# Epoch 198/200
# 112/112 - 0s - loss: 6.1705e-05 - val_loss: 8.3978e-04 - 493ms/epoch - 4ms/step
# Epoch 199/200
# 112/112 - 1s - loss: 4.7825e-05 - val_loss: 7.7060e-04 - 500ms/epoch - 4ms/step
# Epoch 200/200
# 112/112 - 0s - loss: 5.1658e-05 - val_loss: 8.3060e-04 - 496ms/epoch - 4ms/step

# %%
# Extraia os valores de loss do histórico
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Non Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Extraia os valores de loss do histórico
train_loss = history_aug.history['loss']
val_loss = history_aug.history['val_loss']

# Crie um gráfico para visualizar as curvas de loss
epochs = range(2, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss[1:], 'b', label='Training loss')
plt.plot(epochs, val_loss[1:], 'r', label='Validation loss')
plt.title('Training and Validation Loss - Augmented Data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_hat = model.predict(X_test)
print(y_hat.shape)

y_hat_aug = model_aug.predict(X_test)
print(y_hat_aug.shape)
# Out:
# 93/93 [==============================] - 0s 2ms/step
# (2947, 3)
# 93/93 [==============================] - 0s 1ms/step
# (2947, 3)

# %%
PredDF = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat,columns=['yh1','yh2','yh3'])],axis=1)

PredDF_aug = pd.concat([pd.DataFrame(y_test.reset_index(drop=True)).rename(columns={"Enn": "y1","Etn": "y2","Ett": "y3"}),
                                      pd.DataFrame(y_hat_aug,columns=['yh1','yh2','yh3'])],axis=1)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Correlation

# %%
PredDF.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.936165 -0.119855 -0.540636
# y2 -0.124608  0.927406  0.136856
# y3 -0.544344  0.144569  0.946110

# %%
PredDF_aug.corr().iloc[:3,3:]
# Out:
#          yh1       yh2       yh3
# y1  0.762654 -0.001764 -0.352149
# y2 -0.152589  0.713804  0.087109
# y3 -0.456843  0.048577  0.748642

# %% [markdown]
# ## R2

# %%
print('Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF['y1'], PredDF['yh1']))
print('')
print('')
# plt.scatter(PredDF['y1'], PredDF['yh1'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF['y2'], PredDF['yh2']))
print('')
print('')
# plt.scatter(PredDF['y2'], PredDF['yh2'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF['y3'], PredDF['yh3']))
print('')
print('')
# plt.scatter(PredDF['y3'], PredDF['yh3'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()


print('PredDF_aug: Resultados Holdout Enn')
print('')
print(metrics.r2_score(PredDF_aug['y1'], PredDF_aug['yh1']))
print('')
print('')
# plt.scatter(PredDF_aug['y1'], PredDF_aug['yh1'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Etn')
print('')
print(metrics.r2_score(PredDF_aug['y2'], PredDF_aug['yh2']))
print('')
print('')
# plt.scatter(PredDF_aug['y2'], PredDF_aug['yh2'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()

print('PredDF_aug: Resultados Holdout Ett')
print('')
print(metrics.r2_score(PredDF_aug['y3'], PredDF_aug['yh3']))
# print('')
# print('')
# plt.scatter(PredDF_aug['y3'], PredDF_aug['yh3'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.show()
# Out:
# Resultados Holdout Enn
#
# 0.8757578789477685
#
#
# Resultados Holdout Etn
#
# 0.8573700861263098
#
#
# Resultados Holdout Ett
#
# 0.8940160301650563
#
#
# PredDF_aug: Resultados Holdout Enn
#
# 0.3646933924617517
#
#
# PredDF_aug: Resultados Holdout Etn
#
# 0.25787455406993265
#
#
# PredDF_aug: Resultados Holdout Ett
#
# 0.39834493698457674

# %% [markdown]
# # Back to .mat

# %%
ind_tr1= y_test.Enn
ind_tr2= y_test.Etn
ind_tr3= y_test.Ett
y_test.loc[ind_tr1.index,'Enn'] = y_hat[:,0]
y_test.loc[ind_tr2.index,'Etn'] = y_hat[:,1]
y_test.loc[ind_tr3.index,'Ett'] = y_hat[:,2]

ind_tr1_aug= y_test.Enn
ind_tr2_aug= y_test.Etn
ind_tr3_aug= y_test.Ett
y_test.loc[ind_tr1_aug.index,'Enn'] = y_hat_aug[:,0]
y_test.loc[ind_tr2_aug.index,'Etn'] = y_hat_aug[:,1]
y_test.loc[ind_tr3_aug.index,'Ett'] = y_hat_aug[:,2]

# %%
ind_tes1= y_test.Enn
ind_tes2= y_test.Etn
ind_tes3= y_test.Ett
df.loc[ind_tes1.index,'Enn'] = y_test.Enn
df.loc[ind_tes2.index,'Etn'] = y_test.Etn
df.loc[ind_tes3.index,'Ett'] = y_test.Ett

df_aug = df
ind_tes1_aug= y_test.Enn
ind_tes2_aug= y_test.Etn
ind_tes3_aug= y_test.Ett
df_aug.loc[ind_tes1_aug.index,'Enn'] = y_test.Enn
df_aug.loc[ind_tes2_aug.index,'Etn'] = y_test.Etn
df_aug.loc[ind_tes3_aug.index,'Ett'] = y_test.Ett

# %%
display(df[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
display(df_aug[0:15])
# Out:
#       Angles       Enn       Etn       Ett     i      j
# 0   1.313459 -0.021131 -0.005029  0.037062  17.0   34.0
# 1   1.313459 -0.016244 -0.003890  0.037659  17.0   35.0
# 2   1.272007 -0.017141 -0.007839  0.037039  17.0   36.0
# 3   1.272007 -0.015405 -0.004652  0.029757  17.0   37.0
# 4   1.272007 -0.022577 -0.014142  0.030379  17.0   38.0
# 5   4.405660 -0.024865 -0.016795  0.028040  17.0   39.0
# 6   4.405660 -0.023602 -0.016421  0.028559  17.0   40.0
# 7   4.403640 -0.019546 -0.016275  0.028751  17.0   41.0
# 8   4.403640 -0.006281 -0.012775  0.030849  17.0   42.0
# 9   4.403640 -0.017362 -0.016113  0.027512  17.0   43.0
# 10  0.169048  0.015509 -0.001588 -0.003406  17.0  127.0
# 11  0.112003  0.005336 -0.004641 -0.002026  17.0  128.0
# 12  0.417951  0.009321 -0.003391 -0.001601  17.0  129.0
# 13  0.432343  0.000264 -0.005836 -0.000010  17.0  130.0
# 14  0.438457  0.007882 -0.008628  0.002791  17.0  131.0

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df.iloc[a,4]
    j=df.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df.iloc[a,1]
    df2.iloc[ind,2]=df.iloc[a,2]
    df2.iloc[ind,3]=df.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100

Enn_MLP_35=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35.mat', {'Enn_MLP_35': Enn_MLP_35}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35.mat', {'Etn_MLP_35': Etn_MLP_35})
spio.savemat('Ett_MLP_35.mat', {'Ett_MLP_35': Ett_MLP_35})
# Out:
# n1= 199 m1= 210
# ncases= 41790

# %%
n1, m1= angles.shape
ncases1=n1*m1

print('n1=', n1,'m1=', m1)
print('ncases=',ncases1)

y_r= np.zeros((ncases1,5))
y_r.shape

cont=0
for k in range(0, n1):
    for l in range(0, m1): 
        if CM[k,l] == 1:
            y_r[cont,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        else:
            y_r[cont:,:]=[Enn[k,l], Etn[k,l], Ett[k,l],k,l]
        cont= cont+1
        prog=cont/ncases1*100
        
df2= pd.DataFrame({'Angles': angles.flatten()})
df2['Enn']= y_r[:,0].flatten()
df2['Etn']= y_r[:,1].flatten()
df2['Ett']= y_r[:,2].flatten()
df2['k'] = y_r[:,3].flatten()
df2['l'] = y_r[:,4].flatten()

cont1=0
for a in range(0,len(df)):
    i=df_aug.iloc[a,4]
    j=df_aug.iloc[a,5]
    ind=df2.index[(df2['k']==i) & (df2['l']==j)].tolist()
    df2.iloc[ind,1]=df_aug.iloc[a,1]
    df2.iloc[ind,2]=df_aug.iloc[a,2]
    df2.iloc[ind,3]=df_aug.iloc[a,3]
    cont1= cont1+1
    prog=cont1/ncases1*100
    
Enn_MLP_35_aug=df2.Enn.values.reshape(199,-1, order='A')
Etn_MLP_35_aug=df2.Etn.values.reshape(199,-1, order='A')
Ett_MLP_35_aug=df2.Ett.values.reshape(199,-1, order='A')

spio.savemat('Enn_MLP_35_aug.mat', {'Enn_MLP_35_aug': Enn_MLP_35_aug}) # savemat expects a dictionary
spio.savemat('Etn_MLP_35_aug.mat', {'Etn_MLP_35_aug': Etn_MLP_35_aug})
spio.savemat('Ett_MLP_35_aug.mat', {'Ett_MLP_35_aug': Ett_MLP_35_aug})
# Out:
# n1= 199 m1= 210
# ncases= 41790
